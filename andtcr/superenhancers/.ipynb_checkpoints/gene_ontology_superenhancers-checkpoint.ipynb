# %%
'''
Parse gene ontology clusters produced by David and
produce plots.
'''
# Out:
# '\nParse gene ontology clusters produced by David and\nproduce plots.\n'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from io import StringIO

# %%
sns.set_context('poster')

# %%
# Get whole string
filename = 'go_analysis/shared_david_clusters.txt'
cluster_str = open(filename).read()

# %%
# Split out clusters
titled_clusters = cluster_str.split('\n\n')

# %%
# Get enrichment score
enrichment = [float(c[c.find(': ') + 2:c.find('\n')]) for c in titled_clusters]
enrichment = pd.Series(enrichment)

# %%
# Remove title line
text_clusters = [c[c.find('\n') + 1:] for c in titled_clusters]

# %%
# Convert into dataframes
clusters = [pd.io.parsers.read_csv(StringIO(c), sep='\t', header=0) for c in text_clusters]

# %%
clusters[0].head()
# Out:
#           Category                                               Term  Count  \
# 0  SP_PIR_KEYWORDS                               protein biosynthesis     32
# 1    GOTERM_BP_FAT                             GO:0006412~translation     41
# 2    GOTERM_MF_FAT  GO:0008135~translation factor activity, nuclei...     15
#
#            %        PValue                                              Genes  \
# 0  10.996564  6.246493e-27  EIF6, EEF1B2, NARS, EIF5A, RPS2, KARS, RPS3, I...
# 1  14.089347  1.857436e-22  EIF6, EEF1B2, NARS, RPL14, EIF5A, RPS2, KARS, ...
# 2   5.154639  1.941559e-09  EIF6, EEF1A1, EEF1B2, EIF5A, ETF1, EIF4G1, EIF...
#
#    List Total  Pop Hits  Pop Total  Fold Enrichment    Bonferroni  \
# 0         285       139      17854        14.422012  1.736525e-24
# 1         249       319      13588         7.013735  2.932892e-19
# 2         238        98      13288         8.545704  7.688570e-07
#
#       Benjamini           FDR
# 0  8.682626e-25  8.250201e-24
# 1  2.932892e-19  3.105356e-19
# 2  2.562857e-07  2.704137e-06

# %%
# Make a single dataframe with the first row of each cluster
top_matches = [c.loc[0].tolist() for c in clusters]
matches = pd.DataFrame(top_matches, columns=clusters[0].columns)

# %%
# Clean names
matches['Ontology term'] = matches['Term'].str.replace(r'GO:.*~','')
matches
# Out:
#             Category                                               Term  \
# 0    SP_PIR_KEYWORDS                               protein biosynthesis
# 1    SP_PIR_KEYWORDS                                molecular chaperone
# 2    SP_PIR_KEYWORDS                                    isopeptide bond
# 3      GOTERM_CC_FAT  GO:0005852~eukaryotic translation initiation f...
# 4    SP_PIR_KEYWORDS                                 nucleotide-binding
# 5    SP_PIR_KEYWORDS                                  ribonucleoprotein
# 6      GOTERM_CC_FAT                               GO:0005730~nucleolus
# 7      GOTERM_BP_FAT                 GO:0034660~ncRNA metabolic process
# 8      GOTERM_CC_FAT                              GO:0042470~melanosome
# 9      GOTERM_BP_FAT                          GO:0006396~RNA processing
# 10   SP_PIR_KEYWORDS                                    stress response
# 11     GOTERM_BP_FAT    GO:0022613~ribonucleoprotein complex biogenesis
# 12   SP_PIR_KEYWORDS                                         proteasome
# 13     GOTERM_CC_FAT                           GO:0005739~mitochondrion
# 14          INTERPRO               IPR005937:26S proteasome subunit P45
# 15             SMART                                       SM00088:PINT
# 16     GOTERM_BP_FAT                         GO:0001775~cell activation
# 17     GOTERM_BP_FAT        GO:0042127~regulation of cell proliferation
# 18    UP_SEQ_FEATURE                                         repeat:1-2
# 19     GOTERM_CC_FAT  GO:0045261~proton-transporting ATP synthase co...
# 20     GOTERM_BP_FAT  GO:0031400~negative regulation of protein modi...
# 21     GOTERM_BP_FAT                    GO:0006983~ER overload response
# 22          INTERPRO                 IPR001404:Heat shock protein Hsp90
# 23     GOTERM_BP_FAT  GO:0010605~negative regulation of macromolecul...
# 24     GOTERM_BP_FAT  GO:0031328~positive regulation of cellular bio...
# 25          INTERPRO  IPR010987:Glutathione S-transferase, C-termina...
# 26     GOTERM_BP_FAT  GO:0008285~negative regulation of cell prolife...
# 27     GOTERM_BP_FAT     GO:0051249~regulation of lymphocyte activation
# 28     GOTERM_BP_FAT  GO:0045637~regulation of myeloid cell differen...
# 29             SMART                                        SM00360:RRM
# ..               ...                                                ...
# 74      KEGG_PATHWAY       mmu04621:NOD-like receptor signaling pathway
# 75     GOTERM_BP_FAT          GO:0001701~in utero embryonic development
# 76          INTERPRO                  IPR001440:Tetratricopeptide TPR-1
# 77     GOTERM_BP_FAT               GO:0006006~glucose metabolic process
# 78    UP_SEQ_FEATURE                     DNA-binding region:Basic motif
# 79   SP_PIR_KEYWORDS                                           helicase
# 80      KEGG_PATHWAY               mmu04062:Chemokine signaling pathway
# 81     GOTERM_BP_FAT                          GO:0016477~cell migration
# 82    UP_SEQ_FEATURE                     DNA-binding region:Basic motif
# 83    UP_SEQ_FEATURE                                        repeat:WD 5
# 84     GOTERM_MF_FAT                  GO:0019901~protein kinase binding
# 85     GOTERM_BP_FAT                      GO:0022402~cell cycle process
# 86      KEGG_PATHWAY    mmu04060:Cytokine-cytokine receptor interaction
# 87     GOTERM_BP_FAT            GO:0030334~regulation of cell migration
# 88     GOTERM_BP_FAT            GO:0009116~nucleoside metabolic process
# 89     GOTERM_BP_FAT         GO:0009719~response to endogenous stimulus
# 90   SP_PIR_KEYWORDS                                                ATP
# 91   SP_PIR_KEYWORDS                                             Lectin
# 92    UP_SEQ_FEATURE                  propeptide:Removed in mature form
# 93     GOTERM_BP_FAT     GO:0050804~regulation of synaptic transmission
# 94     GOTERM_CC_FAT                              GO:0005813~centrosome
# 95     GOTERM_BP_FAT                    GO:0016570~histone modification
# 96     GOTERM_BP_FAT   GO:0000226~microtubule cytoskeleton organization
# 97    UP_SEQ_FEATURE                              domain:Ig-like V-type
# 98     GOTERM_BP_FAT                   GO:0016044~membrane organization
# 99     GOTERM_BP_FAT  GO:0048609~reproductive process in a multicell...
# 100         INTERPRO             IPR018957:Zinc finger, C3HC4 RING-type
# 101    GOTERM_CC_FAT                               GO:0005792~microsome
# 102    GOTERM_BP_FAT              GO:0048514~blood vessel morphogenesis
# 103  SP_PIR_KEYWORDS                                        zinc-finger
#
#      Count          %        PValue  \
# 0       32  10.996564  6.246493e-27
# 1       11   3.780069  8.334475e-16
# 2       26   8.934708  2.602407e-12
# 3        8   2.749141  4.083862e-10
# 9    GAR1, STRAP, SNRPD3, SF3B5, YBX1, SF3B3, HNRNP...         249       437
# 10   HSP90AB1, HSPH1, HSP90B1, HSP90AA1, HSPA4, HSP...         285        45
# 11   EIF6, GTPBP4, GAR1, EMG1, RRP9, NOP10, EIF3D, ...         249       137
# 12   PSMA7, PSMA2, PSMA1, PSMB4, PSMD14, PSMB7, PSM...         285        54
# 13   UQCRC2, HSP90AB1, ATP5D, LDHA, NARS, ATP5B, CY...         226      1322
# 14                          PSMC5, PSMC4, PSMC3, PSMC2         287         6
# 15                          EIF3C, EIF3A, EIF3E, PSMD3         131        16
# 16   TRP53, SATB1, TNF, STAT5A, FKBP1A, NFKB2, CBLB...         249       246
# 17   CNBP, TNF, STAT5A, NFKBIA, BCL2L1, TNFRSF4, MI...         249       538
# 18                      RPL14, UBA1, DDX21, CALR, CANX         281        23
# 19                         ATP5D, ATP5B, ATP5O, ATP5A1         226         6
# 20            GTPBP4, BAX, SOCS1, FKBP1A, YWHAE, NOC2L         249        38
# 21                                 TRP53, HSPA5, DDIT3         249         8
# 22                         HSP90AB1, HSP90B1, HSP90AA1         287         4
# 23   TRP53, SATB1, GTPBP4, TNF, STRAP, TRIM28, SOCS...         249       506
# 24   HSP90AB1, CNBP, TNF, STAT5A, EIF5A, NFKB1, IL1...         249       552
# 25                    CLIC4, AIMP2, EEF1E1, EPRS, MARS         287        30
# 26   TRP53, GTPBP4, IL2RA, TNF, NDFIP1, CDKN1A, SPR...         249       224
# 27   CDKN1A, CBLB, IL2RA, HSP90AA1, STAT5A, NDFIP1,...         249       144
# 28         TNF, HIF1A, TNFSF11, STAT5A, NDFIP1, NFKBIA         249        51
# 29   HNRNPM, EIF3B, EIF3G, EIF4H, HNRNPA2B1, PTBP1,...         131       212
# ..                                                 ...         ...       ...
# 74   HSP90AB1, HSP90B1, TNF, HSP90AA1, NFKBIB, NFKB...         156        62
# 75   TRP53, PRMT1, HIF1A, PSMC4, PSMC3, BTF3, BCL2L...         249       267
# 76                         ST13, TOMM70A, FKBP4, STIP1         287        95
# 77                          ATF4, LDHA, TNF, MYC, MDH2         249       140
# 78                     ATF4, HIF1A, BHLHE40, MYC, JUNB         281       154
# 79                  DDX39, G3BP1, DHX15, DDX21, RUVBL2         285       120
# 80   ITK, CCR8, CCR7, CCL22, NFKBIB, NFKBIA, NFKB1,...         156       182
# 81         CCL22, TNF, HIF1A, NUP62, ATP5B, BAX, YWHAE         249       240
# 82                     ATF4, HIF1A, BHLHE40, MYC, JUNB         281       154
# 83            EIF3B, STRAP, EIF3I, RRP9, GNB2L1, WDR43         281       202
# 84                                DUSP2, CCND2, GNB2L1         238        71
# 85   TAF10, CDKN1A, ANP32B, RCC2, CCND2, RAN, NPM1,...         249       393
# 86   IL2RB, IL2RA, TNF, IL21R, TNFRSF4, CCL4, TNFSF...         156       244
# 87                                GTPBP4, HIF1A, CLIC4         249        92
# 88                                   NME2, NME1, PRPS1         249        56
# 27       13588         4.168563  3.862398e-01  2.013417e-02  5.155226e-01
# 28       13588         6.420033  9.738453e-01  4.621891e-02  3.784516e+00
# 29        9131         3.616628  7.676228e-02  3.914740e-02  9.439406e-01
# ..         ...              ...           ...           ...           ...
# 74        5738         4.152812  5.032452e-01  4.557281e-02  6.836495e+00
# 75       13588         1.839448  1.000000e+00  5.922868e-01  8.739264e+01
# 76       17763         2.605978  1.000000e+00  9.771538e-01  9.616043e+01
# 77       13588         1.948939  1.000000e+00  8.297271e-01  9.923541e+01
# 78       16021         1.851112  1.000000e+00  9.985226e-01  9.939675e+01
# 79       17854         2.610234  1.000000e+00  4.495212e-01  8.276850e+01
# 80        5738         1.818893  9.999993e-01  4.315473e-01  7.605026e+01
# 81       13588         1.591633  1.000000e+00  8.495389e-01  9.953670e+01
# 82       16021         1.851112  1.000000e+00  9.985226e-01  9.939675e+01
# 83       16021         1.693492  1.000000e+00  9.985946e-01  9.934228e+01
# 84       13288         2.359096  1.000000e+00  9.408573e-01  9.980997e+01
# 85       13588         1.527412  1.000000e+00  7.394685e-01  9.657878e+01
# 86        5738         2.411938  2.272330e-01  2.316188e-02  2.575287e+00
# 87       13588         1.779466  1.000000e+00  9.712440e-01  9.999916e+01
# 88       13588         2.923408  1.000000e+00  8.475431e-01  9.950937e+01
# 89       13588         1.482888  1.000000e+00  9.518611e-01  9.999257e+01
# 90       17854         2.489230  1.000000e+00  3.916177e-01  7.270742e+01
# 91       17854         1.500494  1.000000e+00  9.115343e-01  9.998886e+01
# 92       16021         1.554934  1.000000e+00  9.990565e-01  9.983298e+01
# 93       13588         1.637108  1.000000e+00  9.793258e-01  9.999983e+01
# 94       12504         1.728982  1.000000e+00  7.299591e-01  9.928659e+01
# 95       13588         1.779466  1.000000e+00  9.712440e-01  9.999916e+01
# 96       13588         1.474872  1.000000e+00  9.883580e-01  9.999998e+01
# 97       16021         1.644641  1.000000e+00  9.999688e-01  9.999945e+01
# 98       13588         1.003130  1.000000e+00  9.977205e-01  1.000000e+02
# 99       13588         0.933966  1.000000e+00  9.985260e-01  1.000000e+02
# 100      17763         0.847835  1.000000e+00  1.000000e+00  1.000000e+02
# 101      12504         0.943081  1.000000e+00  9.899252e-01  1.000000e+02
# 102      13588         0.826822  1.000000e+00  9.998902e-01  1.000000e+02
# 103      17854         0.468281  1.000000e+00  1.000000e+00  1.000000e+02
#
#                                          Ontology term
# 0                                 protein biosynthesis
# 1                                  molecular chaperone
# 2                                      isopeptide bond
# 3    eukaryotic translation initiation factor 3 com...
# 4                                   nucleotide-binding
# 5                                    ribonucleoprotein
# 6                                            nucleolus
# 7                              ncRNA metabolic process
# 8                                           melanosome
# 9                                       RNA processing
# 10                                     stress response
# 11                ribonucleoprotein complex biogenesis
# 12                                          proteasome
# 13                                       mitochondrion
# 14                IPR005937:26S proteasome subunit P45
# 15                                        SM00088:PINT
# 16                                     cell activation
# 17                    regulation of cell proliferation
# 18                                          repeat:1-2
# 19   proton-transporting ATP synthase complex, cata...
# 20   negative regulation of protein modification pr...
# 21                                ER overload response
# 22                  IPR001404:Heat shock protein Hsp90
# 23   negative regulation of macromolecule metabolic...
# 24   positive regulation of cellular biosynthetic p...
# 25   IPR010987:Glutathione S-transferase, C-termina...
# 26           negative regulation of cell proliferation
# 27                 regulation of lymphocyte activation
# 28          regulation of myeloid cell differentiation
# 29                                         SM00360:RRM
# ..                                                 ...
# 74        mmu04621:NOD-like receptor signaling pathway
# 75                      in utero embryonic development
# 76                   IPR001440:Tetratricopeptide TPR-1
# 77                           glucose metabolic process
# 78                      DNA-binding region:Basic motif
# 79                                            helicase
# 80                mmu04062:Chemokine signaling pathway
# 81                                      cell migration
# 82                      DNA-binding region:Basic motif
# 83                                         repeat:WD 5
# 84                              protein kinase binding
# 85                                  cell cycle process
# 86     mmu04060:Cytokine-cytokine receptor interaction
# 87                        regulation of cell migration
# 88                        nucleoside metabolic process
# 89                     response to endogenous stimulus
# 90                                                 ATP
# 91                                              Lectin
# 92                   propeptide:Removed in mature form
# 93                 regulation of synaptic transmission
# 94                                          centrosome
# 95                                histone modification
# 96               microtubule cytoskeleton organization
# 97                               domain:Ig-like V-type
# 98                               membrane organization
# 99    reproductive process in a multicellular organism
# 100             IPR018957:Zinc finger, C3HC4 RING-type
# 101                                          microsome
# 102                         blood vessel morphogenesis
# 103                                        zinc-finger
#
# [104 rows x 14 columns]

# %%
# Some redundancy. Take interesting sets.
subdata = matches.loc[list(range(8)) + [16,17]]

# %%
# Plot p-val, with number of genes as size of circle.
scalor = 10
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.scatter(subdata['PValue'], enrichment.loc[subdata.index],
            s=subdata['Count']*scalor, alpha=.5)
ax.set_xscale('log')
ax.set_xlim([0, 1e-30])

# Add labels. Shift some of text so that it's legible.
text_loc = enrichment.loc[subdata.index].tolist()
text_loc[2] -= .6
text_loc[3] += .2
text_loc[4] += .2
text_loc[8] += .8 
for i, label in enumerate(subdata['Ontology term']):
    ax.text(subdata['PValue'].loc[subdata.index[i]]/3, 
            text_loc[i],
            label, fontsize=16)


plt.ylabel('DAVID Cluster Enrichment Score')
plt.xlabel('Term P-Value')
title = 'Gene Ontology Enrichment for Activation Signature Genes'
plt.title(title)
plt.savefig('figures/{}.png'.format(title.replace(' ','_')),
            bbox_inches='tight')
plt.show()

# %%
# And just in chart form.
subdata['p-value'] = ['%.2g' % s for s in subdata['PValue']]
chartable = subdata[['Ontology term', 'p-value', 'Count']]
chartable.index = range(1, len(chartable)+1)
chartable
# Out:
#                                         Ontology term  p-value  Count
# 1                                protein biosynthesis  6.2e-27     32
# 2                                 molecular chaperone  8.3e-16     11
# 3                                     isopeptide bond  2.6e-12     26
# 4   eukaryotic translation initiation factor 3 com...  4.1e-10      8
# 5                                  nucleotide-binding  1.8e-10     62
# 6                                   ribonucleoprotein  2.6e-16     30
# 7                                           nucleolus  1.7e-12     29
# 8                             ncRNA metabolic process  3.1e-08     19
# 9                                     cell activation  0.00017     15
# 10                   regulation of cell proliferation  5.9e-06     27
