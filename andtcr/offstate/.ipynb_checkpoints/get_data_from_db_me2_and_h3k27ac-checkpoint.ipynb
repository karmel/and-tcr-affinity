# %%
from collections import OrderedDict
import pandas as pd

# %%
from pandas.io.sql import read_sql_query
from sqlalchemy import create_engine


def get_engine(uri, password, username='vespucci_user', dbname='vespucci'):
    '''
    dialect+driver://username:password@host:port/database
    '''
    return create_engine('postgresql://{}:{}@{}:5432/{}'.format(
        username, password, uri, dbname))


def dataframe_from_query(query, engine):
    '''
    Given the database connection and query, return a Pandas dataframe
    with the requested data.
    '''
    return read_sql_query(query, engine)

# %%
engine = get_engine(
    uri='ec2-54-160-104-39.compute-1.amazonaws.com',
    password='vespucci 2015')

# %%
ab = 'h3k27ac'
peptides = ['no_peptide', '1um_k99a', '1um_pcc']

# %%
sql = '''select distinct on (p1.id) 
p1.id, chr."name" as chr_name, p1.start, p1."end",
p1.chromosome_id, 
p1.tag_count as tag_count_{peptide},
p1.id as id_{peptide},
p2.tag_count as tag_count_{other_1},
p2.id as id_{other_1},
p3.tag_count as tag_count_{other_2},
p3.id as id_{other_2}

from chipseq.peak_cd4tcell_{ab}_{peptide}_24h p1
join genome_reference_mm10.chromosome chr 
on p1.chromosome_id = chr.id

left outer join chipseq.peak_cd4tcell_{ab}_{other_1}_24h p2
on p1.chromosome_id = p2.chromosome_id
and p1.start_end && p2.start_end
left outer join chipseq.peak_cd4tcell_{ab}_{other_2}_24h p3
on p1.chromosome_id = p3.chromosome_id
and p1.start_end && p3.start_end

left outer join genome_reference_mm10.sequence_transcription_region reg
on p1.chromosome_id = reg.chromosome_id
and p1.start_end && reg.start_site_1000

where reg.id is {genic} NULL;
'''

# %%
others_labels = ['other_1', 'other_2']
for i, current in enumerate(peptides):
    others = peptides[:i] + peptides[i+1:]
    others_d = OrderedDict(zip(others_labels, others))
    
    nongene_sql = sql.format(ab=ab, peptide=current, genic='', **others_d)
    gene_sql = sql.format(ab=ab, peptide=current, genic='NOT', **others_d)
    
    data = dataframe_from_query(nongene_sql, engine)
    data.to_csv('data/enhancers_{}_and_{}.txt'.format(ab, current), 
                sep='\t', header=True, index=False)
    data = dataframe_from_query(gene_sql, engine)
    data.to_csv('data/promoters_{}_and_{}.txt'.format(ab, current),
                sep='\t', header=True, index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-a30a2fb72f81> in <module>()
#       7     gene_sql = sql.format(ab=ab, peptide=current, genic='NOT', **others_d)
#       8
# ----> 9     data = dataframe_from_query(nongene_sql, engine)
#      10     data.to_csv('data/enhancers_me2_and_{}.txt'.format(current),
#      11                 sep='\t', header=True, index=False)
#
# <ipython-input-2-cf5b15c956d8> in dataframe_from_query(query, engine)
#      16     with the requested data.
#      17     '''
# ---> 18     return read_sql_query(query, engine)
#
# /Applications/anaconda/lib/python3.4/site-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     399     return pandas_sql.read_query(
#     400         sql, index_col=index_col, params=params, coerce_float=coerce_float,
# --> 401         parse_dates=parse_dates, chunksize=chunksize)
#     402
#     403
#
# /Applications/anaconda/lib/python3.4/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1082         args = _convert_params(sql, params)
#    1083
# -> 1084         result = self.execute(*args)
#    1085         columns = result.keys()
#    1086
#
# /Applications/anaconda/lib/python3.4/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#     976     def execute(self, *args, **kwargs):
#     977         """Simple passthrough to SQLAlchemy engine"""
# --> 978         return self.engine.execute(*args, **kwargs)
#     979
#     980     def read_table(self, table_name, index_col=None, coerce_float=True,
#
# /Applications/anaconda/lib/python3.4/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1680
#    1681         connection = self.contextual_connect(close_with_result=True)
# -> 1682         return connection.execute(statement, *multiparams, **params)
#    1683
#    1684     def scalar(self, statement, *multiparams, **params):
#
# /Applications/anaconda/lib/python3.4/site-packages/sqlalchemy/engine/base.py in execute(self, object, *multiparams, **params)
#     710         """
#     711         if isinstance(object, util.string_types[0]):
# --> 712             return self._execute_text(object, multiparams, params)
#     713         try:
#     714             meth = object._execute_on_connection
#
# /Applications/anaconda/lib/python3.4/site-packages/sqlalchemy/engine/base.py in _execute_text(self, statement, multiparams, params)
#     859             statement,
#     860             parameters,
# --> 861             statement, parameters
#     862         )
#     863         if self._has_events or self.engine._has_events:
#
# /Applications/anaconda/lib/python3.4/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#     938                                      statement,
#     939                                      parameters,
# --> 940                                      context)
#     941         except Exception as e:
#     942             self._handle_dbapi_exception(
#
# /Applications/anaconda/lib/python3.4/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     433
#     434     def do_execute(self, cursor, statement, parameters, context=None):
# --> 435         cursor.execute(statement, parameters)
#     436
#     437     def do_execute_no_params(self, cursor, statement, context=None):
#
# <string> in __new__(_cls, name, type_code, display_size, internal_size, precision, scale, null_ok)
#
# KeyboardInterrupt:

# %%
data.head()
# Out:
#    id chr_name      start        end  chromosome_id  tag_count_1um_pcc  \
# 0   2     chr9   32692704   32752634             12             2532.6
# 1   3    chr11   11687045   11743539             13             2036.0
# 2   4     chr1  138126403  138180881              1             1874.8
# 3   6    chr11  118205807  118249655             13             1786.0
# 4   7    chr11  117316781  117351761             13             1628.7
#
#    id_1um_pcc  tag_count_no_peptide  id_no_peptide  tag_count_1um_k99a  \
# 0           2                2472.8              2              2246.5
# 1           3                2153.9              3              1962.2
# 2           4                2058.8              4              1868.7
# 3           6                1913.8              5              1847.1
# 4           7                1439.3             13              1641.9
#
#    id_1um_k99a
# 0            2
# 1            3
# 2            4
# 3            5
# 4            7

# %%
# We want one unified set of all the peaks,
# but there is overlap between each of our sets.
# Take the record from the set with the biggest peak
# in each case where there are duplicates.
# This is not perfect, especially for the cases
# where one large peak covers several smaller,
# but it gives us a place to start.

for peak_type in ('enhancers','promoters'):
    keep_dfs = []
    for i, pep in enumerate(peptides):
        data = pd.io.parsers.read_csv('data/{}_me2_and_{}.txt'.format(peak_type, pep), 
                                    sep='\t', header=0)
        data = data.fillna(0)
        print(len(data))
        key = 'tag_count_' + pep

        peptides_before = ['tag_count_' + o for o in peptides[:i]]
        peptides_after = ['tag_count_' + o for o in peptides[i+1:]]
        others = peptides_before + peptides_after
        data_mask = data[key] > data[others].max(axis=1)
        print(sum(data_mask))

        # If there is a tie, only take this row if it is the first instance of the tie.
        tie_mask = data[key] == data[others].max(axis=1)
        # Is this the first instance? Fill nulls for the case of the first column.
        first_mask = data[key] > data[peptides_before].max(axis=1).fillna(0)
        print(sum(tie_mask & first_mask))
        keep_dfs.append(data[data_mask | (tie_mask & first_mask)])

    keep = pd.concat(keep_dfs, join='outer', axis=0, ignore_index=True)
    print(len(keep))
    keep.head()
    keep.to_csv('data/{}_me2_and_union.txt'.format(peak_type), 
                sep='\t', header=True, index=False)
# Out:
# 21413
# 13147
# 48
# 13611
# 2266
# 5
# 14947
# 5850
# 0
# 21316
# 12066
# 7254
# 27
# 11068
# 1135
# 3
# 11267
# 3527
# 0
# 11946
