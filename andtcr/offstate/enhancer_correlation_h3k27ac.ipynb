# %%
'''
How do no-pep enhancers compare with the other two conditions?
'''
# Out:
# '\nHow do no-pep enhancers compare with the other two conditions?\n'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# %%
sns.set_context('poster')

# %%
ab = 'h3k27ac'
data = pd.io.parsers.read_csv('data/enhancers_{}_and_union.txt'.format(ab), 
                sep='\t', header=0)
data = data.fillna(0)
data.head()
# Out:
#   chr_name  chromosome_id        end   id  id_1um_k99a  id_1um_pcc  \
# 0    chr11             13   98501532    7         1681         108
# 1    chr17             18   84159153    8         1848         296
# 2    chr15             16   27607194   93         2400        1762
# 3    chr17             18   84862652  110         1901        2188
# 4     chr4              5  134123465  112          419         442
#
#    id_no_peptide      start  tag_count_1um_k99a  tag_count_1um_pcc  \
# 0              7   98457356               200.3              796.4
# 1              8   84123155               190.4              490.9
# 2             93   27586650               162.9              201.5
# 3            110   84843858               186.8              176.3
# 4            112  134104987               395.8              415.5
#
#    tag_count_no_peptide
# 0                 950.2
# 1                 936.1
# 2                 554.1
# 3                 521.5
# 4                 516.9

# %%
limit = 1000

# %%
r = pearsonr(data['tag_count_no_peptide'], data['tag_count_1um_k99a'])

sns.regplot('tag_count_no_peptide','tag_count_1um_k99a', data,
            label='Linear fit (r={:.2f})'.format(r[0]))
plt.xlim([0,limit])
plt.ylim([0,limit])

plt.legend()

plt.xlabel('No Peptide Enhancer Tag Count')
plt.ylabel('1uM K99A Enhancer Tag Count')

title = 'No Peptide versus 1uM K99A H3K27Ac correlation'
plt.title(title)

plt.savefig('figures/{}.png'.format(title.replace(' ','_')), 
            bbox_inches='tight')

# %%
r = pearsonr(data['tag_count_no_peptide'], data['tag_count_1um_pcc'])
sns.regplot('tag_count_no_peptide','tag_count_1um_pcc', data,
            label='Linear fit (r={:.2f})'.format(r[0]))
plt.xlim([0,limit])
plt.ylim([0,limit])

plt.legend()

plt.xlabel('No Peptide Enhancer Tag Count')
plt.ylabel('1uM PCC Enhancer Tag Count')

title = 'No Peptide versus 1uM PCC H3K27Ac correlation'
plt.title(title)

plt.savefig('figures/{}.png'.format(title.replace(' ','_')), 
            bbox_inches='tight')

# %%
r = pearsonr(data['tag_count_1um_k99a'], data['tag_count_1um_pcc'])
sns.regplot('tag_count_1um_k99a','tag_count_1um_pcc', data,
            label='Linear fit (r={:.2f})'.format(r[0]))
plt.xlim([0,limit])
plt.ylim([0,limit])

plt.legend()

plt.xlabel('1uM K99A Enhancer Tag Count')
plt.ylabel('1uM PCC Enhancer Tag Count')

title = '1uM K99A versus 1uM PCC H3K27Ac correlation'
plt.title(title)

plt.savefig('figures/{}.png'.format(title.replace(' ','_')), 
            bbox_inches='tight')
