# %%
'''
Plot output of FlowJo Geometric MFI analysis as a pretty bargraph.
'''
# Out:
# '\nPlot output of FlowJo Geometric MFI analysis as a pretty bargraph.\n'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_context('poster')

# %%
data = pd.io.parsers.read_csv('data/CD69-CD25-Tbet-Irf4-Mean-MFI.csv', 
                                    sep=',', 
                                    header=0, index_col=0)

# Remove Mean and SD rows
data = data[data['TUBE NAME'].isnull() == False]

# Remove PMA positive controls
data = data[data['TUBE NAME'].str[:3] != 'PMA']

# %%
data.tail()
# Out:
#                                                               TUBE NAME  \
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-1uM-2.fcs                 PCC-1uM-2
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1.fcs             PCC-100uM-1
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1,3a,1-1.fcs  PCC-100uM-1:1-1
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1,3a,1-2.fcs  PCC-100uM-1:1-2
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-2.fcs             PCC-100uM-2
#
#                                                         Lymphocytes/Single Cells/Single Cells/CD4+ | Freq. of Parent (%)  \
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-1uM-2.fcs                                                        78.1
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1.fcs                                                      78.1
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1,3a,1-1.fcs                                               78.1
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1,3a,1-2.fcs                                               78.1
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-2.fcs                                                      78.1
#
#                                                         Lymphocytes/Single Cells/Single Cells/CD4+/CD25+ | Freq. of Parent (%)  \
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-1uM-2.fcs                                                        81.5
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1.fcs                                                      81.5
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1,3a,1-1.fcs                                               81.5
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1,3a,1-2.fcs                                               81.5
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-2.fcs                                                      81.5
#
#                                                         Lymphocytes/Single Cells/Single Cells/CD4+/CD25+ | Geometric Mean (Comp-PE-Cy7-A)  \
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-1uM-2.fcs                                                        7236
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1.fcs                                                      6534
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1,3a,1-1.fcs                                               9407
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1,3a,1-2.fcs                                               8705
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-2.fcs                                                      6315
#
#                                                         Lymphocytes/Single Cells/Single Cells/CD4+/CD69+ | Geometric Mean (Comp-FITC-A)  \
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-1uM-2.fcs                                                        3888
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1.fcs                                                      3558
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1,3a,1-1.fcs                                               3724
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1,3a,1-2.fcs                                               3896
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-2.fcs                                                      3643
#
#                                                         Lymphocytes/Single Cells/Single Cells/CD4+ | Geometric Mean (Comp-PE-A)  \
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-1uM-2.fcs                                                         308
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1.fcs                                                       398
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1,3a,1-1.fcs                                                488
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1,3a,1-2.fcs                                                407
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-2.fcs                                                       339
#
#                                                         Lymphocytes/Single Cells/Single Cells/CD4+ | Geometric Mean (Comp-PerCP-Cy5-5-A)  \
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-1uM-2.fcs                                                       16903
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1.fcs                                                     22898
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1,3a,1-1.fcs                                              23642
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1,3a,1-2.fcs                                              25783
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-2.fcs                                                     21503
#
#                                                         Lymphocytes/Single Cells/Single Cells/CD4+ | Geometric Mean (Comp-APC-A)  \
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-1uM-2.fcs                                                        5719
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1.fcs                                                      5992
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1,3a,1-1.fcs                                               5814
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1,3a,1-2.fcs                                               5878
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-2.fcs                                                      6053
#
#                                                         Lymphocytes/Single Cells/Single Cells/CD4+ | Geometric Mean (Comp-Pacific Blue-A)  \
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-1uM-2.fcs                                                        1205
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1.fcs                                                       678
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1,3a,1-1.fcs                                                486
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1,3a,1-2.fcs                                                847
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-2.fcs                                                       887
#
#                                                         Unnamed: 10
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-1uM-2.fcs                   NaN
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1.fcs                 NaN
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1,3a,1-1.fcs          NaN
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-1,3a,1-2.fcs          NaN
# Stain-1-Foxo1-69-Tbet-Irf4-25-4_PCC-100uM-2.fcs                 NaN

# %%
# Collapse tube names
data['TUBE NAME'] = data['TUBE NAME'].replace(to_replace='-\d$', 
                                              value='',
                                              regex=True)
data['TUBE NAME'].unique().tolist()
# Out:
# ['K99A-1uM',
#  'K99A-10uM',
#  'K99A-10uM-1:1',
#  'K99A-100uM',
#  'K99A-100uM-1:1',
#  'NoPep',
#  'PCC-_01uM',
#  'PCC-_1uM',
#  'PCC-1uM',
#  'PCC-1uM-1:1',
#  'PCC-100uM',
#  'PCC-100uM-1:1']

# %%
# I want a particular ordering of columns.
col_order = ['NoPep',
 'K99A-1uM',
 'K99A-10uM',
 'K99A-100uM',
 'PCC-_01uM',
 'PCC-_1uM',
 'PCC-1uM',
 'PCC-100uM',
 ]

labels = [s.replace('NoPep', 'No-Peptide').replace('-', ' ').replace('_', '0.') for s in col_order]
peps = pd.Series(labels[:1] + [s.split(' ')[0] for s in labels[1:]]).unique()
concentrations = ['0uM'] + [s.split(' ')[1] for s in labels[1:]]
peps, concentrations
# Out:
# (array(['No Peptide', 'K99A', 'PCC'], dtype=object),
#  ['0uM', '1uM', '10uM', '100uM', '0.01uM', '0.1uM', '1uM', '100uM'])

# %%
ab = 'Tbet'
col_name = 'Lymphocytes/Single Cells/Single Cells/CD4+ | Geometric Mean (Comp-PE-A)'.format(ab)

# %%
# Group by name
means = data.groupby(by='TUBE NAME')[col_name].mean()[col_order]
stddev = data.groupby(by='TUBE NAME')[col_name].std()[col_order]

# %%
# Set up colors
colors = sns.color_palette("pastel", 3)

# Get sets of three for final two
colorset = zip(colors[1:], colors[1:], colors[1:])

# Flatten
colorset = colors[:1] + [item for sublist in colorset for item in sublist]

# Add an extra for the last PCC sample
colorset += colorset[-1:]

# %%
x_range = range(0, len(means))
plt.figure()

plt.bar([x + .2 for x in x_range], means, color=list(colorset))
plt.errorbar([x + .6 for x in x_range], means, linewidth=0,
        yerr=stddev, ecolor='black', elinewidth=.5, capsize=20)
plt.xlim([0, len(means) + .2])
plt.ylabel('Mean Fluorescence Intensity for ' + ab)

# Complicated x-axis.
plt.xticks([x + .6 for x in x_range], concentrations,
           rotation=90)

# Then, the peptide. Manually set because we have different counts per peptide...
label_loc = [.6, 2.6, 6.2]
for i, loc in enumerate(label_loc):
    plt.text(loc, -100, peps[i].replace(' ', '\n'), 
             horizontalalignment='center', fontsize=14)

title = 'MFI of {}'.format(ab)
plt.title(title)
plt.savefig('figures/{}.png'.format(title.replace(' ', '_')), bbox_inches='tight')

# %%
ab = 'Irf4'
col_name = 'Lymphocytes/Single Cells/Single Cells/CD4+ | Geometric Mean (Comp-PerCP-Cy5-5-A)'.format(ab)

# %%
# Group by name
means = data.groupby(by='TUBE NAME')[col_name].mean()[col_order]
stddev = data.groupby(by='TUBE NAME')[col_name].std()[col_order]

# %%
x_range = range(0, len(means))
plt.figure()

plt.bar([x + .2 for x in x_range], means, color=list(colorset))
plt.errorbar([x + .6 for x in x_range], means, linewidth=0,
        yerr=stddev, ecolor='black', elinewidth=.5, capsize=20)
plt.xlim([0, len(means) + .2])
plt.ylabel('Mean Fluorescence Intensity for ' + ab)

# Complicated x-axis.
plt.xticks([x + .6 for x in x_range], concentrations,
           rotation=90)

# Then, the peptide. Manually set because we have different counts per peptide...
label_loc = [.6, 2.6, 6.2]
for i, loc in enumerate(label_loc):
    plt.text(loc, -5000, peps[i].replace(' ', '\n'), 
             horizontalalignment='center', fontsize=14)

title = 'MFI of {}'.format(ab)
plt.title(title)
plt.savefig('figures/{}.png'.format(title.replace(' ', '_')), bbox_inches='tight')

# %%
ab = 'Foxo1'
col_name = 'Lymphocytes/Single Cells/Single Cells/CD4+ | Geometric Mean (Comp-Pacific Blue-A)'.format(ab)

# %%
# Group by name
means = data.groupby(by='TUBE NAME')[col_name].mean()[col_order]
stddev = data.groupby(by='TUBE NAME')[col_name].std()[col_order]

# %%
x_range = range(0, len(means))
plt.figure()

plt.bar([x + .2 for x in x_range], means, color=list(colorset))
plt.errorbar([x + .6 for x in x_range], means, linewidth=0,
        yerr=stddev, ecolor='black', elinewidth=.5, capsize=20)
plt.xlim([0, len(means) + .2])
plt.ylabel('Mean Fluorescence Intensity for ' + ab)

# Complicated x-axis.
plt.xticks([x + .6 for x in x_range], concentrations,
           rotation=90)

# Then, the peptide. Manually set because we have different counts per peptide...
label_loc = [.6, 2.6, 6.2]
for i, loc in enumerate(label_loc):
    plt.text(loc, -300, peps[i].replace(' ', '\n'), 
             horizontalalignment='center', fontsize=14)

title = 'MFI of {}'.format(ab)
plt.title(title)
plt.savefig('figures/{}.png'.format(title.replace(' ', '_')), bbox_inches='tight')

# %%
ab = 'CD4'
col_name = 'Lymphocytes/Single Cells/Single Cells/CD4+ | Geometric Mean (Comp-APC-A)'.format(ab)

# %%
# Group by name
means = data.groupby(by='TUBE NAME')[col_name].mean()[col_order]
stddev = data.groupby(by='TUBE NAME')[col_name].std()[col_order]

# %%
x_range = range(0, len(means))
plt.figure()

plt.bar([x + .2 for x in x_range], means, color=list(colorset))
plt.errorbar([x + .6 for x in x_range], means, linewidth=0,
        yerr=stddev, ecolor='black', elinewidth=.5, capsize=20)
plt.xlim([0, len(means) + .2])
plt.ylabel('Mean Fluorescence Intensity for ' + ab)

# Complicated x-axis.
plt.xticks([x + .6 for x in x_range], concentrations,
           rotation=90)

# Then, the peptide. Manually set because we have different counts per peptide...
label_loc = [.6, 2.6, 6.2]
for i, loc in enumerate(label_loc):
    plt.text(loc, -2500, peps[i].replace(' ', '\n'), 
             horizontalalignment='center', fontsize=14)

title = 'MFI of {}'.format(ab)
plt.title(title)
plt.savefig('figures/{}.png'.format(title.replace(' ', '_')), bbox_inches='tight')
