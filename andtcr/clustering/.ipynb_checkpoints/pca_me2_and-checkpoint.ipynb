# %%
'''
Use PCA to evaluate the axes of variation across our five conditions.
'''
# Out:
# '\nUse PCA to evaluate the axes of variation across our five conditions.\n'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA

# %%
sns.set_context('poster')

# %%
data = pd.io.parsers.read_csv('../clustering/data/me2_and/enhancers_me2_and_union.txt', 
                                    sep='\t', 
                                    header=0)

data = data.fillna(0)

# %%
peptides = ['no_peptide', '10um_k99a', '100um_k99a', '0_1um_pcc', '10um_pcc']
prefix = 'tag_count_'
fields = [prefix + p for p in peptides]

# %%
# Extract fields of interest and normalize to unit norm row-wise
subdata = data[fields].div(data[fields].max(axis=1), axis=0)
subdata.head()
# Out:
#    tag_count_no_peptide  tag_count_10um_k99a  tag_count_100um_k99a  \
# 0                     1             0.908188              0.087005
# 1                     1             0.841617              0.583827
# 2                     1             0.813989              0.027501
# 3                     1             0.471603              0.021751
# 4                     1             0.942992              0.734261
#
#    tag_count_0_1um_pcc  tag_count_10um_pcc
# 0             0.885996            0.449848
# 1             0.786752            0.568151
# 2             0.873755            0.612928
# 3             0.074591            0.114248
# 4             0.959039            0.703288

# %%
# Filter out genes that aren't changing.
def check_changing(row):
    if row.max() - row.min() < row.min():
        return False
    return True
filtered = subdata[subdata.apply(check_changing, axis=1)]
print(len(filtered), len(subdata))
filtered.head()
# Out:
# 31065 35600
#    tag_count_no_peptide  tag_count_10um_k99a  tag_count_100um_k99a  \
# 0                     1             0.908188              0.087005
# 2                     1             0.813989              0.027501
# 3                     1             0.471603              0.021751
# 6                     1             0.713919              0.017568
# 7                     1             0.829474              0.226505
#
#    tag_count_0_1um_pcc  tag_count_10um_pcc
# 0             0.885996            0.449848
# 2             0.873755            0.612928
# 3             0.074591            0.114248
# 6             0.645000            0.152973
# 7             0.774585            0.063743

# %%
transpose = subdata.transpose()
pca = PCA(n_components=5)
X_r = pca.fit(transpose).transform(transpose)
print('Explained variance ratio (first five components): '
      + str(pca.explained_variance_ratio_))
X_r
# Out:
# Explained variance ratio (first five components): [  2.90342677e-01   2.53902976e-01   2.34131507e-01   2.21622840e-01
#    3.87285995e-27]
# /Applications/anaconda/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# array([[ -4.06396386e+01,   3.19535444e+01,  -3.00929205e+01,
#           3.55716490e+01,   2.78532204e-12],
#        [ -2.30457888e+01,   1.87038150e+01,   6.84289783e+00,
#          -5.93241678e+01,   5.34102877e-12],
#        [  2.83041051e+01,   2.13914634e+01,   5.44213444e+01,
#           2.14490277e+01,  -2.46863614e-11],
#        [ -2.34801364e+01,  -6.51561005e+01,   9.36128838e+00,
#           8.06683014e+00,   7.75907744e-12],
#        [  5.88614587e+01,  -6.89272226e+00,  -4.05326101e+01,
#          -5.76333908e+00,   8.80127141e-12]])

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_r[:, 0].tolist(), X_r[:, 1].tolist(), X_r[:, 2].tolist(), s=100)
plt.title('PCA: H3K4me2 by Condition')
plt.xlabel('PC1 (29% of variance)')
plt.ylabel('PC2 (25% of variance)')
ax.set_zlabel('PC3 (23% of variance)')

margin = 2
for i, txt in enumerate(peptides):
    ax.text(X_r[i,0] + margin, 
            X_r[i,1] + margin, 
            X_r[i,2] + margin,
            txt, size=13)

plt.savefig('figures/PCA_H3K4me2_by_Condition_3D.png',
            bbox_inches='tight')

# %%
fig = plt.figure()
plt.scatter(X_r[:, 0].tolist(), X_r[:, 1].tolist(), s=100)
plt.title('PCA: H3K4me2 by Condition')
plt.xlabel('PC1 (29% of variance)')
plt.ylabel('PC2 (25% of variance)')

margin = 2
for i, txt in enumerate(peptides):
    plt.annotate(txt, (X_r[i,0] + margin, 
            X_r[i,1] + margin),
            size=13)

plt.savefig('figures/PCA_H3K4me2_by_Condition.png',
            bbox_inches='tight')

plt.axhline(color='black', linewidth=1)
plt.axvline(color='black', linewidth=1)
plt.savefig('figures/PCA_H3K4me2_by_Condition_axes.png',
            bbox_inches='tight')

# %%
pd.DataFrame(pca.transform(transpose), index=fields)
# Out:
#                               0          1          2          3             4
# tag_count_no_peptide -40.639639  31.953544 -30.092920  35.571649  2.785322e-12
# tag_count_10um_k99a  -23.045789  18.703815   6.842898 -59.324168  5.341029e-12
# tag_count_100um_k99a  28.304105  21.391463  54.421344  21.449028 -2.468636e-11
# tag_count_0_1um_pcc  -23.480136 -65.156101   9.361288   8.066830  7.759077e-12
# tag_count_10um_pcc    58.861459  -6.892722 -40.532610  -5.763339  8.801271e-12

# %%
# We want to get the top and bottom features that make up each component.
components = pd.DataFrame(pca.components_)
for x in range(0,4):
    pc = components.loc[x]
    pc.sort()
    num_elem = len(pc)
    bottom = pc.index[:num_elem//10]
    top = pc.index[9*num_elem//10:]
    
    data.loc[bottom].to_csv('data/clusters/pca_pc{}_bottom_me2_and.txt'.format(x + 1), 
                        sep='\t', header=True, index=False)
    data.loc[top].to_csv('data/clusters/pca_pc{}_top_me2_and.txt'.format(x + 1), 
                        sep='\t', header=True, index=False)
