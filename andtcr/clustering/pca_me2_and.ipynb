# %%
'''
Use PCA to evaluate the axes of variation across our five conditions.
'''
# Out:
# '\nUse PCA to evaluate the axes of variation across our five conditions.\n'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA

# %%
sns.set_context('poster')

# %%
data = pd.io.parsers.read_csv('../clustering/data/me2_and/enhancers_me2_and_union.txt', 
                                    sep='\t', 
                                    header=0)

data = data.fillna(0)

# %%
peptides = ['no_peptide', '10um_k99a', '100um_k99a', '0_1um_pcc', '10um_pcc']
prefix = 'tag_count_'
fields = [prefix + p for p in peptides]

# %%
# Extract fields of interest and normalize to unit norm row-wise
subdata = data[fields].div(data[fields].max(axis=1), axis=0)
subdata.head()
# Out:
#    tag_count_no_peptide  tag_count_10um_k99a  tag_count_100um_k99a  \
# 0                     1             0.908188              0.425493
# 1                     1             0.841617              0.583827
# 2                     1             0.813989              0.027501
# 3                     1             0.151818              0.022959
# 4                     1             0.942992              0.734261
#
#    tag_count_0_1um_pcc  tag_count_10um_pcc
# 0             0.885996            0.449848
# 1             0.786752            0.568151
# 2             0.873755            0.612928
# 3             0.423926            0.085686
# 4             0.959039            0.703288

# %%
# Filter out genes that aren't changing.
def check_changing(row):
    if row.max() - row.min() < row.min():
        return False
    return True
filtered = subdata[subdata.apply(check_changing, axis=1)]
print(len(filtered), len(subdata))
filtered.head()
# Out:
# 30985 35556
#    tag_count_no_peptide  tag_count_10um_k99a  tag_count_100um_k99a  \
# 0                     1             0.908188              0.425493
# 2                     1             0.813989              0.027501
# 3                     1             0.151818              0.022959
# 6                     1             0.713919              0.233919
# 7                     1             0.268455              0.157178
#
#    tag_count_0_1um_pcc  tag_count_10um_pcc
# 0             0.885996            0.449848
# 2             0.873755            0.612928
# 3             0.423926            0.085686
# 6             0.645000            0.035946
# 7             0.306184            0.161264

# %%
transpose = subdata.transpose()
pca = PCA(n_components=5)
X_r = pca.fit(transpose).transform(transpose)
print('Explained variance ratio (first five components): '
      + str(pca.explained_variance_ratio_))
X_r
# Out:
# Explained variance ratio (first five components): [  2.90309635e-01   2.53695274e-01   2.34206253e-01   2.21788838e-01
#    6.10180216e-27]
# array([[ -4.07242458e+01,   3.17517085e+01,  -2.93446619e+01,
#           3.61065541e+01,   3.53853630e-12],
#        [ -2.29007023e+01,   1.85432170e+01,   5.24593710e+00,
#          -5.94996618e+01,  -1.03104686e-11],
#        [  2.83068623e+01,   2.18593653e+01,   5.46903233e+01,
#           2.01294516e+01,   9.43897407e-12],
#        [ -2.34177163e+01,  -6.49635861e+01,   1.00566960e+01,
#           7.95665161e+00,   9.12635004e-12],
#        [  5.87358021e+01,  -7.19070464e+00,  -4.06482945e+01,
#          -4.69299555e+00,  -1.17932339e-11]])

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_r[:, 0].tolist(), X_r[:, 1].tolist(), X_r[:, 2].tolist(), s=100)
plt.title('PCA: H3K4me2 by Condition')
plt.xlabel('PC1 (29% of variance)')
plt.ylabel('PC2 (25% of variance)')
ax.set_zlabel('PC3 (23% of variance)')

margin = 2
for i, txt in enumerate(peptides):
    ax.text(X_r[i,0] + margin, 
            X_r[i,1] + margin, 
            X_r[i,2] + margin,
            txt, size=13)

plt.savefig('figures/PCA_H3K4me2_by_Condition_3D.png',
            bbox_inches='tight')

# %%
fig = plt.figure()
plt.scatter(X_r[:, 0].tolist(), X_r[:, 1].tolist(), s=100)
plt.title('PCA: H3K4me2 by Condition')
plt.xlabel('PC1 (29% of variance)')
plt.ylabel('PC2 (25% of variance)')

margin = 2
for i, txt in enumerate(peptides):
    plt.annotate(txt, (X_r[i,0] + margin, 
            X_r[i,1] + margin),
            size=13)

plt.savefig('figures/PCA_H3K4me2_by_Condition.png',
            bbox_inches='tight')

plt.axhline(color='black', linewidth=1)
plt.axvline(color='black', linewidth=1)
plt.savefig('figures/PCA_H3K4me2_by_Condition_axes.png',
            bbox_inches='tight')

# %%
pd.DataFrame(pca.transform(transpose), index=fields)
# Out:
#                               0          1          2          3             4
# tag_count_no_peptide -40.724246  31.751708 -29.344662  36.106554  3.538536e-12
# tag_count_10um_k99a  -22.900702  18.543217   5.245937 -59.499662 -1.031047e-11
# tag_count_100um_k99a  28.306862  21.859365  54.690323  20.129452  9.438974e-12
# tag_count_0_1um_pcc  -23.417716 -64.963586  10.056696   7.956652  9.126350e-12
# tag_count_10um_pcc    58.735802  -7.190705 -40.648294  -4.692996 -1.179323e-11

# %%
# We want to get the top and bottom features that make up each component.
components = pd.DataFrame(pca.components_)
for x in range(0,4):
    pc = components.loc[x]
    pc.sort()
    num_elem = len(pc)
    bottom_quartile = pc.index[:num_elem//4]
    top_quartile = pc.index[3*num_elem//4:]
    
    data.loc[bottom_quartile].to_csv('data/clusters/pca_pc{}_bottom_me2_and.txt'.format(x + 1), 
                        sep='\t', header=True, index=False)
    data.loc[top_quartile].to_csv('data/clusters/pca_pc{}_top_me2_and.txt'.format(x + 1), 
                        sep='\t', header=True, index=False)
