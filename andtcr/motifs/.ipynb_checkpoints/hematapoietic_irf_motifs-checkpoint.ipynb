# %%
'''
Create plot of previously generated IRF motif frequencies.

# Some unix magic for space-separated file of motifs.

pwd
 >> ~/AND_analysis/ChIP_bk/Sets1_2/IRF_motifs/known_motif_finding 
head -n 1 3T3L1-H3K4me1-7d_IRF2/knownResults.txt > hematapoietic_irf2.txt 
for f in *IRF2/knownResults.txt; 
do 
FNAME="${f} "; 
FNAME+=`tail -n 1 $f`; 
echo $FNAME | tr ' ' '\t' >> hematapoietic_irf2.txt; 
done

'''
# Out:
# '\nCreate plot of previously generated IRF motif frequencies.\n\n# Some unix magic for space-separated file of motifs.\n\npwd\n >> ~/AND_analysis/ChIP_bk/Sets1_2/IRF_motifs/known_motif_finding \nhead -n 1 3T3L1-H3K4me1-7d_IRF2/knownResults.txt > hematapoietic_irf2.txt \nfor f in *IRF2/knownResults.txt; \ndo \nFNAME="${f} "; \nFNAME+=`tail -n 1 $f`; \necho $FNAME | tr \' \' \'\t\' >> hematapoietic_irf2.txt; \ndone\n\n'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_context('poster')

# %%
motifs = ['IRF2(IRF)/Erythroblas-IRF2-ChIP-Seq(GSE36985)/Homer',
          ]
names = ['IRF',]

# %%
results = pd.io.parsers.read_csv('data/irf_motifs/hematapoietic_irf2.txt',
                sep='\t', 
                header=0)
print(results.columns)
results.head()
# Out:
# Index(['Motif Name', 'Consensus', 'P-value', 'Log P-value', 'q-value (Benjamini)', '# of Target Sequences with Motif(of 76881)', '% of Target Sequences with Motif', '# of Background Sequences with Motif(of 77204)', '% of Background Sequences with Motif'], dtype='object')
#                                                                                       Motif Name  \
# 3T3L1-H3K4me1-7d_IRF2/knownResults.txt         IRF2(IRF)/Erythroblas-IRF2-ChIP-Seq(GSE36985)/...
# CD4TCell-Th1-H3K4me1_IRF2/knownResults.txt     IRF2(IRF)/Erythroblas-IRF2-ChIP-Seq(GSE36985)/...
# CD4TCell-Th2-H3K4me1_IRF2/knownResults.txt     IRF2(IRF)/Erythroblas-IRF2-ChIP-Seq(GSE36985)/...
# ESC-H3K4me1-1_IRF2/knownResults.txt            IRF2(IRF)/Erythroblas-IRF2-ChIP-Seq(GSE36985)/...
# Fetal-Liver-DN1-H3K4me2_IRF2/knownResults.txt  IRF2(IRF)/Erythroblas-IRF2-ChIP-Seq(GSE36985)/...
#
#                                                   Consensus        P-value  \
# 3T3L1-H3K4me1-7d_IRF2/knownResults.txt         GAAASYGAAASY   1.000000e-05
# CD4TCell-Th1-H3K4me1_IRF2/knownResults.txt     GAAASYGAAASY  1.000000e-106
# CD4TCell-Th2-H3K4me1_IRF2/knownResults.txt     GAAASYGAAASY   1.000000e-08
# ESC-H3K4me1-1_IRF2/knownResults.txt            GAAASYGAAASY   1.000000e+00
# Fetal-Liver-DN1-H3K4me2_IRF2/knownResults.txt  GAAASYGAAASY  1.000000e-156
#
#                                                Log P-value  \
# 3T3L1-H3K4me1-7d_IRF2/knownResults.txt          -11.800000
# CD4TCell-Th1-H3K4me1_IRF2/knownResults.txt     -245.900000
# CD4TCell-Th2-H3K4me1_IRF2/knownResults.txt      -19.860000
# ESC-H3K4me1-1_IRF2/knownResults.txt              -0.000785
# Fetal-Liver-DN1-H3K4me2_IRF2/knownResults.txt  -359.300000
#
#                                                q-value (Benjamini)  \
# 3T3L1-H3K4me1-7d_IRF2/knownResults.txt                      0.0000
# CD4TCell-Th1-H3K4me1_IRF2/knownResults.txt                  0.0000
# CD4TCell-Th2-H3K4me1_IRF2/knownResults.txt                  0.0000
# ESC-H3K4me1-1_IRF2/knownResults.txt                         0.9992
# Fetal-Liver-DN1-H3K4me2_IRF2/knownResults.txt               0.0000
#
#                                                # of Target Sequences with Motif(of 76881)  \
# 3T3L1-H3K4me1-7d_IRF2/knownResults.txt                                                838
# CD4TCell-Th1-H3K4me1_IRF2/knownResults.txt                                           1051
# CD4TCell-Th2-H3K4me1_IRF2/knownResults.txt                                            293
# ESC-H3K4me1-1_IRF2/knownResults.txt                                                   599
# Fetal-Liver-DN1-H3K4me2_IRF2/knownResults.txt                                        1105
#
#                                               % of Target Sequences with Motif  \
# 3T3L1-H3K4me1-7d_IRF2/knownResults.txt                                   1.09%
# CD4TCell-Th1-H3K4me1_IRF2/knownResults.txt                               2.16%
# CD4TCell-Th2-H3K4me1_IRF2/knownResults.txt                               1.23%
# ESC-H3K4me1-1_IRF2/knownResults.txt                                      0.84%
# Fetal-Liver-DN1-H3K4me2_IRF2/knownResults.txt                            2.45%
#
#                                                # of Background Sequences with Motif(of 77204)  \
# 3T3L1-H3K4me1-7d_IRF2/knownResults.txt                                                  718.0
# CD4TCell-Th1-H3K4me1_IRF2/knownResults.txt                                              482.5
# CD4TCell-Th2-H3K4me1_IRF2/knownResults.txt                                              224.9
# ESC-H3K4me1-1_IRF2/knownResults.txt                                                     672.2
# Fetal-Liver-DN1-H3K4me2_IRF2/knownResults.txt                                           428.0
#
#                                               % of Background Sequences with Motif
# 3T3L1-H3K4me1-7d_IRF2/knownResults.txt                                       0.93%
# CD4TCell-Th1-H3K4me1_IRF2/knownResults.txt                                   1.01%
# CD4TCell-Th2-H3K4me1_IRF2/knownResults.txt                                   0.86%
# ESC-H3K4me1-1_IRF2/knownResults.txt                                          0.96%
# Fetal-Liver-DN1-H3K4me2_IRF2/knownResults.txt                                0.98%

# %%
cells = ['3T3L1', 'Th1', 'Th2', 'ESC', 'DN1', 'DN2a', 
         'DN2b', 'LSK', 'Stat1KO Th1', 'DP', 'ThioMac', 'DN3']
cells_ordered = ['ESC', 'LSK', 'DN1', 'DN2a', 'DN2b', 'DN3',
                 'DP', 'Th1', 'Th2', 'Stat1KO Th1', 'ThioMac', '3T3L1'][::-1]
results.index = cells
data = results.loc[cells_ordered]
data.head()
# Out:
#                                                     Motif Name     Consensus  \
# 3T3L1        IRF2(IRF)/Erythroblas-IRF2-ChIP-Seq(GSE36985)/...  GAAASYGAAASY
# ThioMac      IRF2(IRF)/Erythroblas-IRF2-ChIP-Seq(GSE36985)/...  GAAASYGAAASY
# Stat1KO Th1  IRF2(IRF)/Erythroblas-IRF2-ChIP-Seq(GSE36985)/...  GAAASYGAAASY
# Th2          IRF2(IRF)/Erythroblas-IRF2-ChIP-Seq(GSE36985)/...  GAAASYGAAASY
# Th1          IRF2(IRF)/Erythroblas-IRF2-ChIP-Seq(GSE36985)/...  GAAASYGAAASY
#
#                    P-value  Log P-value  q-value (Benjamini)  \
# 3T3L1         1.000000e-05       -11.80                    0
# ThioMac       1.000000e-37       -85.95                    0
# Stat1KO Th1   1.000000e-59      -138.00                    0
# Th2           1.000000e-08       -19.86                    0
# Th1          1.000000e-106      -245.90                    0
#
#              # of Target Sequences with Motif(of 76881)  \
# 3T3L1                                               838
# ThioMac                                             828
# Stat1KO Th1                                        1260
# Th2                                                 293
# Th1                                                1051
#
#             % of Target Sequences with Motif  \
# 3T3L1                                  1.09%
# ThioMac                                1.48%
# Stat1KO Th1                            1.74%
# Th2                                    1.23%
# Th1                                    2.16%
#
#              # of Background Sequences with Motif(of 77204)  \
# 3T3L1                                                 718.0
# ThioMac                                               511.4
# Stat1KO Th1                                           750.9
# Th2                                                   224.9
# Th1                                                   482.5
#
#             % of Background Sequences with Motif
# 3T3L1                                      0.93%
# ThioMac                                    0.92%
# Stat1KO Th1                                1.06%
# Th2                                        0.86%
# Th1                                        1.01%

# %%
target_f  = [float(s) for s in data['% of Target Sequences with Motif'].str.replace('%','')]
bg_f  = [float(s) for s in data['% of Background Sequences with Motif'].str.replace('%','')]
target_diff = [target_f[i] - bg_f[i] for i in range(len(target_f))]
target_f
# Out:
# [1.09, 1.48, 1.74, 1.23, 2.16, 2.27, 2.5, 2.76, 2.49, 2.45, 1.54, 0.84]

# %%
colorset = sns.color_palette('BuGn_d', len(results))
plt.figure()

width = .8
bg_base = [max(bg_f)]*len(data)
plt.barh(range(0,len(data)), bg_base, 
         width, color='#CCCCCC')
plt.barh(range(0,len(data)), target_diff, width, left=bg_base, color=colorset)
plt.title(names[0] + ' motif frequency across hematopoietic cells', fontweight='bold')
plt.yticks([x + width/2 for x in range(0,len(data))], data.index)
plt.xlabel('Percent of H3K4me1/2 peaks with motif')
plt.ylim([-.2, len(data)])

plt.savefig('figures/{}.png'.format(title), bbox_inches='tight')
