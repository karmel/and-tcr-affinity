# %%
'''
GSE2924: Immunodominance of CD8 T cells.
H7a is high affinity, HY is low affinity, plus no treatment.
'''
# Out:
# '\nGSE2924: Immunodominance of CD8 T cells.\nH7a is high affinity, HY is low affinity, plus no treatment.\n'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_context('poster')

# %%
gse = 'GSE2924'
fname = 'data/{}_series_matrix.txt'.format(gse.lower())
data = pd.io.parsers.read_csv(fname, 
                sep='\t', header=0, index_col=0,
                comment='!')
data = data.fillna(0)
data.head()
# Out:
#               GSM62876  GSM62977  GSM62978  GSM62979  GSM62980  GSM62981  \
# ID_REF
# 1415670_at       394.4     171.7     274.6     260.0     199.6     248.8
# 1415671_at       211.7     208.2     176.3     210.2     169.5     224.4
# 1415672_at       328.6     957.8    1267.8     373.5    1326.4    1275.6
# 1415673_at       321.0     163.2     119.8     260.3     238.7     261.8
# 1415674_a_at      48.9     107.2      88.1     103.5     205.7     162.6
#
#               GSM62982  GSM62983  GSM62984  GSM62985  GSM62986  GSM62987  \
# ID_REF
# 1415670_at       409.4     159.1     386.9     307.8     333.3     279.5
# 1415671_at       141.2      82.4     158.9     179.7     187.2     253.9
# 1415672_at      1589.9    1407.1    1623.3    2122.6    1180.4    1386.3
# 1415673_at       163.8     240.1       9.4     162.7     192.5      91.6
# 1415674_a_at     274.5      98.2     211.1     139.5     243.2     227.5
#
#               GSM62988
# ID_REF
# 1415670_at       321.4
# 1415671_at       170.4
# 1415672_at      2307.3
# 1415673_at       125.4
# 1415674_a_at     113.4

# %%
# Get sample names
for line in open(fname).readlines():
    if line.startswith('!Sample_title'):
        headers = line.split('\t')[1:]
    elif line.startswith('!Series_platform_id'):
        platform = line.split('\t')[1].strip().strip('"')
    elif line.startswith('!series_matrix_table_begin'):
        break
headers = [h.strip().strip('"') for h in headers]
print(platform)
headers
# Out:
# GPL1261
# ['CD8+H7aTet+_04',
#  'CD8+Tet-_04',
#  'CD8+Tet-_02',
#  'CD8+Tet-_03',
#  'CD8+Tet-_01',
#  'CD8+Tet-_05',
#  'CD8+HYTet+_01',
#  'CD8+HYTet+_02',
#  'CD8+HYTet+_03',
#  'CD8+HYTet+_04',
#  'CD8+H7aTet+_01',
#  'CD8+H7aTet+_02',
#  'CD8+H7aTet+_03']

# %%
high, low, notx = [], [], []
for header in headers:
    if 'H7a' in header: high.append(header)
    elif 'HY' in header: low.append(header)
    else: notx.append(header)

# %%
# Rename our columns
data.columns = headers
data.head()
# Out:
#               CD8+H7aTet+_04  CD8+Tet-_04  CD8+Tet-_02  CD8+Tet-_03  \
# ID_REF
# 1415670_at             394.4        171.7        274.6        260.0
# 1415671_at             211.7        208.2        176.3        210.2
# 1415672_at             328.6        957.8       1267.8        373.5
# 1415673_at             321.0        163.2        119.8        260.3
# 1415674_a_at            48.9        107.2         88.1        103.5
#
#               CD8+Tet-_01  CD8+Tet-_05  CD8+HYTet+_01  CD8+HYTet+_02  \
# ID_REF
# 1415670_at          199.6        248.8          409.4          159.1
# 1415671_at          169.5        224.4          141.2           82.4
# 1415672_at         1326.4       1275.6         1589.9         1407.1
# 1415673_at          238.7        261.8          163.8          240.1
# 1415674_a_at        205.7        162.6          274.5           98.2
#
#               CD8+HYTet+_03  CD8+HYTet+_04  CD8+H7aTet+_01  CD8+H7aTet+_02  \
# ID_REF
# 1415670_at            386.9          307.8           333.3           279.5
# 1415671_at            158.9          179.7           187.2           253.9
# 1415672_at           1623.3         2122.6          1180.4          1386.3
# 1415673_at              9.4          162.7           192.5            91.6
# 1415674_a_at          211.1          139.5           243.2           227.5
#
#               CD8+H7aTet+_03
# ID_REF
# 1415670_at             321.4
# 1415671_at             170.4
# 1415672_at            2307.3
# 1415673_at             125.4
# 1415674_a_at           113.4

# %%
# Get gene names
# Ugh. Platform file has three different comment chars in the
# header lines. Hardcode header for now...
fname = 'data/{}.txt'.format(platform)
probes = pd.io.parsers.read_csv(fname, 
                sep='\t', header=18, index_col=0)
probes.head()
# Out:
# /Applications/anaconda/lib/python3.4/site-packages/pandas/io/parsers.py:1154: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)
#                  GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# ID
# 1415670_at     BC024686     NaN            Mus musculus     Jun 9, 2011
# 1415671_at    NM_013477     NaN            Mus musculus     Jun 9, 2011
# 1415672_at    NM_020585     NaN            Mus musculus     Jun 9, 2011
# 1415673_at    NM_133900     NaN            Mus musculus     Jun 9, 2011
# 1415674_a_at  NM_021789     NaN            Mus musculus     Jun 9, 2011
#
#                    Sequence Type Sequence Source  \
# ID
# 1415670_at    Consensus sequence         GenBank
# 1415671_at    Consensus sequence         GenBank
# 1415672_at    Consensus sequence         GenBank
# 1415673_at    Consensus sequence         GenBank
# 1415674_a_at  Consensus sequence         GenBank
#
#                                              Target Description  \
# ID
# 1415670_at    gb:BC024686.1 /DB_XREF=gi:19354080 /FEA=FLmRNA...
# 1415671_at    gb:NM_013477.1 /DB_XREF=gi:7304908 /GEN=Atp6v0...
# 1415672_at    gb:NM_020585.1 /DB_XREF=gi:10181207 /GEN=AB041...
# 1415673_at    gb:NM_133900.1 /DB_XREF=gi:19527115 /GEN=AI480...
# 1415674_a_at  gb:NM_021789.1 /DB_XREF=gi:11140824 /GEN=Sbdn ...
#
#              Representative Public ID  \
# ID
# 1415670_at                   BC024686
# 1415671_at                  NM_013477
# 1415672_at                  NM_020585
# 1415673_at                  NM_133900
# 1415674_a_at                NM_021789
#
#                                                     Gene Title Gene Symbol  \
# ID
# 1415670_at             coatomer protein complex, subunit gamma        Copg
# 1415671_at    ATPase, H+ transporting, lysosomal V0 subunit D1    Atp6v0d1
# 1415672_at            golgi autoantigen, golgin subfamily a, 7      Golga7
# 1415673_at                           phosphoserine phosphatase        Psph
# 1415674_a_at            trafficking protein particle complex 4     Trappc4
#
#              ENTREZ_GENE_ID        RefSeq Transcript ID  \
# ID
# 1415670_at            54161     NM_017477 /// NM_201244
# 1415671_at            11972                   NM_013477
# 1415672_at            57437  NM_001042484 /// NM_020585
# 1415673_at           100678                   NM_133900
# 1415674_a_at          60409                   NM_021789
#
#                                Gene Ontology Biological Process  \
# ID
# 1415670_at    0006810 // transport // inferred from electron...
# 1415671_at    0006810 // transport // inferred from electron...
# 1415672_at    0006893 // Golgi to plasma membrane transport ...
# 1415673_at    0006563 // L-serine metabolic process // infer...
# 1415674_a_at  0006810 // transport // inferred from electron...
#
#                                Gene Ontology Cellular Component  \
# ID
# 1415670_at    0000139 // Golgi membrane // inferred from ele...
# 1415671_at    0005769 // early endosome // inferred from dir...
# 1415672_at    0000139 // Golgi membrane // not recorded /// ...
# 1415673_at    0005737 // cytoplasm // inferred from sequence...
# 1415674_a_at  0005783 // endoplasmic reticulum // inferred f...
#
#                                Gene Ontology Molecular Function
# ID
# 1415670_at    0005198 // structural molecule activity // inf...
# 1415671_at    0005515 // protein binding // inferred from el...
# 1415672_at                                                  NaN
# 1415673_at    0000287 // magnesium ion binding // inferred f...
# 1415674_a_at  0005515 // protein binding // inferred from el...

# %%
genes_of_interest = ['Cd83', 'Gata3', 'Ikzf2', 'Kit',
                     'Gpr183', 'Lad1', 'Tnfsf8', 
                     'Ccl4', 'Cd5', 'Rgs16', 'Nr4a2']

for gene in genes_of_interest:
    probe_set = probes[probes['Gene Symbol'] == gene].index
    
    # Get rows for probes of interest.
    gene_data = data.loc[probe_set]
    
    # Pick the row with the highest mean intensity
    mean_intensity = gene_data.mean(axis=1)
    mean_intensity.sort(ascending=False)
    
    probe_data = gene_data.loc[mean_intensity.index[0]]
    # Reorder columns
    probe_groups = [probe_data[notx], probe_data[low], probe_data[high]]
    
    plt.figure()
    plt.boxplot(probe_groups)

    
    plt.ylabel('Probe Intensity')
    labels = ['Notx (CD8)', 'Low affinity (CD8 + HY)', 'High affinity (CD8 + H7a)'])
    plt.xticks(range(1,len(labels)+1),
               labels)

    title = '{}- Immunodominance in CD8 T cell responses- {}'.format(gse,gene)
    plt.title(title)

    plt.savefig('figures/{}.png'.format(title.replace(' ','_')),
                bbox_inches='tight')
