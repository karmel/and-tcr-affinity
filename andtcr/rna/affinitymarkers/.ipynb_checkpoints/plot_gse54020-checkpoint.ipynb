# %%
'''
GSE54020: High and low avidity cancer-specific CD8 T cells
'''
# Out:
# '\nGSE54020: High and low avidity cancer-specific CD8 T cells\n'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_context('poster')

# %%
gse = 'GSE54020'
fname = 'data/{}_series_matrix.txt'.format(gse)
data = pd.io.parsers.read_csv(fname, 
                sep='\t', header=0, index_col=0,
                comment='!')
data = data.fillna(0)
data.head()
# Out:
#          GSM1305941  GSM1305942  GSM1305943  GSM1305944  GSM1305945  \
# ID_REF
# 6747201     3.25411     3.43084     3.63311     3.76979     3.50002
# 6747202     3.56929     3.50025     3.57232     3.31018     3.70692
# 6747206     3.68740     3.51507     3.86297     3.69956     3.52258
# 6747207     4.45786     4.14298     4.65267     4.67280     4.56073
# 6747211    12.03510    11.42800    11.29980    11.88110    11.42400
#
#          GSM1305946  GSM1305947
# ID_REF
# 6747201     3.69805     3.55174
# 6747202     3.33988     3.16107
# 6747206     3.82349     3.43207
# 6747207     4.20657     4.72764
# 6747211    11.60200    11.48150

# %%
# Get sample names
for line in open(fname).readlines():
    if line.startswith('!Sample_title'):
        headers = line.split('\t')[1:]
    elif line.startswith('!Series_platform_id'):
        platform = line.split('\t')[1].strip().strip('"')
    elif line.startswith('!series_matrix_table_begin'):
        break
headers = [h.strip().strip('"') for h in headers]
print(platform)
headers
# Out:
# GPL6096
# ['High avidity T cells 1',
#  'High avidity T cells 2',
#  'High avidity T cells 3',
#  'Low avidity T cells 1',
#  'Low avidity T cells 2',
#  'Low avidity T cells 3',
#  'Low avidity T cells 4']

# %%
high, low = [], []
for header in headers:
    if 'High' in header: high.append(header)
    elif 'Low' in header: low.append(header)

# %%
# Rename our columns
data.columns = headers
data.head()
# Out:
#          High avidity T cells 1  High avidity T cells 2  \
# ID_REF
# 6747201                 3.25411                 3.43084
# 6747202                 3.56929                 3.50025
# 6747206                 3.68740                 3.51507
# 6747207                 4.45786                 4.14298
# 6747211                12.03510                11.42800
#
#          High avidity T cells 3  Low avidity T cells 1  Low avidity T cells 2  \
# ID_REF
# 6747201                 3.63311                3.76979                3.50002
# 6747202                 3.57232                3.31018                3.70692
# 6747206                 3.86297                3.69956                3.52258
# 6747207                 4.65267                4.67280                4.56073
# 6747211                11.29980               11.88110               11.42400
#
#          Low avidity T cells 3  Low avidity T cells 4
# ID_REF
# 6747201                3.69805                3.55174
# 6747202                3.33988                3.16107
# 6747206                3.82349                3.43207
# 6747207                4.20657                4.72764
# 6747211               11.60200               11.48150

# %%
# Get gene names
# Ugh. Platform file has three different comment chars in the
# header lines. Hardcode header for now...
fname = 'data/{}.txt'.format(platform)
probes = pd.io.parsers.read_csv(fname, 
                sep='\t', header=14, index_col=0)
probes = probes.fillna('')
probes.head()
# Out:
#                    GB_LIST               SPOT_ID seqname     RANGE_GB  \
# ID
# 6747200                     chr1:3018698-3044814    chr1  NC_000067.5
# 6747201  AK143492,AK149257  chr1:3048143-3048338    chr1  NC_000067.5
# 6747202           AK016604  chr1:3063355-3063577    chr1  NC_000067.5
# 6747203           AK016604  chr1:3063748-3063805    chr1  NC_000067.5
# 6747204                     chr1:3064259-3064287    chr1  NC_000067.5
#
#         RANGE_STRAND RANGE_START RANGE_STOP total_probes  \
# ID
# 6747200            +     3018698    3044814           12
# 6747201            +     3048143    3048338            4
# 6747202            +     3063355    3063577            4
# 6747203            +     3063748    3063805            4
# 6747204            +     3064259    3064287            2
#
#                                            gene_assignment  \
# ID
# 6747200                                                ---
# 6747201                                                ---
# 6747202  AK016604 // 4933401J01Rik // RIKEN cDNA 493340...
# 6747203  AK016604 // 4933401J01Rik // RIKEN cDNA 493340...
# 6747204                                                ---
#
#                                            mrna_assignment category
# ID
# 6747200  GENSCAN00000037374 // ENSEMBL // cdna:Genscan ...     main
# 6747201  AK143492 // GenBank HTC // Mus musculus 8 cell...     main
# 6747202  AK016604 // GenBank HTC // Mus musculus adult ...     main
# 6747203  AK016604 // GenBank HTC // Mus musculus adult ...     main
# 6747204                                                ---     main

# %%
genes_of_interest = ['Cd83', 'Gata3', 'Ikzf2', 'Kit',
                     'Gpr183', 'Lad1', 'Tnfsf8', 
                     'Ccl4', 'Cd5', 'Rgs16', 'Nr4a2']
for gene in genes_of_interest:
    probe_set = probes[probes['gene_assignment'].str.contains(gene)].index
    
    # Get rows for probes of interest.
    gene_data = data.loc[probe_set]
    
    # Pick the row with the highest mean intensity
    mean_intensity = gene_data.mean(axis=1)
    mean_intensity.sort(ascending=False)
    
    probe_data = gene_data.loc[mean_intensity.index[0]]
    # Reorder columns
    probe_groups = [probe_data[low], probe_data[high]]
    
    plt.figure()
    plt.boxplot(probe_groups)

    
    plt.ylabel('Probe Intensity')
    
    labels = ['Low avidity (Tumor-specific CD8s)', 'High avidity (Tumor-specific CD8s)']
    plt.xticks(range(1,len(labels)+1),
               labels)

    title = '{}- High versus low avidity tumor-specific CD8 T cells- {}'.format(gse, gene)
    plt.title(title)

    plt.savefig('figures/{}.png'.format(title.replace(' ','_')),
                bbox_inches='tight')
