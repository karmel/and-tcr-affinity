# %%
'''
We have a set of ~300 genes with names and scores.

Given a microarray .txt file, normalize, extract the genes of interest,
and determine score.
'''
# Out:
# '\nWe have a set of ~300 genes with names and scores.\n\nGiven a microarray .txt file, normalize, extract the genes of interest,\nand determine score.\n'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import subprocess
import numpy as np

# %%
sns.set_context('poster')

# %%
gse = 'GSE60337'
fname = 'data/{}_series_matrix.txt'.format(gse)

# Comment lines begin with a variety of characters. Figure out where to start manually.
start_at = 0
for i, line in enumerate(open(fname).readlines()):
    if line.startswith('!Sample_title'):
        headers = line.split('\t')[1:]
    elif line.startswith('!Series_platform_id'):
        platform = line.split('\t')[1].strip().strip('"')
    elif line[0] not in ('!', '#', '^', '\n'):
        start_at = i
        break
data = pd.io.parsers.read_csv(fname, 
                sep='\t', header=start_at-1, index_col=0)
data = data.fillna(0)
headers = [h.strip().strip('"').replace(' ','_').replace(',','') for h in headers]
print(platform)
print(headers)
data.head()
# Out:
# GPL6246
# ['T4.129#1', 'T4.129#2', 'T4.AJ#1', 'T4.AJ#2', 'T4.AKR#1', 'T4.AKR#2', 'T4.B10#1', 'T4.B10#3', 'T4.B6#1', 'T4.B6#2', 'T4.B6#3', 'T4.B6#4', 'T4.B6#5', 'T4.BPL#1', 'T4.BPL#2', 'T4.BTBR#1', 'T4.BTBR#2', 'T4.Balb#1', 'T4.Balb#2', 'T4.C3H#1', 'T4.C3H#2', 'T4.C57BR#1', 'T4.C57BR#2', 'T4.C57KS#1', 'T4.C57KS#2', 'T4.C57L#1', 'T4.C57L#2', 'T4.CAS#2', 'T4.CAS#3', 'T4.CBACA#1', 'T4.CBACA#2', 'T4.CBAJ#1', 'T4.CBAJ#2', 'T4.CE#1', 'T4.CE#2', 'T4.DBA2#1', 'T4.DBA2#2', 'T4.DDY#1', 'T4.DDY#2', 'T4.FVB#1', 'T4.FVB#2', 'T4.JF1Ms#1', 'T4.JF1Ms#2', 'T4.KK#1', 'T4.KK#2', 'T4.LG#1', 'T4.LG#2', 'T4.LP#1', 'T4.LP#2', 'T4.MA#1', 'T4.MA#2', 'T4.MRL#1', 'T4.MRL#2', 'T4.MSM#1', 'T4.MSM#2', 'T4.NOD#1', 'T4.NOD#2', 'T4.NON#1', 'T4.NON#2', 'T4.NOR#1', 'T4.NOR#2', 'T4.NZB#1', 'T4.NZB#2', 'T4.NZW#1', 'T4.NZW#2', 'T4.P#1', 'T4.P#2', 'T4.PL#1', 'T4.PL#2', 'T4.PWD#1', 'T4.PWD#2', 'T4.RIII#1', 'T4.RIII#2', 'T4.SEA#1', 'T4.SEA#2', 'T4.SJL#1', 'T4.SJL#2', 'T4.SM#1', 'T4.SM#2', 'T4.SWR#1', 'T4.WSB#1', 'T4.WSB#2']
# /Applications/anaconda/lib/python3.4/site-packages/pandas/io/parsers.py:1154: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)
#           GSM1472000  GSM1472001  GSM1472002  GSM1472003  GSM1472004  \
# ID_REF
# 10344620     20.1717     22.3287     22.4646     24.4083     24.2962
# 10344622    207.7495    214.1281    216.3114    256.2096    221.3736
# 10344624    975.3835   1094.4586   1147.3980   1758.5033   1041.9389
# 10344633    763.2650    916.3283    813.2552   1062.5045    797.4313
# 10344637    379.6801    420.8961    316.9711    537.2289    378.4611
#
#           GSM1472005  GSM1472006  GSM1472007  GSM1472008  GSM1472009  \
# ID_REF
# 10344620     25.0382     27.2014     23.2352     22.9827     22.6995
# 10344622    292.8199    236.3997    219.6098    241.0234    211.1897
# 10344624   1054.8665   1106.9478   1075.5465   1419.1045   1159.1558
# 10344633    730.4834    789.8505    969.3024    913.6694    846.0762
# 10344637    375.0992    387.1061    302.0949    388.2560    434.1414
#
#              ...      GSM1472072  GSM1472073  GSM1472074  GSM1472075  \
# ID_REF       ...
# 10344620     ...         31.1694     24.2739     23.3382     25.8730
# 10344622     ...        396.5335    208.1275    237.4557    295.4072
# 10344624     ...        878.4766   1119.0867   1160.2022   1113.9808
# 10344633     ...        802.7615    785.5682    802.4744    874.6055
# 10344637     ...        322.5035    496.9713    481.6293    438.4020
#
#           GSM1472076  GSM1472077  GSM1472078  GSM1472079  GSM1472080  \
# ID_REF
# 10344620     25.9467     23.9986     25.6940     28.4083     27.7806
# 10344622    202.8816    185.0017    174.8460    185.0209    236.4680
# 10344624   1051.3983   1085.7975   1014.0615   1081.8170   1340.4752
# 10344633    886.5030    851.4190    833.0256    781.8594    634.7469
# 10344637    410.6427    450.5723    358.5221    495.4127    428.6244
#
#           GSM1472081
# ID_REF
# 10344620     27.4788
# 10344622    254.9747
# 10344624   1117.9710
# 10344633    712.6443
# 10344637    350.1117
#
# [5 rows x 82 columns]

# %%
headers_ordered = headers

# %%
# Rename our columns
data.columns = headers
data.head()
# Out:
#           T4.129#1   T4.129#2    T4.AJ#1    T4.AJ#2   T4.AKR#1   T4.AKR#2  \
# ID_REF
# 10344620   20.1717    22.3287    22.4646    24.4083    24.2962    25.0382
# 10344622  207.7495   214.1281   216.3114   256.2096   221.3736   292.8199
# 10344624  975.3835  1094.4586  1147.3980  1758.5033  1041.9389  1054.8665
# 10344633  763.2650   916.3283   813.2552  1062.5045   797.4313   730.4834
# 10344637  379.6801   420.8961   316.9711   537.2289   378.4611   375.0992
#
#            T4.B10#1   T4.B10#3    T4.B6#1    T4.B6#2    ...      T4.RIII#2  \
# ID_REF                                                  ...
# 10344620    27.2014    23.2352    22.9827    22.6995    ...        31.1694
# 10344622   236.3997   219.6098   241.0234   211.1897    ...       396.5335
# 10344624  1106.9478  1075.5465  1419.1045  1159.1558    ...       878.4766
# 10344633   789.8505   969.3024   913.6694   846.0762    ...       802.7615
# 10344637   387.1061   302.0949   388.2560   434.1414    ...       322.5035
#
#            T4.SEA#1   T4.SEA#2   T4.SJL#1   T4.SJL#2    T4.SM#1    T4.SM#2  \
# ID_REF
# 10344620    24.2739    23.3382    25.8730    25.9467    23.9986    25.6940
# 10344622   208.1275   237.4557   295.4072   202.8816   185.0017   174.8460
# 10344624  1119.0867  1160.2022  1113.9808  1051.3983  1085.7975  1014.0615
# 10344633   785.5682   802.4744   874.6055   886.5030   851.4190   833.0256
# 10344637   496.9713   481.6293   438.4020   410.6427   450.5723   358.5221
#
#            T4.SWR#1   T4.WSB#1   T4.WSB#2
# ID_REF
# 10344620    28.4083    27.7806    27.4788
# 10344622   185.0209   236.4680   254.9747
# 10344624  1081.8170  1340.4752  1117.9710
# 10344633   781.8594   634.7469   712.6443
# 10344637   495.4127   428.6244   350.1117
#
# [5 rows x 82 columns]

# %%
# Get gene names
fname = 'data/{}.txt'.format(platform)
start_at = 0
for i, line in enumerate(open(fname).readlines()):
    if line[0] not in ('!', '#', '^', '\s', '\n'):
        start_at = i
        break
probes = pd.io.parsers.read_csv(fname, 
            sep='\t', header=start_at, index_col=0)
probes.head()
# Out:
#                      GB_LIST               SPOT_ID seqname     RANGE_GB  \
# ID
# 10344614                 NaN  chr1:3044314-3044814    chr1  NC_000067.5
# 10344616                 NaN  chr1:3092097-3092206    chr1  NC_000067.5
# 10344618                 NaN  chr1:3266404-3267429    chr1  NC_000067.5
# 10344620                 NaN  chr1:3670652-3670993    chr1  NC_000067.5
# 10344622  NM_024221,BC094468  chr1:4761212-4762280    chr1  NC_000067.5
#
#          RANGE_STRAND RANGE_START RANGE_STOP total_probes  \
# ID
# 10344614            +     3044314    3044814           33
# 10344616            +     3092097    3092206           25
# 10344618            +     3266404    3267429           25
# 10344620            +     3670652    3670993           25
# 10344622            +     4761212    4762280            8
#
#                                             gene_assignment  \
# ID
# 10344614                                                ---
# 10344616                                                ---
# 10344618                                                ---
# 10344620  ENSMUST00000097833 // Gm10568 // predicted gen...
# 10344622  ENSMUST00000097833 // Gm10568 // predicted gen...
#
#                                             mrna_assignment category
# ID
# 10344614  ENSMUST00000160944 // ENSEMBL // cdna:pseudoge...     main
# 10344616  ENSMUST00000082908 // ENSEMBL // ncrna:snRNA c...     main
# 10344618                                                ---      ---
# 10344620  ENSMUST00000097833 // ENSEMBL // Putative unch...     main
# 10344622  GENSCAN00000047522 // ENSEMBL // cdna:Genscan ...     main

# %%
def get_symbol(row):
    try:
        return str(row['gene_assignment']).split('//')[1].strip()
    except IndexError:
        return ''

probes['Gene symbol'] = probes.apply(get_symbol, axis=1)
probes.head()
# Out:
#                      GB_LIST               SPOT_ID seqname     RANGE_GB  \
# ID
# 10344614                 NaN  chr1:3044314-3044814    chr1  NC_000067.5
# 10344616                 NaN  chr1:3092097-3092206    chr1  NC_000067.5
# 10344618                 NaN  chr1:3266404-3267429    chr1  NC_000067.5
# 10344620                 NaN  chr1:3670652-3670993    chr1  NC_000067.5
# 10344622  NM_024221,BC094468  chr1:4761212-4762280    chr1  NC_000067.5
#
#          RANGE_STRAND RANGE_START RANGE_STOP total_probes  \
# ID
# 10344614            +     3044314    3044814           33
# 10344616            +     3092097    3092206           25
# 10344618            +     3266404    3267429           25
# 10344620            +     3670652    3670993           25
# 10344622            +     4761212    4762280            8
#
#                                             gene_assignment  \
# ID
# 10344614                                                ---
# 10344616                                                ---
# 10344618                                                ---
# 10344620  ENSMUST00000097833 // Gm10568 // predicted gen...
# 10344622  ENSMUST00000097833 // Gm10568 // predicted gen...
#
#                                             mrna_assignment category  \
# ID
# 10344614  ENSMUST00000160944 // ENSEMBL // cdna:pseudoge...     main
# 10344616  ENSMUST00000082908 // ENSEMBL // ncrna:snRNA c...     main
# 10344618                                                ---      ---
# 10344620  ENSMUST00000097833 // ENSEMBL // Putative unch...     main
# 10344622  GENSCAN00000047522 // ENSEMBL // cdna:Genscan ...     main
#
#          Gene symbol
# ID
# 10344614
# 10344616
# 10344618
# 10344620     Gm10568
# 10344622     Gm10568

# %%
merged = pd.merge(data, probes, left_index=True, right_index=True)
merged.head()
# Out:
#           T4.129#1   T4.129#2    T4.AJ#1    T4.AJ#2   T4.AKR#1   T4.AKR#2  \
# 10344620   20.1717    22.3287    22.4646    24.4083    24.2962    25.0382
# 10344622  207.7495   214.1281   216.3114   256.2096   221.3736   292.8199
# 10344624  975.3835  1094.4586  1147.3980  1758.5033  1041.9389  1054.8665
# 10344633  763.2650   916.3283   813.2552  1062.5045   797.4313   730.4834
# 10344637  379.6801   420.8961   316.9711   537.2289   378.4611   375.0992
#
#            T4.B10#1   T4.B10#3    T4.B6#1    T4.B6#2     ...       seqname  \
# 10344620    27.2014    23.2352    22.9827    22.6995     ...          chr1
# 10344622   236.3997   219.6098   241.0234   211.1897     ...          chr1
# 10344624  1106.9478  1075.5465  1419.1045  1159.1558     ...          chr1
# 10344633   789.8505   969.3024   913.6694   846.0762     ...          chr1
# 10344637   387.1061   302.0949   388.2560   434.1414     ...          chr1
#
#              RANGE_GB  RANGE_STRAND  RANGE_START  RANGE_STOP  total_probes  \
# 10344620  NC_000067.5             +      3670652     3670993            25
# 10344622  NC_000067.5             +      4761212     4762280             8
# 10344624  NC_000067.5             +      4797943     4836817            23
# 10344633  NC_000067.5             +      4847895     4887990             8
# 10344637  NC_000067.5             +      5073253     5152630            30
#
#                                             gene_assignment  \
# 10344620  ENSMUST00000097833 // Gm10568 // predicted gen...
# 10344622  ENSMUST00000097833 // Gm10568 // predicted gen...
# 10344624  NM_008866 // Lypla1 // lysophospholipase 1 // ...
# 10344633  NM_011541 // Tcea1 // transcription elongation...
# 10344637  NM_133826 // Atp6v1h // ATPase, H+ transportin...
#
#                                             mrna_assignment  category  \
# 10344620  ENSMUST00000097833 // ENSEMBL // Putative unch...      main
# 10344622  GENSCAN00000047522 // ENSEMBL // cdna:Genscan ...      main
# 10344624  NM_008866 // RefSeq // Mus musculus lysophosph...      main
# 10344633  NM_011541 // RefSeq // Mus musculus transcript...      main
# 10344637  NM_133826 // RefSeq // Mus musculus ATPase, H+...      main
#
#           Gene symbol
# 10344620      Gm10568
# 10344622      Gm10568
# 10344624       Lypla1
# 10344633        Tcea1
# 10344637      Atp6v1h
#
# [5 rows x 94 columns]

# %%
subdata = merged[['Gene symbol'] + headers_ordered]
filename = 'data/{}_gene_values.txt'.format(gse)
subdata.to_csv(filename,
               header=True, index=False, sep='\t')
scores = subprocess.check_output('python ../calculate_activation_signature_score.py -f ' +
                                '{}'.format(filename), shell=True)
print(scores)
# Out:
# b'Activation scores:\nt4.129#1    0.048600\nt4.129#2    0.217933\nt4.aj#1     0.174164\nt4.aj#2     0.297655\nt4.akr#1    0.161235\nt4.akr#2    0.012759\nt4.b10#1    0.394805\nt4.b10#3    0.418835\nt4.b6#1     0.298939\nt4.b6#2     0.432464\nt4.b6#3     0.284614\nt4.b6#4     0.068205\nt4.b6#5     0.127484\nt4.bpl#1   -0.067918\nt4.bpl#2   -0.450026\n...\nt4.pl#1     -0.259887\nt4.pl#2     -1.000000\nt4.pwd#1     0.419655\nt4.pwd#2     0.413089\nt4.riii#1   -0.153647\nt4.riii#2   -0.354925\nt4.sea#1    -0.066925\nt4.sea#2    -0.053351\nt4.sjl#1     0.024303\nt4.sjl#2    -0.228252\nt4.sm#1     -0.340650\nt4.sm#2     -0.194809\nt4.swr#1    -0.216533\nt4.wsb#1    -0.249856\nt4.wsb#2    -0.283565\nLength: 82, dtype: float64\n'

# %%
import sys
sys.path.append('../')
from calculate_activation_signature_score import ActivationOptionParser

parser = ActivationOptionParser()
filename = 'data/{}_gene_values.txt'.format(gse)
scores = parser.scores_from_file(filename)

# %%
# Irregular numbers of samples-- calc means and std.
groups = [scores[i:i+2] for i in range(0,8,2)]
groups += [scores[8:13]] # bl6
groups += [scores[i:i+2] for i in range(13,79,2)]
groups += [scores[79:80]] # SWR
groups += [scores[i:i+2] for i in range(80,len(scores),2)]
means = [np.mean(score_group) for score_group in groups]
stddev = [np.std(score_group) for score_group in groups]
labels = [score_group.index[0][3:-2].upper() for score_group in groups]
print(labels)
groups
# Out:
# ['129', 'AJ', 'AKR', 'B10', 'B6', 'BPL', 'BTBR', 'BALB', 'C3H', 'C57BR', 'C57KS', 'C57L', 'CAS', 'CBACA', 'CBAJ', 'CE', 'DBA2', 'DDY', 'FVB', 'JF1MS', 'KK', 'LG', 'LP', 'MA', 'MRL', 'MSM', 'NOD', 'NON', 'NOR', 'NZB', 'NZW', 'P', 'PL', 'PWD', 'RIII', 'SEA', 'SJL', 'SM', 'SWR', 'WSB']
# [t4.129#1    0.048600
#  t4.129#2    0.217933
#  dtype: float64, t4.aj#1    0.174164
#  t4.aj#2    0.297655
#  dtype: float64, t4.akr#1    0.161235
#  t4.akr#2    0.012759
#  dtype: float64, t4.b10#1    0.394805
#  t4.b10#3    0.418835
#  dtype: float64, t4.b6#1    0.298939
#  t4.b6#2    0.432464
#  t4.b6#3    0.284614
#  t4.b6#4    0.068205
#  t4.b6#5    0.127484
#  dtype: float64, t4.bpl#1   -0.067918
#  t4.bpl#2   -0.450026
#  dtype: float64, t4.btbr#1    0.065563
#  t4.btbr#2    0.263865
#  dtype: float64, t4.balb#1   -0.148072
#  t4.balb#2   -0.361330
#  dtype: float64, t4.c3h#1   -0.186799
#  t4.c3h#2    0.057045
#  dtype: float64, t4.c57br#1    0.021557
#  t4.c57br#2    0.009496
#  dtype: float64, t4.c57ks#1    0.173558
#  t4.c57ks#2    0.068612
#  dtype: float64, t4.c57l#1    0.084232
#  t4.c57l#2    0.166100
#  dtype: float64, t4.cas#2   -0.705072
#  t4.cas#3   -0.413074
#  dtype: float64, t4.cbaca#1    0.085024
#  t4.cbaca#2    0.041544
#  dtype: float64, t4.cbaj#1    0.079077
#  t4.cbaj#2    0.069232
#  dtype: float64, t4.ce#1   -0.089821
#  t4.ce#2   -0.057289
#  dtype: float64, t4.dba2#1    0.759377
#  t4.dba2#2    0.511519
#  dtype: float64, t4.ddy#1    0.144161
#  t4.ddy#2    0.005605
#  dtype: float64, t4.fvb#1   -0.246210
#  t4.fvb#2   -0.358622
#  dtype: float64, t4.jf1ms#1   -0.129442
#  t4.jf1ms#2   -0.162583
#  dtype: float64, t4.kk#1   -0.238059
#  t4.kk#2   -0.227052
#  dtype: float64, t4.lg#1    0.315533
#  t4.lg#2    0.088538
#  dtype: float64, t4.lp#1   -0.216436
#  t4.lp#2    0.059601
#  dtype: float64, t4.ma#1    0.376573
#  t4.ma#2    0.234823
#  dtype: float64, t4.mrl#1    0.464566
#  t4.mrl#2    0.556058
#  dtype: float64, t4.msm#1   -0.575502
#  t4.msm#2   -0.087442
#  dtype: float64, t4.nod#1    0.217849
#  t4.nod#2   -0.012079
#  dtype: float64, t4.non#1   -0.421673
#  t4.non#2   -0.179179
#  dtype: float64, t4.nor#1    0.079348
#  t4.nor#2   -0.007938
#  dtype: float64, t4.nzb#1   -0.194828
#  t4.nzb#2   -0.158263
#  dtype: float64, t4.nzw#1    0.293626
#  t4.nzw#2    0.193341
#  dtype: float64, t4.p#1   -0.060389
#  t4.p#2   -0.122665
#  dtype: float64, t4.pl#1   -0.259887
#  t4.pl#2   -1.000000
#  dtype: float64, t4.pwd#1    0.419655
#  t4.pwd#2    0.413089
#  dtype: float64, t4.riii#1   -0.153647
#  t4.riii#2   -0.354925
#  dtype: float64, t4.sea#1   -0.066925
#  t4.sea#2   -0.053351
#  dtype: float64, t4.sjl#1    0.024303
#  t4.sjl#2   -0.228252
#  dtype: float64, t4.sm#1   -0.340650
#  t4.sm#2   -0.194809
#  dtype: float64, t4.swr#1   -0.216533
#  dtype: float64, t4.wsb#1   -0.249856
#  t4.wsb#2   -0.283565
#  dtype: float64]

# %%
# Set up colors
colorset = sns.color_palette("GnBu_d", len(means))

# %%
x_range = range(0, len(means))
plt.figure(figsize=[20,10])

bars = plt.bar([x + .2 for x in x_range], means, color=list(colorset))
plt.errorbar([x + .6 for x in x_range], means, linewidth=0,
        yerr=stddev, ecolor='black', elinewidth=.5, capsize=20)


# Label scores above bars
for i, score in enumerate(means):
    if score < 0:
        align = 'top'
        height = score - .1
    else: 
        align = 'bottom'
        height = score + .1
    plt.text(i + .6, height, '%.2f' % score,
                ha='center', va=align, fontsize=14)

plt.ylim([-1.1, 1.1])
plt.xlim([0, len(means) + .2])
plt.ylabel('Activation Signature Score')

plt.xticks([x + .6 for x in x_range], labels, rotation=90)

title = 'Activation Signature Scores: {}'.format(gse)
plt.title(title)
plt.savefig('figures/{}.png'.format(title.replace(' ', '_')), bbox_inches='tight')
