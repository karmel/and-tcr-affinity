# %%
'''
We have a set of ~300 genes with names and scores.

Given an RPKM file, normalize, extract the genes of interest,
and determine score.
'''
# Out:
# '\nWe have a set of ~300 genes with names and scores.\n\nGiven an RPKM file, normalize, extract the genes of interest,\nand determine score.\n'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import subprocess

# %%
sns.set_context('poster')

# %%
gse = 'meki'
filename = '../../data/mean/rpkm.txt'
data = pd.io.parsers.read_csv(filename, 
                                    sep='\t', 
                                    header=0, index_col=0)

print(data.shape)

# Get gene column
data['Gene symbol'] = [s.split('|')[0] for s in data['Annotation/Divergence']]

cols = ['No-Peptide-24h',
        '10uM-K99A-24h', 
        '100uM-K99A-24h', 
        '0-1uM-PCC-24h', 
        '10uM-PCC-24h', 
        ]
meki_cols = [s + '-MEKi' for s in cols]
labels = ['No Peptide', '10uM K99A', '100uM K99A', '0.1uM PCC', '10uM PCC']
data.head()
# Out:
# (24063, 33)
#                 id.1    chr      start        end strand  Length  Copies  \
# id
# NM_013478  NM_013478   chr5  137981521  137990232      +    1308       1
# NM_172784  NM_172784  chr10    7589800    7625477      +    3388       1
# NM_007732  NM_007732  chr19   47646341   47692042      -    5373       1
# NM_016772  NM_016772   chr7   28825338   28832239      +    1126       1
# NR_077063  NR_077063   chr7   43745466   43755936      -    2551       1
#
#                                        Annotation/Divergence  0-1uM-PCC-24h-1  \
# id
# NM_013478         Azgp1|Zag|-|5 G2|5 76.92 cM|protein-coding            0.000
# NM_172784  Lrp11|1700034J19Rik|6330533B21|9830160H19Rik|-...            1.027
# NM_007732  Col17a1|BP180|Bpag|Bpag2|-|19 D1|19 40.07 cM|p...            0.000
# NM_016772              Ech1|AA617331|-|7 A3|7|protein-coding           23.820
# NR_077063                        2310002F09Rik|-|-|7|7|ncRNA            0.000
#
#            100uM-K99A-24h-1      ...        No-Peptide-24h-std  10uM-K99A-24h  \
# id                               ...
# NM_013478             0.000      ...                  0.000000         0.0000
# NM_172784             1.688      ...                  0.072832         0.8530
# NM_007732             0.000      ...                  0.058690         0.0040
# NM_016772            34.892      ...                  7.484725        36.6585
# NR_077063             0.000      ...                  0.014142         0.0470
#
#            10uM-K99A-24h-std  100uM-K99A-24h  100uM-K99A-24h-std  \
# id
# NM_013478           0.000000          0.0000            0.000000
# NM_172784           0.295571          1.3405            0.491439
# NM_007732           0.005657          0.0095            0.013435
# NM_016772           4.456894         29.7200            7.314313
# NR_077063           0.043841          0.0000            0.000000
#
#            0-1uM-PCC-24h  0-1uM-PCC-24h-std  10uM-PCC-24h  10uM-PCC-24h-std  \
# id
# NM_013478         0.0000           0.000000        0.0000          0.000000
# NM_172784         1.0895           0.088388        0.9210          0.005657
# NM_007732         0.0090           0.012728        0.0105          0.014849
# NM_016772        25.7330           2.705391       28.8205          1.897167
# NR_077063         0.0000           0.000000        0.0000          0.000000
#
#              Gene symbol
# id
# NM_013478          Azgp1
# NM_172784          Lrp11
# NM_007732        Col17a1
# NM_016772           Ech1
# NR_077063  2310002F09Rik
#
# [5 rows x 34 columns]

# %%
# Get alternating columns
cols_ordered = [item for sublist in zip(cols, meki_cols) for item in sublist]
cols_ordered
# Out:
# ['No-Peptide-24h',
#  'No-Peptide-24h-MEKi',
#  '10uM-K99A-24h',
#  '10uM-K99A-24h-MEKi',
#  '100uM-K99A-24h',
#  '100uM-K99A-24h-MEKi',
#  '0-1uM-PCC-24h',
#  '0-1uM-PCC-24h-MEKi',
#  '10uM-PCC-24h',
#  '10uM-PCC-24h-MEKi']

# %%
subdata = data[['Gene symbol'] + cols_ordered]
filename = 'data/{}_gene_values.txt'.format(gse)
subdata.to_csv(filename,
               header=True, index=False, sep='\t')
scores = subprocess.check_output('python ../calculate_activation_signature_score.py -f ' +
                                '{}'.format(filename), shell=True)
print(scores)
# Out:
# b'Activation scores:\nno-peptide-24h        -716.218158\nno-peptide-24h-meki   -830.379741\n10um-k99a-24h          -86.605192\n10um-k99a-24h-meki    -534.866604\n100um-k99a-24h         369.904612\n100um-k99a-24h-meki      7.073732\n0-1um-pcc-24h          421.726677\n0-1um-pcc-24h-meki     377.024320\n10um-pcc-24h           558.926828\n10um-pcc-24h-meki      433.413527\ndtype: float64\n'

# %%
import sys
sys.path.append('../')
from calculate_activation_signature_score import ActivationOptionParser

parser = ActivationOptionParser()
filename = 'data/{}_gene_values.txt'.format(gse)
scores = parser.scores_from_file(filename)

# %%
# Set up colors
colors = sns.color_palette("husl", 5)[::-1]

# Get sets of two
color_groups = zip(colors, colors)

# Flatten
color_groups = [item for sublist in color_groups for item in sublist]

# %%
x_range = range(0, len(scores))
plt.figure()

bars = plt.bar([x + .2 for x in x_range], scores, color=list(color_groups))

# Add hatching on every other bar
for i, bar in enumerate(bars):
    if i%2 == 1:
        bar.set_hatch('//')
    else:
        bar.set_hatch(None)

# Custom legend
notx_patch = plt.Rectangle((0, 0), 1, 1, fc="white")
meki_patch = plt.Rectangle((0, 0), 1, 1, fc="white", hatch ='//')

plt.legend([notx_patch, meki_patch], ['Notx', '0.5uM MEKi'], loc='upper left')

# Label scores above bars
for i, score in enumerate(scores):
    if score < 0:
        align = 'top'
        height = score - 5
    else: 
        align = 'bottom'
        height = score + 2
    plt.text(i + .6, height, int(score),
                ha='center', va=align, fontsize=14)

plt.ylim([plt.ylim()[0], plt.ylim()[1] + 50])
plt.xlim([0, len(scores) + .2])
plt.ylabel('Activation Signature Score')

plt.xticks([x + 1.1 for x in x_range if not x%2], labels)

title = 'Activation Signature Scores with MEKi Treatment'
plt.title(title)
plt.savefig('figures/{}.png'.format(title.replace(' ', '_')), bbox_inches='tight')
