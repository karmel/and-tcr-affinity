# %%
'''
We have a set of ~300 genes with names and scores.

Given a microarray .txt file, normalize, extract the genes of interest,
and determine score.
'''
# Out:
# '\nWe have a set of ~300 genes with names and scores.\n\nGiven a microarray .txt file, normalize, extract the genes of interest,\nand determine score.\n'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import subprocess
import numpy as np

# %%
sns.set_context('poster')

# %%
gse = 'GSE42276'
fname = 'data/{}_series_matrix.txt'.format(gse)

# Comment lines begin with a variety of characters. Figure out where to start manually.
start_at = 0
for i, line in enumerate(open(fname).readlines()):
    if line.startswith('!Sample_title'):
        headers = line.split('\t')[1:]
    elif line.startswith('!Series_platform_id'):
        platform = line.split('\t')[1].strip().strip('"')
    elif line[0] not in ('!', '#', '^', '\n'):
        start_at = i
        break
data = pd.io.parsers.read_csv(fname, 
                sep='\t', header=start_at-1, index_col=0)
data = data.fillna(0)
headers = [h.strip().strip('"').replace(' ','_').replace(',','') for h in headers]
print(platform)
print(headers)
data.head()
# Out:
# GPL6246
# ['TC.0hr#3', 'TC.0hr#4', 'TC.0hr#5', 'TC.BTLA.early#1', 'TC.BTLA.early#2', 'TC.BTLA.early#3', 'TC.BTLA.late#1', 'TC.BTLA.late#2', 'TC.BTLA.late#3', 'TC.CD3-28.early#1', 'TC.CD3-28.early#2', 'TC.CD3-28.early#3', 'TC.CD3-28.late#1', 'TC.CD3-28.late#2', 'TC.CD3-28.late#3', 'TC.CD3.early#1', 'TC.CD3.early#2', 'TC.CD3.early#3', 'TC.CD3.early#4', 'TC.CD3.late#1', 'TC.CD3.late#2', 'TC.CD3.late#3', 'TC.CD3.late#4', 'TC.CD80.early#1', 'TC.CD80.early#2', 'TC.CD80.late#1', 'TC.CD80.late#2', 'TC.CTLA4.early#1', 'TC.CTLA4.early#2', 'TC.CTLA4.early#3', 'TC.CTLA4.late#1', 'TC.CTLA4.late#2', 'TC.CTLA4.late#3', 'TC.ICOS.early#1', 'TC.ICOS.early#2', 'TC.ICOS.late#1', 'TC.ICOS.late#2', 'TC.PD1.early#1', 'TC.PD1.early#2', 'TC.PD1.early#3', 'TC.PD1.late#1', 'TC.PD1.late#2', 'TC.PD1.late#3', 'TR.0hr#3', 'TR.0hr#4', 'TR.0hr#5', 'TR.BTLA.early#1', 'TR.BTLA.early#2', 'TR.BTLA.early#3', 'TR.BTLA.late#1', 'TR.BTLA.late#2', 'TR.BTLA.late#3', 'TR.CD3-28.early#1', 'TR.CD3-28.early#2', 'TR.CD3-28.early#3', 'TR.CD3-28.late#1', 'TR.CD3-28.late#2', 'TR.CD3-28.late#3', 'TR.CD3.early#1', 'TR.CD3.early#2', 'TR.CD3.early#3', 'TR.CD3.early#4', 'TR.CD3.late#1', 'TR.CD3.late#2', 'TR.CD3.late#3', 'TR.CD3.late#4', 'TR.CD80.early#1', 'TR.CD80.early#2', 'TR.CD80.late#1', 'TR.CD80.late#2', 'TR.CTLA4.early#1', 'TR.CTLA4.early#2', 'TR.CTLA4.early#3', 'TR.CTLA4.late#1', 'TR.CTLA4.late#2', 'TR.CTLA4.late#3', 'TR.ICOS.early#1', 'TR.ICOS.early#2', 'TR.ICOS.late#1', 'TR.ICOS.late#2', 'TR.PD1.early#1', 'TR.PD1.early#3', 'TR.PD1.late#1', 'TR.PD1.late#2', 'TR.PD1.late#3']
# /Applications/anaconda/lib/python3.4/site-packages/pandas/io/parsers.py:1154: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)
#           GSM1036762  GSM1036763  GSM1036764  GSM1036765  GSM1036766  \
# ID_REF
# 10344620     24.4918     23.3073     23.9188     29.7944     22.3886
# 10344622    215.7454    274.3759    237.5154    221.5953    294.9352
# 10344624    773.2870    867.4858    862.2638    873.7849    858.7905
# 10344633    829.4705    893.6936    926.1491    808.1588    765.3511
# 10344637    382.5084    349.7999    332.3025    466.0718    375.5460
#
#           GSM1036767  GSM1036768  GSM1036769  GSM1036770  GSM1036771  \
# ID_REF
# 10344620     26.8367     23.9592     24.3595     24.0695     23.5637
# 10344622    325.9291    192.1863    241.8696    204.0357    231.7418
# 10344624    818.6776   1112.3994   1135.7423    869.7976    842.1346
# 10344633    861.3136    987.5631   1018.3385   1005.6019    783.4177
# 10344637    430.9088    336.2123    341.9758    347.2539    417.6570
#
#              ...      GSM1036837  GSM1036838  GSM1036839  GSM1036840  \
# ID_REF       ...
# 10344620     ...         28.3709     24.1765     27.5815     30.1145
# 10344622     ...        198.3455    231.5387    259.1096    227.2046
# 10344624     ...        830.1995    663.9898    545.0675    952.4592
# 10344633     ...        839.4739    702.3708    716.1488    970.7747
# 10344637     ...        265.4425    216.6129    232.0945    306.4158
#
#           GSM1036841  GSM1036842  GSM1036843  GSM1036844  GSM1036845  \
# ID_REF
# 10344620     24.0967     26.3130     34.4667     25.8749     26.6948
# 10344622    299.5740    136.9477    165.9087    224.8830    260.2709
# 10344624   1095.9144    891.7887    750.0764    831.4099    933.7206
# 10344633    974.6256    872.4222    899.1571    810.1625    772.0953
# 10344637    360.4419    259.9102    243.6599    292.9382    267.8591
#
#           GSM1036846
# ID_REF
# 10344620     30.7280
# 10344622    194.3686
# 10344624    854.0774
# 10344633    761.2883
# 10344637    257.2873
#
# [5 rows x 85 columns]

# %%
headers_ordered = headers

# %%
# Rename our columns
data.columns = headers
data.head()
# Out:
#           TC.0hr#3  TC.0hr#4  TC.0hr#5  TC.BTLA.early#1  TC.BTLA.early#2  \
# ID_REF
# 10344620   24.4918   23.3073   23.9188          29.7944          22.3886
# 10344622  215.7454  274.3759  237.5154         221.5953         294.9352
# 10344624  773.2870  867.4858  862.2638         873.7849         858.7905
# 10344633  829.4705  893.6936  926.1491         808.1588         765.3511
# 10344637  382.5084  349.7999  332.3025         466.0718         375.5460
#
#           TC.BTLA.early#3  TC.BTLA.late#1  TC.BTLA.late#2  TC.BTLA.late#3  \
# ID_REF
# 10344620          26.8367         23.9592         24.3595         24.0695
# 10344622         325.9291        192.1863        241.8696        204.0357
# 10344624         818.6776       1112.3994       1135.7423        869.7976
# 10344633         861.3136        987.5631       1018.3385       1005.6019
# 10344637         430.9088        336.2123        341.9758        347.2539
#
#           TC.CD3-28.early#1      ...        TR.CTLA4.late#3  TR.ICOS.early#1  \
# ID_REF                           ...
# 10344620            23.5637      ...                28.3709          24.1765
# 10344622           231.7418      ...               198.3455         231.5387
# 10344624           842.1346      ...               830.1995         663.9898
# 10344633           783.4177      ...               839.4739         702.3708
# 10344637           417.6570      ...               265.4425         216.6129
#
#           TR.ICOS.early#2  TR.ICOS.late#1  TR.ICOS.late#2  TR.PD1.early#1  \
# ID_REF
# 10344620          27.5815         30.1145         24.0967         26.3130
# 10344622         259.1096        227.2046        299.5740        136.9477
# 10344624         545.0675        952.4592       1095.9144        891.7887
# 10344633         716.1488        970.7747        974.6256        872.4222
# 10344637         232.0945        306.4158        360.4419        259.9102
#
#           TR.PD1.early#3  TR.PD1.late#1  TR.PD1.late#2  TR.PD1.late#3
# ID_REF
# 10344620         34.4667        25.8749        26.6948        30.7280
# 10344622        165.9087       224.8830       260.2709       194.3686
# 10344624        750.0764       831.4099       933.7206       854.0774
# 10344633        899.1571       810.1625       772.0953       761.2883
# 10344637        243.6599       292.9382       267.8591       257.2873
#
# [5 rows x 85 columns]

# %%
# Get gene names
fname = 'data/{}.txt'.format(platform)
start_at = 0
for i, line in enumerate(open(fname).readlines()):
    if line[0] not in ('!', '#', '^', '\s', '\n'):
        start_at = i
        break
probes = pd.io.parsers.read_csv(fname, 
            sep='\t', header=start_at, index_col=0)
probes.head()
# Out:
#                      GB_LIST               SPOT_ID seqname     RANGE_GB  \
# ID
# 10344614                 NaN  chr1:3044314-3044814    chr1  NC_000067.5
# 10344616                 NaN  chr1:3092097-3092206    chr1  NC_000067.5
# 10344618                 NaN  chr1:3266404-3267429    chr1  NC_000067.5
# 10344620                 NaN  chr1:3670652-3670993    chr1  NC_000067.5
# 10344622  NM_024221,BC094468  chr1:4761212-4762280    chr1  NC_000067.5
#
#          RANGE_STRAND RANGE_START RANGE_STOP total_probes  \
# ID
# 10344614            +     3044314    3044814           33
# 10344616            +     3092097    3092206           25
# 10344618            +     3266404    3267429           25
# 10344620            +     3670652    3670993           25
# 10344622            +     4761212    4762280            8
#
#                                             gene_assignment  \
# ID
# 10344614                                                ---
# 10344616                                                ---
# 10344618                                                ---
# 10344620  ENSMUST00000097833 // Gm10568 // predicted gen...
# 10344622  ENSMUST00000097833 // Gm10568 // predicted gen...
#
#                                             mrna_assignment category
# ID
# 10344614  ENSMUST00000160944 // ENSEMBL // cdna:pseudoge...     main
# 10344616  ENSMUST00000082908 // ENSEMBL // ncrna:snRNA c...     main
# 10344618                                                ---      ---
# 10344620  ENSMUST00000097833 // ENSEMBL // Putative unch...     main
# 10344622  GENSCAN00000047522 // ENSEMBL // cdna:Genscan ...     main

# %%
def get_symbol(row):
    try:
        return str(row['gene_assignment']).split('//')[1].strip()
    except IndexError:
        return ''

probes['Gene symbol'] = probes.apply(get_symbol, axis=1)
probes.head()
# Out:
#                      GB_LIST               SPOT_ID seqname     RANGE_GB  \
# ID
# 10344614                 NaN  chr1:3044314-3044814    chr1  NC_000067.5
# 10344616                 NaN  chr1:3092097-3092206    chr1  NC_000067.5
# 10344618                 NaN  chr1:3266404-3267429    chr1  NC_000067.5
# 10344620                 NaN  chr1:3670652-3670993    chr1  NC_000067.5
# 10344622  NM_024221,BC094468  chr1:4761212-4762280    chr1  NC_000067.5
#
#          RANGE_STRAND RANGE_START RANGE_STOP total_probes  \
# ID
# 10344614            +     3044314    3044814           33
# 10344616            +     3092097    3092206           25
# 10344618            +     3266404    3267429           25
# 10344620            +     3670652    3670993           25
# 10344622            +     4761212    4762280            8
#
#                                             gene_assignment  \
# ID
# 10344614                                                ---
# 10344616                                                ---
# 10344618                                                ---
# 10344620  ENSMUST00000097833 // Gm10568 // predicted gen...
# 10344622  ENSMUST00000097833 // Gm10568 // predicted gen...
#
#                                             mrna_assignment category  \
# ID
# 10344614  ENSMUST00000160944 // ENSEMBL // cdna:pseudoge...     main
# 10344616  ENSMUST00000082908 // ENSEMBL // ncrna:snRNA c...     main
# 10344618                                                ---      ---
# 10344620  ENSMUST00000097833 // ENSEMBL // Putative unch...     main
# 10344622  GENSCAN00000047522 // ENSEMBL // cdna:Genscan ...     main
#
#          Gene symbol
# ID
# 10344614
# 10344616
# 10344618
# 10344620     Gm10568
# 10344622     Gm10568

# %%
merged = pd.merge(data, probes, left_index=True, right_index=True)
merged.head()
# Out:
#           TC.0hr#3  TC.0hr#4  TC.0hr#5  TC.BTLA.early#1  TC.BTLA.early#2  \
# 10344620   24.4918   23.3073   23.9188          29.7944          22.3886
# 10344622  215.7454  274.3759  237.5154         221.5953         294.9352
# 10344624  773.2870  867.4858  862.2638         873.7849         858.7905
# 10344633  829.4705  893.6936  926.1491         808.1588         765.3511
# 10344637  382.5084  349.7999  332.3025         466.0718         375.5460
#
#           TC.BTLA.early#3  TC.BTLA.late#1  TC.BTLA.late#2  TC.BTLA.late#3  \
# 10344620          26.8367         23.9592         24.3595         24.0695
# 10344622         325.9291        192.1863        241.8696        204.0357
# 10344624         818.6776       1112.3994       1135.7423        869.7976
# 10344633         861.3136        987.5631       1018.3385       1005.6019
# 10344637         430.9088        336.2123        341.9758        347.2539
#
#           TC.CD3-28.early#1     ...       seqname     RANGE_GB  RANGE_STRAND  \
# 10344620            23.5637     ...          chr1  NC_000067.5             +
# 10344622           231.7418     ...          chr1  NC_000067.5             +
# 10344624           842.1346     ...          chr1  NC_000067.5             +
# 10344633           783.4177     ...          chr1  NC_000067.5             +
# 10344637           417.6570     ...          chr1  NC_000067.5             +
#
#           RANGE_START  RANGE_STOP  total_probes  \
# 10344620      3670652     3670993            25
# 10344622      4761212     4762280             8
# 10344624      4797943     4836817            23
# 10344633      4847895     4887990             8
# 10344637      5073253     5152630            30
#
#                                             gene_assignment  \
# 10344620  ENSMUST00000097833 // Gm10568 // predicted gen...
# 10344622  ENSMUST00000097833 // Gm10568 // predicted gen...
# 10344624  NM_008866 // Lypla1 // lysophospholipase 1 // ...
# 10344633  NM_011541 // Tcea1 // transcription elongation...
# 10344637  NM_133826 // Atp6v1h // ATPase, H+ transportin...
#
#                                             mrna_assignment  category  \
# 10344620  ENSMUST00000097833 // ENSEMBL // Putative unch...      main
# 10344622  GENSCAN00000047522 // ENSEMBL // cdna:Genscan ...      main
# 10344624  NM_008866 // RefSeq // Mus musculus lysophosph...      main
# 10344633  NM_011541 // RefSeq // Mus musculus transcript...      main
# 10344637  NM_133826 // RefSeq // Mus musculus ATPase, H+...      main
#
#           Gene symbol
# 10344620      Gm10568
# 10344622      Gm10568
# 10344624       Lypla1
# 10344633        Tcea1
# 10344637      Atp6v1h
#
# [5 rows x 97 columns]

# %%
subdata = merged[['Gene symbol'] + headers_ordered]
filename = 'data/{}_gene_values.txt'.format(gse)
subdata.to_csv(filename,
               header=True, index=False, sep='\t')
scores = subprocess.check_output('python ../calculate_activation_signature_score.py -f ' +
                                '{}'.format(filename), shell=True)
print(scores)
# Out:
# b'Activation scores:\ntc.0hr#3            -0.427916\ntc.0hr#4            -0.381089\ntc.0hr#5            -0.493463\ntc.btla.early#1      0.208134\ntc.btla.early#2      0.170450\ntc.btla.early#3      0.141623\ntc.btla.late#1       0.448210\ntc.btla.late#2       0.423956\ntc.btla.late#3       0.266816\ntc.cd3-28.early#1    0.281137\ntc.cd3-28.early#2    0.110708\ntc.cd3-28.early#3    0.496729\ntc.cd3-28.late#1     0.892664\ntc.cd3-28.late#2     0.864764\ntc.cd3-28.late#3     1.000000\n...\ntr.ctla4.early#1   -0.315453\ntr.ctla4.early#2   -0.194344\ntr.ctla4.early#3   -0.209290\ntr.ctla4.late#1    -0.208758\ntr.ctla4.late#2    -0.533560\ntr.ctla4.late#3    -0.381913\ntr.icos.early#1    -0.176419\ntr.icos.early#2    -0.007609\ntr.icos.late#1      0.705308\ntr.icos.late#2      0.576844\ntr.pd1.early#1     -0.254800\ntr.pd1.early#3     -0.078141\ntr.pd1.late#1      -0.377197\ntr.pd1.late#2      -0.455949\ntr.pd1.late#3      -0.398941\nLength: 85, dtype: float64\n'

# %%
import sys
sys.path.append('../')
from calculate_activation_signature_score import ActivationOptionParser

parser = ActivationOptionParser()
filename = 'data/{}_gene_values.txt'.format(gse)
scores = parser.scores_from_file(filename)

# %%
# Irregular numbers of samples-- calc means and std.
groups = [scores[:3]] # Unstim
groups += [scores[15:19]] + [scores[19:23]] # CD3 only
groups += [scores[9:12]] + [scores[12:15]] # CD28
groups += [scores[3:6]] + [scores[6:9]]
groups += [scores[23:25]] + [scores[25:27]]
groups += [scores[27:30]] + [scores[30:33]]
groups += [scores[33:35]] + [scores[35:37]]
groups += [scores[37:40]] + [scores[40:43]]

means = [np.mean(score_group) for score_group in groups]
stddev = [np.std(score_group) for score_group in groups]

labels = ['Unstim', 'CD3 only', '+ CD28',
          '+ BTLA', '+ CD80',
          '+ CTLA4', '+ ICOS', 
          '+ PD1']

groups
# Out:
# [tc.0hr#3   -0.427916
#  tc.0hr#4   -0.381089
#  tc.0hr#5   -0.493463
#  dtype: float64, tc.cd3.early#1   -0.006779
#  tc.cd3.early#2   -0.024326
#  tc.cd3.early#3   -0.274058
#  tc.cd3.early#4   -0.112413
#  dtype: float64, tc.cd3.late#1    0.230659
#  tc.cd3.late#2    0.050420
#  tc.cd3.late#3   -0.011548
#  tc.cd3.late#4   -0.033779
#  dtype: float64, tc.cd3-28.early#1    0.281137
#  tc.cd3-28.early#2    0.110708
#  tc.cd3-28.early#3    0.496729
#  dtype: float64, tc.cd3-28.late#1    0.892664
#  tc.cd3-28.late#2    0.864764
#  tc.cd3-28.late#3    1.000000
#  dtype: float64, tc.btla.early#1    0.208134
#  tc.btla.early#2    0.170450
#  tc.btla.early#3    0.141623
#  dtype: float64, tc.btla.late#1    0.448210
#  tc.btla.late#2    0.423956
#  tc.btla.late#3    0.266816
#  dtype: float64, tc.cd80.early#1    0.078430
#  tc.cd80.early#2    0.035938
#  dtype: float64, tc.cd80.late#1    0.339341
#  tc.cd80.late#2    0.394052
#  dtype: float64, tc.ctla4.early#1   -0.111188
#  tc.ctla4.early#2   -0.052418
#  tc.ctla4.early#3   -0.288080
#  dtype: float64, tc.ctla4.late#1    0.133855
#  tc.ctla4.late#2    0.132825
#  tc.ctla4.late#3   -0.110392
#  dtype: float64, tc.icos.early#1    0.345475
#  tc.icos.early#2    0.308820
#  dtype: float64, tc.icos.late#1    0.658652
#  tc.icos.late#2    0.516235
#  dtype: float64, tc.pd1.early#1   -0.157841
#  tc.pd1.early#2   -0.137063
#  tc.pd1.early#3   -0.208946
#  dtype: float64, tc.pd1.late#1    0.236225
#  tc.pd1.late#2    0.231082
#  tc.pd1.late#3   -0.081448
#  dtype: float64]

# %%
# Set up colors
colorset = sns.color_palette("GnBu_d", len(means)//2)

# Get sets of two
color_groups = zip(colorset[1:], colorset[1:])

# Flatten
color_groups = [colorset[0]] + [item for sublist in color_groups for item in sublist]

# %%
x_range = range(0, len(means))
plt.figure()

bars = plt.bar([x + .2 for x in x_range], means, color=list(color_groups))
plt.errorbar([x + .6 for x in x_range], means, linewidth=0,
        yerr=stddev, ecolor='black', elinewidth=.5, capsize=20)

# Add hatching on every other bar
for i, bar in enumerate(bars):
    if i == 0:
        continue # Unstim
    elif i%2 == 1:
        bar.set_hatch(None)
    else:
        bar.set_hatch('//')

# Custom legend
clear_patch = plt.Rectangle((0, 0), 1, 1, fc="white")
hatch_patch = plt.Rectangle((0, 0), 1, 1, fc="white", hatch ='//')

plt.legend([clear_patch, hatch_patch], 
           ['Early timepoint', 'Late timepoint'], loc='lower left')

# Label scores above bars
for i, score in enumerate(means):
    if score < 0:
        align = 'top'
        height = score - .1
    else: 
        align = 'bottom'
        height = score + .1
    plt.text(i + .6, height, '%.2f' % score,
                ha='center', va=align, fontsize=14)

plt.ylim([-1.1, 1.1])
plt.xlim([0, len(means) + .2])
plt.ylabel('Activation Signature Score')

plt.xticks([1.1] + [x + 1.1 for x in x_range[1:] if not x%2], ['']*len(labels))
for i, label in enumerate(labels):
    if i == 0:
        x_loc = .6
    else:
        x_loc = i*2 + .1
    plt.text(x_loc, plt.ylim()[0]*1.01, label,
                ha='center', va='top', fontsize=14)


title = 'Activation Signature Scores: {}'.format(gse)
plt.title(title)
plt.savefig('figures/{}.png'.format(title.replace(' ', '_')), bbox_inches='tight')
