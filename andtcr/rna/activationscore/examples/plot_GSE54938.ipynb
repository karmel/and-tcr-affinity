# %%
'''
We have a set of ~300 genes with names and scores.

Given a microarray .txt file, normalize, extract the genes of interest,
and determine score.
'''
# Out:
# '\nWe have a set of ~300 genes with names and scores.\n\nGiven a microarray .txt file, normalize, extract the genes of interest,\nand determine score.\n'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import subprocess
import numpy as np

# %%
sns.set_context('poster')

# %%
gse = 'GSE54938'
fname = 'data/{}_series_matrix.txt'.format(gse)

# Comment lines begin with a variety of characters. Figure out where to start manually.
start_at = 0
for i, line in enumerate(open(fname).readlines()):
    if line.startswith('!Sample_title'):
        headers = line.split('\t')[1:]
    elif line.startswith('!Series_platform_id'):
        platform = line.split('\t')[1].strip().strip('"')
    elif line[0] not in ('!', '#', '^', '\n'):
        start_at = i
        break
data = pd.io.parsers.read_csv(fname, 
                sep='\t', header=start_at-1, index_col=0)
data = data.fillna(0)
headers = [h.strip().strip('"').replace(' ','_').replace(',','') for h in headers]
print(platform)
print(headers)
data.head()
# Out:
# GPL1261
# ['Th1_culture_APC_alone', 'Th1_culture_HA_stimulation_biological_replicate_1', 'Th1_culture_HA_stimulation_biological_replicate_2', 'Th1_culture_PBAB_stimulation_biological_replicate_1', 'Th1_culture_PBAB_stimulation_biological_replicate_2', 'Th9_culture_APC_alone', 'Th9_culture_HA_stimulation_biological_replicate_1', 'Th9_culture_HA_stimulation_biological_replicate_2', 'Th9_culture_PBAB_stimulation_biological_replicate_1', 'Th9_culture_PBAB_stimulation_biological_replicate_2', 'Th17_culture_APC_alone', 'Th17_culture_HA_stimulation_biological_replicate_1', 'Th17_culture_HA_stimulation_biological_replicate_2', 'Th17_culture_PBAB_stimulation_biological_replicate_1', 'Th17_culture_PBAB_stimulation_biological_replicate_2']
#               GSM1326807  GSM1326808  GSM1326809  GSM1326810  GSM1326811  \
# ID_REF
# 1415670_at       5.36103     9.56740     8.98196     9.88006     9.03798
# 1415671_at       7.83079    10.75100    10.39350     9.88999     9.32849
# 1415672_at       9.25071    11.48460    11.42510    11.35420    11.48560
# 1415673_at       5.22896     9.64953     9.56406    10.57580    10.49710
# 1415674_a_at     7.86652    10.13850    10.31280    10.11220    10.22730
#
#               GSM1326812  GSM1326813  GSM1326814  GSM1326815  GSM1326816  \
# ID_REF
# 1415670_at       6.61494     9.63085     8.72623     9.77176     9.23255
# 1415671_at       8.19419    10.46350     9.88348     9.85894     9.71440
# 1415672_at       8.67666    11.48840    11.48180    11.68790    11.68050
# 1415673_at       6.24539     9.81732     9.77528    10.28410    10.12910
# 1415674_a_at     6.69347    10.13850    10.26340     9.93280    10.15540
#
#               GSM1326817  GSM1326818  GSM1326819  GSM1326820  GSM1326821
# ID_REF
# 1415670_at       6.70655     9.52067     8.96363     9.83702     9.50282
# 1415671_at       7.89932    10.43670    10.00520    10.19270     9.86463
# 1415672_at       9.57195    11.44730    11.25470    11.99960    12.12610
# 1415673_at       6.16881     9.33680     9.57182     9.74912     9.72133
# 1415674_a_at     7.82563    10.05410    10.42290     9.98500    10.60260

# %%
labels = ['Th1', 'Th9', 'Th17']

# %%
# Rename our columns
data.columns = headers
data.head()
# Out:
#               Th1_culture_APC_alone  \
# ID_REF
# 1415670_at                  5.36103
# 1415671_at                  7.83079
# 1415672_at                  9.25071
# 1415673_at                  5.22896
# 1415674_a_at                7.86652
#
#               Th1_culture_HA_stimulation_biological_replicate_1  \
# ID_REF
# 1415670_at                                              9.56740
# 1415671_at                                             10.75100
# 1415672_at                                             11.48460
# 1415673_at                                              9.64953
# 1415674_a_at                                           10.13850
#
#               Th1_culture_HA_stimulation_biological_replicate_2  \
# ID_REF
# 1415670_at                                              8.98196
# 1415671_at                                             10.39350
# 1415672_at                                             11.42510
# 1415673_at                                              9.56406
# 1415674_a_at                                           10.31280
#
#               Th1_culture_PBAB_stimulation_biological_replicate_1  \
# ID_REF
# 1415670_at                                              9.88006
# 1415671_at                                              9.88999
# 1415672_at                                             11.35420
# 1415673_at                                             10.57580
# 1415674_a_at                                           10.11220
#
#               Th1_culture_PBAB_stimulation_biological_replicate_2  \
# ID_REF
# 1415670_at                                              9.03798
# 1415671_at                                              9.32849
# 1415672_at                                             11.48560
# 1415673_at                                             10.49710
# 1415674_a_at                                           10.22730
#
#               Th9_culture_APC_alone  \
# ID_REF
# 1415670_at                  6.61494
# 1415671_at                  8.19419
# 1415672_at                  8.67666
# 1415673_at                  6.24539
# 1415674_a_at                6.69347
#
#               Th9_culture_HA_stimulation_biological_replicate_1  \
# ID_REF
# 1415670_at                                              9.63085
# 1415671_at                                             10.46350
# 1415672_at                                             11.48840
# 1415673_at                                              9.81732
# 1415674_a_at                                           10.13850
#
#               Th9_culture_HA_stimulation_biological_replicate_2  \
# ID_REF
# 1415670_at                                              8.72623
# 1415671_at                                              9.88348
# 1415672_at                                             11.48180
# 1415673_at                                              9.77528
# 1415674_a_at                                           10.26340
#
#               Th9_culture_PBAB_stimulation_biological_replicate_1  \
# ID_REF
# 1415670_at                                              9.77176
# 1415671_at                                              9.85894
# 1415672_at                                             11.68790
# 1415673_at                                             10.28410
# 1415674_a_at                                            9.93280
#
#               Th9_culture_PBAB_stimulation_biological_replicate_2  \
# ID_REF
# 1415670_at                                              9.23255
# 1415671_at                                              9.71440
# 1415672_at                                             11.68050
# 1415673_at                                             10.12910
# 1415674_a_at                                           10.15540
#
#               Th17_culture_APC_alone  \
# ID_REF
# 1415670_at                   6.70655
# 1415671_at                   7.89932
# 1415672_at                   9.57195
# 1415673_at                   6.16881
# 1415674_a_at                 7.82563
#
#               Th17_culture_HA_stimulation_biological_replicate_1  \
# ID_REF
# 1415670_at                                              9.52067
# 1415671_at                                             10.43670
# 1415672_at                                             11.44730
# 1415673_at                                              9.33680
# 1415674_a_at                                           10.05410
#
#               Th17_culture_HA_stimulation_biological_replicate_2  \
# ID_REF
# 1415670_at                                              8.96363
# 1415671_at                                             10.00520
# 1415672_at                                             11.25470
# 1415673_at                                              9.57182
# 1415674_a_at                                           10.42290
#
#               Th17_culture_PBAB_stimulation_biological_replicate_1  \
# ID_REF
# 1415670_at                                              9.83702
# 1415671_at                                             10.19270
# 1415672_at                                             11.99960
# 1415673_at                                              9.74912
# 1415674_a_at                                            9.98500
#
#               Th17_culture_PBAB_stimulation_biological_replicate_2
# ID_REF
# 1415670_at                                              9.50282
# 1415671_at                                              9.86463
# 1415672_at                                             12.12610
# 1415673_at                                              9.72133
# 1415674_a_at                                           10.60260

# %%
# Get gene names
fname = 'data/{}.txt'.format(platform)
start_at = 0
for i, line in enumerate(open(fname).readlines()):
    if line[0] not in ('!', '#', '^', '\s', '\n'):
        start_at = i
        break
probes = pd.io.parsers.read_csv(fname, 
            sep='\t', header=start_at, index_col=0)
probes.head()
# Out:
# /Applications/anaconda/lib/python3.4/site-packages/pandas/io/parsers.py:1154: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)
#                  GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# ID
# 1415670_at     BC024686     NaN            Mus musculus     Jun 9, 2011
# 1415671_at    NM_013477     NaN            Mus musculus     Jun 9, 2011
# 1415672_at    NM_020585     NaN            Mus musculus     Jun 9, 2011
# 1415673_at    NM_133900     NaN            Mus musculus     Jun 9, 2011
# 1415674_a_at  NM_021789     NaN            Mus musculus     Jun 9, 2011
#
#                    Sequence Type Sequence Source  \
# ID
# 1415670_at    Consensus sequence         GenBank
# 1415671_at    Consensus sequence         GenBank
# 1415672_at    Consensus sequence         GenBank
# 1415673_at    Consensus sequence         GenBank
# 1415674_a_at  Consensus sequence         GenBank
#
#                                              Target Description  \
# ID
# 1415670_at    gb:BC024686.1 /DB_XREF=gi:19354080 /FEA=FLmRNA...
# 1415671_at    gb:NM_013477.1 /DB_XREF=gi:7304908 /GEN=Atp6v0...
# 1415672_at    gb:NM_020585.1 /DB_XREF=gi:10181207 /GEN=AB041...
# 1415673_at    gb:NM_133900.1 /DB_XREF=gi:19527115 /GEN=AI480...
# 1415674_a_at  gb:NM_021789.1 /DB_XREF=gi:11140824 /GEN=Sbdn ...
#
#              Representative Public ID  \
# ID
# 1415670_at                   BC024686
# 1415671_at                  NM_013477
# 1415672_at                  NM_020585
# 1415673_at                  NM_133900
# 1415674_a_at                NM_021789
#
#                                                     Gene Title Gene Symbol  \
# ID
# 1415670_at             coatomer protein complex, subunit gamma        Copg
# 1415671_at    ATPase, H+ transporting, lysosomal V0 subunit D1    Atp6v0d1
# 1415672_at            golgi autoantigen, golgin subfamily a, 7      Golga7
# 1415673_at                           phosphoserine phosphatase        Psph
# 1415674_a_at            trafficking protein particle complex 4     Trappc4
#
#              ENTREZ_GENE_ID        RefSeq Transcript ID  \
# ID
# 1415670_at            54161     NM_017477 /// NM_201244
# 1415671_at            11972                   NM_013477
# 1415672_at            57437  NM_001042484 /// NM_020585
# 1415673_at           100678                   NM_133900
# 1415674_a_at          60409                   NM_021789
#
#                                Gene Ontology Biological Process  \
# ID
# 1415670_at    0006810 // transport // inferred from electron...
# 1415671_at    0006810 // transport // inferred from electron...
# 1415672_at    0006893 // Golgi to plasma membrane transport ...
# 1415673_at    0006563 // L-serine metabolic process // infer...
# 1415674_a_at  0006810 // transport // inferred from electron...
#
#                                Gene Ontology Cellular Component  \
# ID
# 1415670_at    0000139 // Golgi membrane // inferred from ele...
# 1415671_at    0005769 // early endosome // inferred from dir...
# 1415672_at    0000139 // Golgi membrane // not recorded /// ...
# 1415673_at    0005737 // cytoplasm // inferred from sequence...
# 1415674_a_at  0005783 // endoplasmic reticulum // inferred f...
#
#                                Gene Ontology Molecular Function
# ID
# 1415670_at    0005198 // structural molecule activity // inf...
# 1415671_at    0005515 // protein binding // inferred from el...
# 1415672_at                                                  NaN
# 1415673_at    0000287 // magnesium ion binding // inferred f...
# 1415674_a_at  0005515 // protein binding // inferred from el...

# %%
probes['Gene symbol'] = probes['Gene Symbol']
probes.head()
# Out:
#                  GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# ID
# 1415670_at     BC024686     NaN            Mus musculus     Jun 9, 2011
# 1415671_at    NM_013477     NaN            Mus musculus     Jun 9, 2011
# 1415672_at    NM_020585     NaN            Mus musculus     Jun 9, 2011
# 1415673_at    NM_133900     NaN            Mus musculus     Jun 9, 2011
# 1415674_a_at  NM_021789     NaN            Mus musculus     Jun 9, 2011
#
#                    Sequence Type Sequence Source  \
# ID
# 1415670_at    Consensus sequence         GenBank
# 1415671_at    Consensus sequence         GenBank
# 1415672_at    Consensus sequence         GenBank
# 1415673_at    Consensus sequence         GenBank
# 1415674_a_at  Consensus sequence         GenBank
#
#                                              Target Description  \
# ID
# 1415670_at    gb:BC024686.1 /DB_XREF=gi:19354080 /FEA=FLmRNA...
# 1415671_at    gb:NM_013477.1 /DB_XREF=gi:7304908 /GEN=Atp6v0...
# 1415672_at    gb:NM_020585.1 /DB_XREF=gi:10181207 /GEN=AB041...
# 1415673_at    gb:NM_133900.1 /DB_XREF=gi:19527115 /GEN=AI480...
# 1415674_a_at  gb:NM_021789.1 /DB_XREF=gi:11140824 /GEN=Sbdn ...
#
#              Representative Public ID  \
# ID
# 1415670_at                   BC024686
# 1415671_at                  NM_013477
# 1415672_at                  NM_020585
# 1415673_at                  NM_133900
# 1415674_a_at                NM_021789
#
#                                                     Gene Title Gene Symbol  \
# ID
# 1415670_at             coatomer protein complex, subunit gamma        Copg
# 1415671_at    ATPase, H+ transporting, lysosomal V0 subunit D1    Atp6v0d1
# 1415672_at            golgi autoantigen, golgin subfamily a, 7      Golga7
# 1415673_at                           phosphoserine phosphatase        Psph
# 1415674_a_at            trafficking protein particle complex 4     Trappc4
#
#              ENTREZ_GENE_ID        RefSeq Transcript ID  \
# ID
# 1415670_at            54161     NM_017477 /// NM_201244
# 1415671_at            11972                   NM_013477
# 1415672_at            57437  NM_001042484 /// NM_020585
# 1415673_at           100678                   NM_133900
# 1415674_a_at          60409                   NM_021789
#
#                                Gene Ontology Biological Process  \
# ID
# 1415670_at    0006810 // transport // inferred from electron...
# 1415671_at    0006810 // transport // inferred from electron...
# 1415672_at    0006893 // Golgi to plasma membrane transport ...
# 1415673_at    0006563 // L-serine metabolic process // infer...
# 1415674_a_at  0006810 // transport // inferred from electron...
#
#                                Gene Ontology Cellular Component  \
# ID
# 1415670_at    0000139 // Golgi membrane // inferred from ele...
# 1415671_at    0005769 // early endosome // inferred from dir...
# 1415672_at    0000139 // Golgi membrane // not recorded /// ...
# 1415673_at    0005737 // cytoplasm // inferred from sequence...
# 1415674_a_at  0005783 // endoplasmic reticulum // inferred f...
#
#                                Gene Ontology Molecular Function Gene symbol
# ID
# 1415670_at    0005198 // structural molecule activity // inf...        Copg
# 1415671_at    0005515 // protein binding // inferred from el...    Atp6v0d1
# 1415672_at                                                  NaN      Golga7
# 1415673_at    0000287 // magnesium ion binding // inferred f...        Psph
# 1415674_a_at  0005515 // protein binding // inferred from el...     Trappc4

# %%
merged = pd.merge(data, probes, left_index=True, right_index=True)
merged.head()
# Out:
#               Th1_culture_APC_alone  \
# 1415670_at                  5.36103
# 1415671_at                  7.83079
# 1415672_at                  9.25071
# 1415673_at                  5.22896
# 1415674_a_at                7.86652
#
#               Th1_culture_HA_stimulation_biological_replicate_1  \
# 1415670_at                                              9.56740
# 1415671_at                                             10.75100
# 1415672_at                                             11.48460
# 1415673_at                                              9.64953
# 1415674_a_at                                           10.13850
#
#               Th1_culture_HA_stimulation_biological_replicate_2  \
# 1415670_at                                              8.98196
# 1415671_at                                             10.39350
# 1415672_at                                             11.42510
# 1415673_at                                              9.56406
# 1415674_a_at                                           10.31280
#
#               Th1_culture_PBAB_stimulation_biological_replicate_1  \
# 1415670_at                                              9.88006
# 1415671_at                                              9.88999
# 1415672_at                                             11.35420
# 1415673_at                                             10.57580
# 1415674_a_at                                           10.11220
#
#               Th1_culture_PBAB_stimulation_biological_replicate_2  \
# 1415670_at                                              9.03798
# 1415671_at                                              9.32849
# 1415672_at                                             11.48560
# 1415673_at                                             10.49710
# 1415674_a_at                                           10.22730
#
#               Th9_culture_APC_alone  \
# 1415670_at                  6.61494
# 1415671_at                  8.19419
# 1415672_at                  8.67666
# 1415673_at                  6.24539
# 1415674_a_at                6.69347
#
#               Th9_culture_HA_stimulation_biological_replicate_1  \
# 1415670_at                                              9.63085
# 1415671_at                                             10.46350
# 1415672_at                                             11.48840
# 1415673_at                                              9.81732
# 1415674_a_at                                           10.13850
#
#               Th9_culture_HA_stimulation_biological_replicate_2  \
# 1415670_at                                              8.72623
# 1415671_at                                              9.88348
# 1415672_at                                             11.48180
# 1415673_at                                              9.77528
# 1415674_a_at                                           10.26340
#
#               Th9_culture_PBAB_stimulation_biological_replicate_1  \
# 1415670_at                                              9.77176
# 1415671_at                                              9.85894
# 1415672_at                                             11.68790
# 1415673_at                                             10.28410
# 1415674_a_at                                            9.93280
#
#               Th9_culture_PBAB_stimulation_biological_replicate_2     ...      \
# 1415670_at                                              9.23255       ...
# 1415671_at                                              9.71440       ...
# 1415672_at                                             11.68050       ...
# 1415673_at                                             10.12910       ...
# 1415674_a_at                                           10.15540       ...
#
#                                              Target Description  \
# 1415670_at    gb:BC024686.1 /DB_XREF=gi:19354080 /FEA=FLmRNA...
# 1415671_at    gb:NM_013477.1 /DB_XREF=gi:7304908 /GEN=Atp6v0...
# 1415672_at    gb:NM_020585.1 /DB_XREF=gi:10181207 /GEN=AB041...
# 1415673_at    gb:NM_133900.1 /DB_XREF=gi:19527115 /GEN=AI480...
# 1415674_a_at  gb:NM_021789.1 /DB_XREF=gi:11140824 /GEN=Sbdn ...
#
#               Representative Public ID  \
# 1415670_at                    BC024686
# 1415671_at                   NM_013477
# 1415672_at                   NM_020585
# 1415673_at                   NM_133900
# 1415674_a_at                 NM_021789
#
#                                                     Gene Title  Gene Symbol  \
# 1415670_at             coatomer protein complex, subunit gamma         Copg
# 1415671_at    ATPase, H+ transporting, lysosomal V0 subunit D1     Atp6v0d1
# 1415672_at            golgi autoantigen, golgin subfamily a, 7       Golga7
# 1415673_at                           phosphoserine phosphatase         Psph
# 1415674_a_at            trafficking protein particle complex 4      Trappc4
#
#               ENTREZ_GENE_ID        RefSeq Transcript ID  \
# 1415670_at             54161     NM_017477 /// NM_201244
# 1415671_at             11972                   NM_013477
# 1415672_at             57437  NM_001042484 /// NM_020585
# 1415673_at            100678                   NM_133900
# 1415674_a_at           60409                   NM_021789
#
#                                Gene Ontology Biological Process  \
# 1415670_at    0006810 // transport // inferred from electron...
# 1415671_at    0006810 // transport // inferred from electron...
# 1415672_at    0006893 // Golgi to plasma membrane transport ...
# 1415673_at    0006563 // L-serine metabolic process // infer...
# 1415674_a_at  0006810 // transport // inferred from electron...
#
#                                Gene Ontology Cellular Component  \
# 1415670_at    0000139 // Golgi membrane // inferred from ele...
# 1415671_at    0005769 // early endosome // inferred from dir...
# 1415672_at    0000139 // Golgi membrane // not recorded /// ...
# 1415673_at    0005737 // cytoplasm // inferred from sequence...
# 1415674_a_at  0005783 // endoplasmic reticulum // inferred f...
#
#                                Gene Ontology Molecular Function Gene symbol
# 1415670_at    0005198 // structural molecule activity // inf...        Copg
# 1415671_at    0005515 // protein binding // inferred from el...    Atp6v0d1
# 1415672_at                                                  NaN      Golga7
# 1415673_at    0000287 // magnesium ion binding // inferred f...        Psph
# 1415674_a_at  0005515 // protein binding // inferred from el...     Trappc4
#
# [5 rows x 31 columns]

# %%
subdata = merged[['Gene symbol'] + headers]
filename = 'data/{}_gene_values.txt'.format(gse)
subdata.to_csv(filename,
               header=True, index=False, sep='\t')
scores = subprocess.check_output('python ../calculate_activation_signature_score.py -f ' +
                                '{}'.format(filename), shell=True)
print(scores)
# Out:
# b'Activation scores:\nth1_culture_apc_alone                                  -1.000000\nth1_culture_ha_stimulation_biological_replicate_1       0.190754\nth1_culture_ha_stimulation_biological_replicate_2       0.094353\nth1_culture_pbab_stimulation_biological_replicate_1     0.425176\nth1_culture_pbab_stimulation_biological_replicate_2     0.344661\nth9_culture_apc_alone                                  -0.918348\nth9_culture_ha_stimulation_biological_replicate_1       0.113425\nth9_culture_ha_stimulation_biological_replicate_2       0.046879\nth9_culture_pbab_stimulation_biological_replicate_1     0.416221\nth9_culture_pbab_stimulation_biological_replicate_2     0.340805\nth17_culture_apc_alone                                 -0.859104\nth17_culture_ha_stimulation_biological_replicate_1      0.150690\nth17_culture_ha_stimulation_biological_replicate_2      0.105846\nth17_culture_pbab_stimulation_biological_replicate_1    0.288749\nth17_culture_pbab_stimulation_biological_replicate_2    0.259892\ndtype: float64\n'

# %%
import sys
sys.path.append('../')
from calculate_activation_signature_score import ActivationOptionParser

parser = ActivationOptionParser()
filename = 'data/{}_gene_values.txt'.format(gse)
scores = parser.scores_from_file(filename)

# %%
# Irregular numbers of samples-- calc means and std.
means = [scores[0],
         np.mean(scores[1:3]),
         np.mean(scores[3:5]),
         scores[5],
         np.mean(scores[6:8]),
         np.mean(scores[8:10]),
         scores[10],
         np.mean(scores[11:13]),
         np.mean(scores[13:15]),
         ]
stddev = [0,
         np.std(scores[1:3]),
         np.std(scores[3:5]),
         0,
         np.std(scores[6:8]),
         np.std(scores[8:10]),
         0,
         np.std(scores[11:13]),
         np.std(scores[13:15]),
         ]

# %%
# Set up colors
colors = sns.color_palette("GnBu_d", len(means)//3)


# Get sets of two
triples = zip(colors, colors, colors)

# Flatten
triples = [item for sublist in triples for item in sublist]

# %%
x_range = range(0, len(means))
plt.figure()

bars = plt.bar([x + .2 for x in x_range], means, color=list(triples))
plt.errorbar([x + .6 for x in x_range], means, linewidth=0,
        yerr=stddev, ecolor='black', elinewidth=.5, capsize=20)

# Add hatching on every other bar
for i, bar in enumerate(bars):
    if i%3 == 2:
        bar.set_hatch('//')
    elif i%3 == 1:
        bar.set_hatch('..')
    else:
        bar.set_hatch(None)

# Custom legend
clear_patch = plt.Rectangle((0, 0), 1, 1, fc="white")
dot_patch = plt.Rectangle((0, 0), 1, 1, fc="white", hatch ='..')
hatch_patch = plt.Rectangle((0, 0), 1, 1, fc="white", hatch ='//')

plt.legend([clear_patch, dot_patch, hatch_patch], 
           ['Culture only', 'APCs + Ag', 'aCD3 + aCD28'], loc='upper left')


# Label scores above bars
for i, score in enumerate(means):
    if score < 0:
        align = 'top'
        height = score - .05
    else: 
        align = 'bottom'
        height = score + .05
    plt.text(i + .6, height, '%.2f' % score,
                ha='center', va=align, fontsize=14)

plt.ylim([-1.1, 1.1])
plt.xlim([0, len(means) + .2])
plt.ylabel('Activation Signature Score')

plt.xticks([x + .6 for x in x_range], ['']*len(means))
for i, label in enumerate(labels):
    plt.text(3*i + 1.5, plt.ylim()[0]*1.1, label, fontsize=14)

title = 'Activation Signature Scores: {}'.format(gse)
plt.title(title)
plt.savefig('figures/{}.png'.format(title.replace(' ', '_')), bbox_inches='tight')
