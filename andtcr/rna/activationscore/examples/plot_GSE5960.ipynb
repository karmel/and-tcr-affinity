# %%
'''
We have a set of ~300 genes with names and scores.

Given a microarray .txt file, normalize, extract the genes of interest,
and determine score.
'''
# Out:
# '\nWe have a set of ~300 genes with names and scores.\n\nGiven a microarray .txt file, normalize, extract the genes of interest,\nand determine score.\n'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import subprocess
import numpy as np

# %%
sns.set_context('poster')

# %%
gse = 'GSE5960'
fname = 'data/{}_series_matrix.txt'.format(gse)

# Comment lines begin with a variety of characters. Figure out where to start manually.
start_at = 0
for i, line in enumerate(open(fname).readlines()):
    if line.startswith('!Sample_title'):
        headers = line.split('\t')[1:]
    elif line.startswith('!Series_platform_id'):
        platform = line.split('\t')[1].strip().strip('"')
    elif line[0] not in ('!', '#', '^', '\n'):
        start_at = i
        break
data = pd.io.parsers.read_csv(fname, 
                sep='\t', header=start_at-1, index_col=0)
data = data.fillna(0)
headers = [h.strip().strip('"').replace(' ','_').replace(',','') for h in headers]
print(platform)
print(headers)
data.head()
# Out:
# GPL81
# ['Control1', 'Anergic1', 'Control2', 'Anergic2']
#            GSM138549  GSM138550  GSM138551  GSM138552
# ID_REF
# 100001_at    11877.6     9328.6     7281.3     5290.3
# 100002_at       58.8       33.5       37.6       84.8
# 100003_at       10.0       64.8       68.6       92.8
# 100004_at      219.7      175.7      252.3      178.1
# 100005_at      360.4      373.8      412.8      403.1

# %%
headers_ordered = ['Control1', 'Control2', 'Anergic1', 'Anergic2']
labels = ['Naive', 'Anergic']

# %%
# Rename our columns
data.columns = headers
data.head()
# Out:
#            Control1  Anergic1  Control2  Anergic2
# ID_REF
# 100001_at   11877.6    9328.6    7281.3    5290.3
# 100002_at      58.8      33.5      37.6      84.8
# 100003_at      10.0      64.8      68.6      92.8
# 100004_at     219.7     175.7     252.3     178.1
# 100005_at     360.4     373.8     412.8     403.1

# %%
# Get gene names
fname = 'data/{}.txt'.format(platform)
start_at = 0
for i, line in enumerate(open(fname).readlines()):
    if line[0] not in ('!', '#', '^', '\s', '\n'):
        start_at = i
        break
probes = pd.io.parsers.read_csv(fname, 
            sep='\t', header=start_at, index_col=0)
probes.head()
# Out:
#              GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# ID
# 100001_at    M18228     NaN            Mus musculus     Jun 9, 2011
# 100002_at    X70393     NaN            Mus musculus     Jun 9, 2011
# 100003_at    D38216     NaN            Mus musculus     Jun 9, 2011
# 100004_at  AW120890     NaN            Mus musculus     Jun 9, 2011
# 100005_at    X92346     NaN            Mus musculus     Jun 9, 2011
#
#                 Sequence Type Sequence Source  \
# ID
# 100001_at  Consensus sequence         GenBank
# 100002_at  Consensus sequence         GenBank
# 100003_at  Consensus sequence         GenBank
# 100004_at  Consensus sequence         GenBank
# 100005_at  Consensus sequence         GenBank
#
#                                           Target Description  \
# ID
# 100001_at  Cluster Incl M18228:CD3 antigen, gamma polypep...
# 100002_at  Cluster Incl X70393:Inter-alpha trypsin inhibi...
# 100003_at  Cluster Incl D38216:Mouse RyR1 mRNA for skelet...
# 100004_at  Cluster Incl AW120890:UI-M-BH2.3-aob-a-12-0-UI...
# 100005_at  Cluster Incl X92346:Tnf receptor associated fa...
#
#           Representative Public ID  \
# ID
# 100001_at                   M18228
# 100002_at                   X70393
# 100003_at                   D38216
# 100004_at                 AW120890
# 100005_at                   X92346
#
#                                              Gene Title Gene Symbol  \
# ID
# 100001_at                CD3 antigen, gamma polypeptide        Cd3g
# 100002_at  inter-alpha trypsin inhibitor, heavy chain 3       Itih3
# 100003_at         ryanodine receptor 1, skeletal muscle        Ryr1
# 100004_at                  integrator complex subunit 7       Ints7
# 100005_at              TNF receptor associated factor 4       Traf4
#
#           ENTREZ_GENE_ID RefSeq Transcript ID  \
# ID
# 100001_at          12502            NM_009850
# 100002_at          16426            NM_008407
# 100003_at          20190            NM_009109
# 100004_at          77065            NM_178632
# 100005_at          22032            NM_009423
#
#                             Gene Ontology Biological Process  \
# ID
# 100001_at  0007163 // establishment or maintenance of cel...
# 100002_at  0010466 // negative regulation of peptidase ac...
# 100003_at  0001666 // response to hypoxia // inferred fro...
# 100004_at  0016180 // snRNA processing // inferred from e...
# 100005_at  0006915 // apoptosis // inferred from electron...
#
#                             Gene Ontology Cellular Component  \
# ID
# 100001_at  0016020 // membrane // inferred from electroni...
# 100002_at  0005576 // extracellular region // inferred fr...
# 100003_at  0005624 // membrane fraction // inferred from ...
# 100004_at  0005634 // nucleus // inferred from electronic...
# 100005_at  0005634 // nucleus // inferred from electronic...
#
#                             Gene Ontology Molecular Function
# ID
# 100001_at  0004872 // receptor activity // inferred from ...
# 100002_at  0004867 // serine-type endopeptidase inhibitor...
# 100003_at  0004872 // receptor activity // inferred from ...
# 100004_at  0005488 // binding // inferred from electronic...
# 100005_at  0004842 // ubiquitin-protein ligase activity /...

# %%
probes['Gene symbol'] = probes['Gene Symbol']
probes.head()
# Out:
#              GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# ID
# 100001_at    M18228     NaN            Mus musculus     Jun 9, 2011
# 100002_at    X70393     NaN            Mus musculus     Jun 9, 2011
# 100003_at    D38216     NaN            Mus musculus     Jun 9, 2011
# 100004_at  AW120890     NaN            Mus musculus     Jun 9, 2011
# 100005_at    X92346     NaN            Mus musculus     Jun 9, 2011
#
#                 Sequence Type Sequence Source  \
# ID
# 100001_at  Consensus sequence         GenBank
# 100002_at  Consensus sequence         GenBank
# 100003_at  Consensus sequence         GenBank
# 100004_at  Consensus sequence         GenBank
# 100005_at  Consensus sequence         GenBank
#
#                                           Target Description  \
# ID
# 100001_at  Cluster Incl M18228:CD3 antigen, gamma polypep...
# 100002_at  Cluster Incl X70393:Inter-alpha trypsin inhibi...
# 100003_at  Cluster Incl D38216:Mouse RyR1 mRNA for skelet...
# 100004_at  Cluster Incl AW120890:UI-M-BH2.3-aob-a-12-0-UI...
# 100005_at  Cluster Incl X92346:Tnf receptor associated fa...
#
#           Representative Public ID  \
# ID
# 100001_at                   M18228
# 100002_at                   X70393
# 100003_at                   D38216
# 100004_at                 AW120890
# 100005_at                   X92346
#
#                                              Gene Title Gene Symbol  \
# ID
# 100001_at                CD3 antigen, gamma polypeptide        Cd3g
# 100002_at  inter-alpha trypsin inhibitor, heavy chain 3       Itih3
# 100003_at         ryanodine receptor 1, skeletal muscle        Ryr1
# 100004_at                  integrator complex subunit 7       Ints7
# 100005_at              TNF receptor associated factor 4       Traf4
#
#           ENTREZ_GENE_ID RefSeq Transcript ID  \
# ID
# 100001_at          12502            NM_009850
# 100002_at          16426            NM_008407
# 100003_at          20190            NM_009109
# 100004_at          77065            NM_178632
# 100005_at          22032            NM_009423
#
#                             Gene Ontology Biological Process  \
# ID
# 100001_at  0007163 // establishment or maintenance of cel...
# 100002_at  0010466 // negative regulation of peptidase ac...
# 100003_at  0001666 // response to hypoxia // inferred fro...
# 100004_at  0016180 // snRNA processing // inferred from e...
# 100005_at  0006915 // apoptosis // inferred from electron...
#
#                             Gene Ontology Cellular Component  \
# ID
# 100001_at  0016020 // membrane // inferred from electroni...
# 100002_at  0005576 // extracellular region // inferred fr...
# 100003_at  0005624 // membrane fraction // inferred from ...
# 100004_at  0005634 // nucleus // inferred from electronic...
# 100005_at  0005634 // nucleus // inferred from electronic...
#
#                             Gene Ontology Molecular Function Gene symbol
# ID
# 100001_at  0004872 // receptor activity // inferred from ...        Cd3g
# 100002_at  0004867 // serine-type endopeptidase inhibitor...       Itih3
# 100003_at  0004872 // receptor activity // inferred from ...        Ryr1
# 100004_at  0005488 // binding // inferred from electronic...       Ints7
# 100005_at  0004842 // ubiquitin-protein ligase activity /...       Traf4

# %%
merged = pd.merge(data, probes, left_index=True, right_index=True)
merged.head()
# Out:
#            Control1  Anergic1  Control2  Anergic2    GB_ACC SPOT_ID  \
# 100001_at   11877.6    9328.6    7281.3    5290.3    M18228     NaN
# 100002_at      58.8      33.5      37.6      84.8    X70393     NaN
# 100003_at      10.0      64.8      68.6      92.8    D38216     NaN
# 100004_at     219.7     175.7     252.3     178.1  AW120890     NaN
# 100005_at     360.4     373.8     412.8     403.1    X92346     NaN
#
#           Species Scientific Name Annotation Date       Sequence Type  \
# 100001_at            Mus musculus     Jun 9, 2011  Consensus sequence
# 100002_at            Mus musculus     Jun 9, 2011  Consensus sequence
# 100003_at            Mus musculus     Jun 9, 2011  Consensus sequence
# 100004_at            Mus musculus     Jun 9, 2011  Consensus sequence
# 100005_at            Mus musculus     Jun 9, 2011  Consensus sequence
#
#           Sequence Source                                 Target Description  \
# 100001_at         GenBank  Cluster Incl M18228:CD3 antigen, gamma polypep...
# 100002_at         GenBank  Cluster Incl X70393:Inter-alpha trypsin inhibi...
# 100003_at         GenBank  Cluster Incl D38216:Mouse RyR1 mRNA for skelet...
# 100004_at         GenBank  Cluster Incl AW120890:UI-M-BH2.3-aob-a-12-0-UI...
# 100005_at         GenBank  Cluster Incl X92346:Tnf receptor associated fa...
#
#           Representative Public ID  \
# 100001_at                   M18228
# 100002_at                   X70393
# 100003_at                   D38216
# 100004_at                 AW120890
# 100005_at                   X92346
#
#                                              Gene Title Gene Symbol  \
# 100001_at                CD3 antigen, gamma polypeptide        Cd3g
# 100002_at  inter-alpha trypsin inhibitor, heavy chain 3       Itih3
# 100003_at         ryanodine receptor 1, skeletal muscle        Ryr1
# 100004_at                  integrator complex subunit 7       Ints7
# 100005_at              TNF receptor associated factor 4       Traf4
#
#           ENTREZ_GENE_ID RefSeq Transcript ID  \
# 100001_at          12502            NM_009850
# 100002_at          16426            NM_008407
# 100003_at          20190            NM_009109
# 100004_at          77065            NM_178632
# 100005_at          22032            NM_009423
#
#                             Gene Ontology Biological Process  \
# 100001_at  0007163 // establishment or maintenance of cel...
# 100002_at  0010466 // negative regulation of peptidase ac...
# 100003_at  0001666 // response to hypoxia // inferred fro...
# 100004_at  0016180 // snRNA processing // inferred from e...
# 100005_at  0006915 // apoptosis // inferred from electron...
#
#                             Gene Ontology Cellular Component  \
# 100001_at  0016020 // membrane // inferred from electroni...
# 100002_at  0005576 // extracellular region // inferred fr...
# 100003_at  0005624 // membrane fraction // inferred from ...
# 100004_at  0005634 // nucleus // inferred from electronic...
# 100005_at  0005634 // nucleus // inferred from electronic...
#
#                             Gene Ontology Molecular Function Gene symbol
# 100001_at  0004872 // receptor activity // inferred from ...        Cd3g
# 100002_at  0004867 // serine-type endopeptidase inhibitor...       Itih3
# 100003_at  0004872 // receptor activity // inferred from ...        Ryr1
# 100004_at  0005488 // binding // inferred from electronic...       Ints7
# 100005_at  0004842 // ubiquitin-protein ligase activity /...       Traf4

# %%
subdata = merged[['Gene symbol'] + headers_ordered]
filename = 'data/{}_gene_values.txt'.format(gse)
subdata.to_csv(filename,
               header=True, index=False, sep='\t')
scores = subprocess.check_output('python ../calculate_activation_signature_score.py -f ' +
                                '{}'.format(filename), shell=True)
print(scores)
# Out:
# b'Activation scores:\ncontrol1    134.601639\ncontrol2     -0.332077\nanergic1    -18.568723\nanergic2   -115.700839\ndtype: float64\n'

# %%
import sys
sys.path.append('../')
from calculate_activation_signature_score import ActivationOptionParser

parser = ActivationOptionParser()
filename = 'data/{}_gene_values.txt'.format(gse)
scores = parser.scores_from_file(filename)

# %%
# Irregular numbers of samples-- calc means and std.
groups = [scores[i:i+2] for i in range(0, len(scores),2)]
means = [np.mean(score_group) for score_group in groups]
stddev = [np.std(score_group) for score_group in groups]

# %%
# Set up colors
colorset = sns.color_palette("GnBu_d", len(means))

# %%
x_range = range(0, len(means))
plt.figure()

bars = plt.bar([x + .2 for x in x_range], means, color=list(colorset))
plt.errorbar([x + .6 for x in x_range], means, linewidth=0,
        yerr=stddev, ecolor='black', elinewidth=.5, capsize=20)


# Label scores above bars
for i, score in enumerate(means):
    if score < 0:
        align = 'top'
        height = score - .1
    else: 
        align = 'bottom'
        height = score + .5
    plt.text(i + .6, height, '%.2f' % score,
                ha='center', va=align, fontsize=14)

plt.xlim([0, len(means) + .2])
plt.ylabel('Activation Signature Score')

plt.xticks([x + .6 for x in x_range], labels)

title = 'Activation Signature Scores: {}'.format(gse)
plt.title(title)
plt.savefig('figures/{}.png'.format(title.replace(' ', '_')), bbox_inches='tight')

# %%
data.corr()
# Out:
#           Control1  Anergic1  Control2  Anergic2
# Control1  1.000000  0.946256  0.958429  0.939593
# Anergic1  0.946256  1.000000  0.907511  0.977526
# Control2  0.958429  0.907511  1.000000  0.935466
# Anergic2  0.939593  0.977526  0.935466  1.000000
