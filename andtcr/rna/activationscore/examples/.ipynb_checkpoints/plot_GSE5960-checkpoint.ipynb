# %%
'''
We have a set of ~300 genes with names and scores.

Given a microarray .txt file, normalize, extract the genes of interest,
and determine score.
'''
# Out:
# '\nWe have a set of ~300 genes with names and scores.\n\nGiven a microarray .txt file, normalize, extract the genes of interest,\nand determine score.\n'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import subprocess
import numpy as np

# %%
sns.set_context('poster')

# %%
gse = 'GSE5960'
fname = 'data/{}_series_matrix.txt'.format(gse)

# Comment lines begin with a variety of characters. Figure out where to start manually.
start_at = 0
for i, line in enumerate(open(fname).readlines()):
    if line.startswith('!Sample_title'):
        headers = line.split('\t')[1:]
    elif line.startswith('!Series_platform_id'):
        platform = line.split('\t')[1].strip().strip('"')
    elif line[0] not in ('!', '#', '^', '\n'):
        start_at = i
        break
data = pd.io.parsers.read_csv(fname, 
                sep='\t', header=start_at-1, index_col=0)
data = data.fillna(0)
headers = [h.strip().strip('"').replace(' ','_').replace(',','') for h in headers]
print(platform)
print(headers)
data.head()
# Out:
# GPL11202
# ['Tnaive_1', 'Tnaive_2', 'Tnaive_3', 'Th1_1', 'Th1_2', 'Th1_3', 'Th17_1', 'Th17_2', 'Th17_3']
#                  GSM1402510  GSM1402511  GSM1402512  GSM1402513  GSM1402514  \
# ID_REF
# (+)E1A_r60_1      -0.027936    0.471502    0.027936   -0.548860   -0.182672
# (+)E1A_r60_3       0.194148    0.343686    0.301563    0.033942    0.297015
# (+)E1A_r60_a104    0.293437    0.466183    0.077216    0.494470    0.404419
# (+)E1A_r60_a107    0.246303    0.433899   -0.101953   -0.625384   -0.063508
# (+)E1A_r60_a135   -0.010316    0.463204    0.050079   -0.426844   -0.193603
#
#                  GSM1402515  GSM1402516  GSM1402517  GSM1402518
# ID_REF
# (+)E1A_r60_1      -0.366868   -0.351189    0.097913    0.389798
# (+)E1A_r60_3      -0.246925   -0.387853   -0.033942   -0.218456
# (+)E1A_r60_a104   -0.074076   -0.179874   -0.093488    0.074075
# (+)E1A_r60_a107   -0.335678   -0.617187    0.063508    0.791529
# (+)E1A_r60_a135   -0.417910   -0.310529    0.091082    0.498606

# %%
labels = ['Naive', 'Th1', 'Th17']

# %%
# Rename our columns
data.columns = headers
data.head()
# Out:
#                  Tnaive_1  Tnaive_2  Tnaive_3     Th1_1     Th1_2     Th1_3  \
# ID_REF
# (+)E1A_r60_1    -0.027936  0.471502  0.027936 -0.548860 -0.182672 -0.366868
# (+)E1A_r60_3     0.194148  0.343686  0.301563  0.033942  0.297015 -0.246925
# (+)E1A_r60_a104  0.293437  0.466183  0.077216  0.494470  0.404419 -0.074076
# (+)E1A_r60_a107  0.246303  0.433899 -0.101953 -0.625384 -0.063508 -0.335678
# (+)E1A_r60_a135 -0.010316  0.463204  0.050079 -0.426844 -0.193603 -0.417910
#
#                    Th17_1    Th17_2    Th17_3
# ID_REF
# (+)E1A_r60_1    -0.351189  0.097913  0.389798
# (+)E1A_r60_3    -0.387853 -0.033942 -0.218456
# (+)E1A_r60_a104 -0.179874 -0.093488  0.074075
# (+)E1A_r60_a107 -0.617187  0.063508  0.791529
# (+)E1A_r60_a135 -0.310529  0.091082  0.498606

# %%
# Get gene names
fname = 'data/{}.txt'.format(platform)
start_at = 0
for i, line in enumerate(open(fname).readlines()):
    if line[0] not in ('!', '#', '^', '\s', '\n'):
        start_at = i
        break
probes = pd.io.parsers.read_csv(fname, 
            sep='\t', header=start_at, index_col=0)
probes.head()
# Out:
#                          SPOT_ID CONTROL_TYPE REFSEQ GB_ACC  GENE GENE_SYMBOL  \
# ID
# (+)E1A_r60_1        (+)E1A_r60_1          pos    NaN    NaN   NaN         NaN
# (+)E1A_r60_3        (+)E1A_r60_3          pos    NaN    NaN   NaN         NaN
# (+)E1A_r60_a104  (+)E1A_r60_a104          pos    NaN    NaN   NaN         NaN
# (+)E1A_r60_a107  (+)E1A_r60_a107          pos    NaN    NaN   NaN         NaN
# (+)E1A_r60_a135  (+)E1A_r60_a135          pos    NaN    NaN   NaN         NaN
#
#                 GENE_NAME UNIGENE_ID ENSEMBL_ID  TIGR_ID ACCESSION_STRING  \
# ID
# (+)E1A_r60_1          NaN        NaN        NaN      NaN              NaN
# (+)E1A_r60_3          NaN        NaN        NaN      NaN              NaN
# (+)E1A_r60_a104       NaN        NaN        NaN      NaN              NaN
# (+)E1A_r60_a107       NaN        NaN        NaN      NaN              NaN
# (+)E1A_r60_a135       NaN        NaN        NaN      NaN              NaN
#
#                 CHROMOSOMAL_LOCATION CYTOBAND DESCRIPTION GO_ID SEQUENCE
# ID
# (+)E1A_r60_1                     NaN      NaN         NaN   NaN      NaN
# (+)E1A_r60_3                     NaN      NaN         NaN   NaN      NaN
# (+)E1A_r60_a104                  NaN      NaN         NaN   NaN      NaN
# (+)E1A_r60_a107                  NaN      NaN         NaN   NaN      NaN
# (+)E1A_r60_a135                  NaN      NaN         NaN   NaN      NaN

# %%
probes['Gene symbol'] = probes['GENE_SYMBOL']
probes.head()
# Out:
#                          SPOT_ID CONTROL_TYPE REFSEQ GB_ACC  GENE GENE_SYMBOL  \
# ID
# (+)E1A_r60_1        (+)E1A_r60_1          pos    NaN    NaN   NaN         NaN
# (+)E1A_r60_3        (+)E1A_r60_3          pos    NaN    NaN   NaN         NaN
# (+)E1A_r60_a104  (+)E1A_r60_a104          pos    NaN    NaN   NaN         NaN
# (+)E1A_r60_a107  (+)E1A_r60_a107          pos    NaN    NaN   NaN         NaN
# (+)E1A_r60_a135  (+)E1A_r60_a135          pos    NaN    NaN   NaN         NaN
#
#                 GENE_NAME UNIGENE_ID ENSEMBL_ID  TIGR_ID ACCESSION_STRING  \
# ID
# (+)E1A_r60_1          NaN        NaN        NaN      NaN              NaN
# (+)E1A_r60_3          NaN        NaN        NaN      NaN              NaN
# (+)E1A_r60_a104       NaN        NaN        NaN      NaN              NaN
# (+)E1A_r60_a107       NaN        NaN        NaN      NaN              NaN
# (+)E1A_r60_a135       NaN        NaN        NaN      NaN              NaN
#
#                 CHROMOSOMAL_LOCATION CYTOBAND DESCRIPTION GO_ID SEQUENCE  \
# ID
# (+)E1A_r60_1                     NaN      NaN         NaN   NaN      NaN
# (+)E1A_r60_3                     NaN      NaN         NaN   NaN      NaN
# (+)E1A_r60_a104                  NaN      NaN         NaN   NaN      NaN
# (+)E1A_r60_a107                  NaN      NaN         NaN   NaN      NaN
# (+)E1A_r60_a135                  NaN      NaN         NaN   NaN      NaN
#
#                 Gene symbol
# ID
# (+)E1A_r60_1            NaN
# (+)E1A_r60_3            NaN
# (+)E1A_r60_a104         NaN
# (+)E1A_r60_a107         NaN
# (+)E1A_r60_a135         NaN

# %%
merged = pd.merge(data, probes, left_index=True, right_index=True)
merged.head()
# Out:
#                  Tnaive_1  Tnaive_2  Tnaive_3     Th1_1     Th1_2     Th1_3  \
# (+)E1A_r60_1    -0.027936  0.471502  0.027936 -0.548860 -0.182672 -0.366868
# (+)E1A_r60_3     0.194148  0.343686  0.301563  0.033942  0.297015 -0.246925
# (+)E1A_r60_a104  0.293437  0.466183  0.077216  0.494470  0.404419 -0.074076
# (+)E1A_r60_a107  0.246303  0.433899 -0.101953 -0.625384 -0.063508 -0.335678
# (+)E1A_r60_a135 -0.010316  0.463204  0.050079 -0.426844 -0.193603 -0.417910
#
#                    Th17_1    Th17_2    Th17_3          SPOT_ID     ...      \
# (+)E1A_r60_1    -0.351189  0.097913  0.389798     (+)E1A_r60_1     ...
# (+)E1A_r60_3    -0.387853 -0.033942 -0.218456     (+)E1A_r60_3     ...
# (+)E1A_r60_a104 -0.179874 -0.093488  0.074075  (+)E1A_r60_a104     ...
# (+)E1A_r60_a107 -0.617187  0.063508  0.791529  (+)E1A_r60_a107     ...
# (+)E1A_r60_a135 -0.310529  0.091082  0.498606  (+)E1A_r60_a135     ...
#
#                 UNIGENE_ID ENSEMBL_ID TIGR_ID  ACCESSION_STRING  \
# (+)E1A_r60_1           NaN        NaN     NaN               NaN
# (+)E1A_r60_3           NaN        NaN     NaN               NaN
# (+)E1A_r60_a104        NaN        NaN     NaN               NaN
# (+)E1A_r60_a107        NaN        NaN     NaN               NaN
# (+)E1A_r60_a135        NaN        NaN     NaN               NaN
#
#                 CHROMOSOMAL_LOCATION CYTOBAND DESCRIPTION GO_ID  SEQUENCE  \
# (+)E1A_r60_1                     NaN      NaN         NaN   NaN       NaN
# (+)E1A_r60_3                     NaN      NaN         NaN   NaN       NaN
# (+)E1A_r60_a104                  NaN      NaN         NaN   NaN       NaN
# (+)E1A_r60_a107                  NaN      NaN         NaN   NaN       NaN
# (+)E1A_r60_a135                  NaN      NaN         NaN   NaN       NaN
#
#                 Gene symbol
# (+)E1A_r60_1            NaN
# (+)E1A_r60_3            NaN
# (+)E1A_r60_a104         NaN
# (+)E1A_r60_a107         NaN
# (+)E1A_r60_a135         NaN
#
# [5 rows x 26 columns]

# %%
subdata = merged[['Gene symbol'] + headers]
filename = 'data/{}_gene_values.txt'.format(gse)
subdata.to_csv(filename,
               header=True, index=False, sep='\t')
scores = subprocess.check_output('python ../calculate_activation_signature_score.py -f ' +
                                '{}'.format(filename), shell=True)
print(scores)
# Out:
# b'Activation scores:\ntnaive_1    0.268835\ntnaive_2    0.506661\ntnaive_3    0.666681\nth1_1      -0.163618\nth1_2      -0.002833\nth1_3       0.045818\nth17_1     -0.958722\nth17_2     -0.203729\nth17_3     -0.159093\ndtype: float64\n'

# %%
import sys
sys.path.append('../')
from calculate_activation_signature_score import ActivationOptionParser

parser = ActivationOptionParser()
filename = 'data/{}_gene_values.txt'.format(gse)
scores = parser.scores_from_file(filename)

# %%
# Irregular numbers of samples-- calc means and std.
groups = [scores[i:i+3] for i in range(0, len(scores),3)]
means = [np.mean(score_group) for score_group in groups]
stddev = [np.std(score_group) for score_group in groups]

# %%
# Set up colors
colorset = sns.color_palette("GnBu_d", len(means))

# %%
x_range = range(0, len(means))
plt.figure()

bars = plt.bar([x + .2 for x in x_range], means, color=list(colorset))
plt.errorbar([x + .6 for x in x_range], means, linewidth=0,
        yerr=stddev, ecolor='black', elinewidth=.5, capsize=20)


# Label scores above bars
for i, score in enumerate(means):
    if score < 0:
        align = 'top'
        height = score - .1
    else: 
        align = 'bottom'
        height = score + .5
    plt.text(i + .6, height, '%.2f' % score,
                ha='center', va=align, fontsize=14)

plt.xlim([0, len(means) + .2])
plt.ylabel('Activation Signature Score')

plt.xticks([x + .6 for x in x_range], labels)

title = 'Activation Signature Scores: {}'.format(gse)
plt.title(title)
plt.savefig('figures/{}.png'.format(title.replace(' ', '_')), bbox_inches='tight')

# %%
data.corr()
# Out:
#           Tnaive_1  Tnaive_2  Tnaive_3     Th1_1     Th1_2     Th1_3  \
# Tnaive_1  1.000000  0.730041  0.690407 -0.056132 -0.101019 -0.159016
# Tnaive_2  0.730041  1.000000  0.704893 -0.038957 -0.093529 -0.163100
# Tnaive_3  0.690407  0.704893  1.000000 -0.178989 -0.188708 -0.174310
# Th1_1    -0.056132 -0.038957 -0.178989  1.000000  0.393676  0.309789
# Th1_2    -0.101019 -0.093529 -0.188708  0.393676  1.000000  0.355529
# Th1_3    -0.159016 -0.163100 -0.174310  0.309789  0.355529  1.000000
# Th17_1   -0.180040 -0.172074 -0.185658 -0.043555 -0.083578 -0.094104
# Th17_2   -0.214227 -0.207526 -0.232878 -0.089691 -0.016328 -0.102951
# Th17_3   -0.139431 -0.125492 -0.167736 -0.002464  0.005928 -0.102784
#
#             Th17_1    Th17_2    Th17_3
# Tnaive_1 -0.180040 -0.214227 -0.139431
# Tnaive_2 -0.172074 -0.207526 -0.125492
# Tnaive_3 -0.185658 -0.232878 -0.167736
# Th1_1    -0.043555 -0.089691 -0.002464
# Th1_2    -0.083578 -0.016328  0.005928
# Th1_3    -0.094104 -0.102951 -0.102784
# Th17_1    1.000000  0.396102  0.291566
# Th17_2    0.396102  1.000000  0.295349
# Th17_3    0.291566  0.295349  1.000000
