# %%
'''
Do the PCs defined in PCA correlated with AP-1 presence?
'''
# Out:
# '\nDo the PCs defined in PCA correlated with AP-1 presence?\n'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_context('poster')

# %%
filename = 'output/clusters/pca_genes_rna_and.txt'
pca = pd.io.parsers.read_csv(filename, 
                             sep='\t', 
                             header=0, index_col=0)
pca.head()
# Out:
#              chr      start        end strand  Length  Copies  \
# id
# NM_015779  chr10   79886312   79888216      +     913       1
# NM_025359  chr12   36014555   36042478      -    1915       1
# NM_177603  chr19   41845976   41848132      -    2154       1
# NM_027238   chr4   83220301   83324189      -    8742       1
# NR_105986   chr4  138316132  138316200      -      68       1
#
#                                        Annotation/Divergence  0-1uM-PCC-24h  \
# id
# NM_015779  Elane|Ela2|F430011M15Rik|NE|-|10 C1|10 39.72 c...          3.718
# NM_025359  Tspan13|1100001I23Rik|NET-6|Tm4sf13|RP23-282B1...         64.645
# NM_177603         Frat2|-|-|19 C3|19 35.33 cM|protein-coding          9.572
# NM_027238  Ttc39b|1810054D07Rik|9130422G05Rik|AI450603|AV...         15.858
# NR_105986                     Mir7019|mmu-mir-7019|-|-|ncRNA          9.244
#
#            100uM-K99A-24h  10uM-K99A-24h  10uM-PCC-24h  No-Peptide-24h  \
# id
# NM_015779          15.165         32.074         1.068          80.409
# NM_025359         153.193        146.362        63.563          48.460
# NM_177603           8.387         12.399         7.347          27.698
# NM_027238          12.156         10.709        19.425           7.475
# NR_105986           7.541          1.804         7.970          19.767
#
#           gene_name       pc1       pc2
# id
# NM_015779     Elane -0.005017 -0.001364
# NM_025359   Tspan13  0.001839 -0.058348
# NM_177603     Frat2 -0.001272  0.001754
# NM_027238    Ttc39b  0.000631  0.002537
# NR_105986   Mir7019 -0.000752  0.004714

# %%
filename = '../data/ap1_per_gene.txt'
ap1 = pd.io.parsers.read_csv(filename, 
                             sep='\t', 
                             header=0, index_col=0)
ap1.head()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-9-c31f259a6157> in <module>()
#       2 ap1 = pd.io.parsers.read_csv(filename,
#       3                              sep='\t',
# ----> 4                              header=0, index_col=0)
#       5 ap1.head()
#
# /Applications/anaconda/lib/python3.4/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, float_precision, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format, skip_blank_lines)
#     463                     skip_blank_lines=skip_blank_lines)
#     464
# --> 465         return _read(filepath_or_buffer, kwds)
#     466
#     467     parser_f.__name__ = name
#
# /Applications/anaconda/lib/python3.4/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     239
#     240     # Create the parser.
# --> 241     parser = TextFileReader(filepath_or_buffer, **kwds)
#     242
#     243     if (nrows is not None) and (chunksize is not None):
#
# /Applications/anaconda/lib/python3.4/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     555             self.options['has_index_names'] = kwds['has_index_names']
#     556
# --> 557         self._make_engine(self.engine)
#     558
#     559     def _get_options_with_defaults(self, engine):
#
# /Applications/anaconda/lib/python3.4/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#     692     def _make_engine(self, engine='c'):
#     693         if engine == 'c':
# --> 694             self._engine = CParserWrapper(self.f, **self.options)
#     695         else:
#     696             if engine == 'python':
#
# /Applications/anaconda/lib/python3.4/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1054         kwds['allow_leading_cols'] = self.index_col is not False
#    1055
# -> 1056         self._reader = _parser.TextReader(src, **kwds)
#    1057
#    1058         # XXX
#
# /Applications/anaconda/lib/python3.4/site-packages/pandas/parser.so in pandas.parser.TextReader.__cinit__ (pandas/parser.c:3136)()
#
# /Applications/anaconda/lib/python3.4/site-packages/pandas/parser.so in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:5767)()
#
# OSError: File b'../data/ap1_per_gene.txt' does not exist

# %%
# Merge on Refseq ID
pca_ap1 = pd.merge(pca, ap1, how='left', 
                   left_index=True, right_index=True, 
                   suffixes=('','_refseq'))
pca_ap1 = pca_ap1.fillna(0)

# %%
# Per refseq id, plot PC1 value versus total AP1
pc_ap1['ap1'] = pc_ap1[['batf_tag_count',
                        'cjun_tag_count',
                        'junb_tag_count',
                        'jund_tag_count',]].sum()
plt.plot(pc_ap1['ap1'], pc_ap1['pc1'])
