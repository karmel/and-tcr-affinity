# %%
'''
Do the PCs defined in PCA correlated with AP-1 presence?
'''
# Out:
# '\nDo the PCs defined in PCA correlated with AP-1 presence?\n'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_context('poster')

# %%
min_tags = 20

# %%
filename = 'output/clusters/pca_genes_rna_and.txt'
pca = pd.io.parsers.read_csv(filename, 
                             sep='\t', 
                             header=0, index_col=0)
pca.head()
# Out:
#              chr      start        end strand  Length  Copies  \
# id
# NM_015779  chr10   79886312   79888216      +     913       1
# NM_025359  chr12   36014555   36042478      -    1915       1
# NM_177603  chr19   41845976   41848132      -    2154       1
# NM_027238   chr4   83220301   83324189      -    8742       1
# NR_105986   chr4  138316132  138316200      -      68       1
#
#                                        Annotation/Divergence  0-1uM-PCC-24h  \
# id
# NM_015779  Elane|Ela2|F430011M15Rik|NE|-|10 C1|10 39.72 c...          3.718
# NM_025359  Tspan13|1100001I23Rik|NET-6|Tm4sf13|RP23-282B1...         64.645
# NM_177603         Frat2|-|-|19 C3|19 35.33 cM|protein-coding          9.572
# NM_027238  Ttc39b|1810054D07Rik|9130422G05Rik|AI450603|AV...         15.858
# NR_105986                     Mir7019|mmu-mir-7019|-|-|ncRNA          9.244
#
#            100uM-K99A-24h  10uM-K99A-24h  10uM-PCC-24h  No-Peptide-24h  \
# id
# ...

# %%
filename = '../data/ap1_per_gene.txt'
ap1 = pd.io.parsers.read_csv(filename, 
                             sep='\t', 
                             header=0, index_col=0)

ap1['ap1'] = ap1[['batf_tag_count',
                        'cjun_tag_count',
                        'junb_tag_count',
                        'jund_tag_count',
                        ]].sum(axis=1)
ap1.head()
# Out:
#                     chr_name  transcription_start  transcription_end  strand  \
# sequence_identifier
# NM_001001130           chr13             67747799           67755134       1
# NM_001001144            chr9            110333355          110384949       0
# NM_001001152           chr13             67254917           67269068       1
# NM_001001160            chr6             85469575           85502994       1
# NM_001001176            chrX            106206873          106219842       1
#
#                      batf_tag_count  cjun_tag_count  irf4_tag_count  \
# sequence_identifier
# NM_001001130                  15.30            8.87           33.60
# NM_001001144                  26.84           14.30           24.40
# NM_001001152                  27.50            0.00            6.69
# NM_001001160                   0.00            0.00            0.00
# NM_001001176                   0.00           20.50           10.40
#
# ...

# %%
# Merge on Refseq ID
pca_ap1 = pd.merge(pca, ap1, how='left', 
                   left_index=True, right_index=True, 
                   suffixes=('','_refseq'))
pca_ap1 = pca_ap1.fillna(0)
pca_ap1.shape
# Out:
# (3459, 25)

# %%
# Per refseq id, plot PC1 value versus total AP1

sns.regplot('ap1', 'pc1', pca_ap1)
#plt.xlim([0,400])
plt.ylim([-.05,.05])
plt.ylabel('Value along Principal Component 1')
plt.xlabel('Cumulative AP-1 Peak Tag Count in Promoter')

title = 'AP-1 enrichment per gene promoter'
plt.title(title)

plt.savefig('figures/{}.png'.format(title.replace(' ','_')),
            bbox_inches='tight')

# %%
# Box plots of top versus bottom.
pc1_ap1_sorted = pca_ap1.sort('pc1')
ten_pct = len(pca_ap1)//10
pc1_bottom = pc1_ap1_sorted[:ten_pct]
pc1_top = pc1_ap1_sorted[9*ten_pct:]
plt.boxplot([pc1_bottom['ap1'], 
             pc1_top['ap1']])

plt.ylim([0,500])

plt.ylabel('Cumulative AP-1 Peak Tags')
plt.xticks([1,2],
           ['Gene promoters in\nbottom 10% of PC1',
            'Gene promoters in\ntop 10% of PC1',])

title = 'AP-1 enrichment in the top versus bottom of PC1'
plt.title(title)

plt.savefig('figures/{}.png'.format(title.replace(' ','_')),
            bbox_inches='tight')

# %%
# Box plots of top versus bottom.
pca_ap1_sorted = pca_ap1.sort('pc2')
ten_pct = len(pca_ap1)//10
plt.boxplot([pca_ap1_sorted[:ten_pct]['ap1'], 
             pca_ap1_sorted[9*ten_pct:]['ap1']])
plt.ylim([0,500])

plt.ylabel('Cumulative AP-1 Peak Tags')
plt.xticks([1,2],
           ['Gene promoters in\nbottom 10% of PC2',
            'Gene promoters in\ntop 10% of PC2',])

title = 'AP-1 enrichment in the top versus bottom of PC2'
plt.title(title)

plt.savefig('figures/{}.png'.format(title.replace(' ','_')),
            bbox_inches='tight')

# %%
# Box plots of top versus bottom.
plt.boxplot([pc1_bottom['batf_tag_count'], 
             pc1_top['batf_tag_count']])
plt.ylim([0,100])
# Out:
# (0, 100)

# %%
# Now add in the monotonic portions
# Box plots of top versus bottom.
filename = 'output/clusters/monotonic_pc1_top_increasing.txt'
incr = pd.io.parsers.read_csv(filename, 
                             sep='\t', 
                             header=0, index_col=0)
incr.head()
# Out:
#                 chr      start        end strand  Length  Copies  \
# id
# NM_013674     chr13   30749258   30766927      +    4672       1
# NM_010735     chr17   35203165   35205351      -    1377       1
# NM_001002927   chr4    4133536    4138445      -    1408       1
# NM_153564      chr3  142496934  142522344      +    3008       1
# NM_008367      chr2   11642792   11693194      +    4418       1
#
#                                           Annotation/Divergence  \
# id
# NM_013674     Irf4|AI385587|IRF-4|LSIRF|Spip|RP23-213G18.1|1...
# NM_010735     Lta|LT|LT-[a]|LT-alpha|LT[a]|LTalpha|Ltx|TNF-b...
# NM_001002927  Penk|AI326464|ENK|PPA|Penk1|RP23-76M24.2|4 A1|...
# NM_153564      Gbp5|5330409J06Rik|Gbp5a|-|3 H1|3|protein-coding
# NM_008367     Il2ra|CD25|Il2r|Ly-43|-|2 A2-A3|2 8.91 cM|prot...
#
#               0-1uM-PCC-24h  100uM-K99A-24h  10uM-K99A-24h  10uM-PCC-24h  \
# id
# NM_013674           280.797         141.322         71.101       332.356
# ...

# %%
# Merge on Refseq ID
incr_ap1 = pd.merge(incr, ap1, how='left', 
                   left_index=True, right_index=True, 
                   suffixes=('','_refseq'))
incr_ap1 = incr_ap1.fillna(0)
incr_ap1.describe()
# Out:
#               start           end       Length  Copies  0-1uM-PCC-24h  \
# count  1.220000e+02  1.220000e+02   122.000000     122     122.000000
# mean   7.584656e+07  7.586407e+07  2136.926230       1     195.153328
# std    4.349721e+07  4.349628e+07  1347.757649       0     187.705195
# min    4.133536e+06  4.138445e+06   513.000000       1      73.310000
# 25%    3.860246e+07  3.864769e+07  1265.750000       1     109.711250
# 50%    7.530695e+07  7.532261e+07  1756.000000       1     138.402000
# 75%    1.108902e+08  1.109056e+08  2508.500000       1     228.773500
# max    1.800364e+08  1.800425e+08  8241.000000       1    1744.609000
#
#        100uM-K99A-24h  10uM-K99A-24h  10uM-PCC-24h  No-Peptide-24h  \
# count      122.000000     122.000000    122.000000      122.000000
# mean       168.251615     126.585934    209.475934       65.172574
# std        164.052845     131.849229    194.292097       60.879491
# ...

# %%
# Box plots of top versus bottom with monotonic set.
sets = [pc1_ap1_sorted['ap1'],
            pc1_bottom['ap1'], 
            pc1_top['ap1'],
            incr_ap1['ap1']]
plt.boxplot(sets)
plt.ylim([0,500])

plt.ylabel('Cumulative AP-1 Peak Tags')

segment_labels = ['All gene promoters',
            'Gene promoters in\nbottom 10% of PC1',
            'Gene promoters in\ntop 10% of PC1',
            'Gene promoters in\nmonotonically increasing\ntop 10% of PC1',]
plt.xticks(range(1, len(segment_labels) + 1), segment_labels)

title = 'AP-1 enrichment in PC1 by segment'
plt.title(title)

plt.savefig('figures/{}.png'.format(title.replace(' ','_')),
            bbox_inches='tight')

# %%
# Percent AP-1 binding

pct_bound = [sum(x > min_tags)/len(x)*100 for x in sets]

plt.figure()
colors = sns.color_palette('Blues_r', len(pct_bound))
width = .8

plt.bar(range(0,len(pct_bound)), 
        pct_bound,
        width, color=colors)

plt.ylabel('Percent of segment with AP-1 binding')
plt.xticks([x+width/2 for x in range(0,len(pct_bound))], 
           segment_labels)


title = 'AP-1 frequency in gene promoters by PC1 segment'
plt.title(title)

plt.savefig('figures/{}.png'.format(title.replace(' ','_')),
            bbox_inches='tight')
