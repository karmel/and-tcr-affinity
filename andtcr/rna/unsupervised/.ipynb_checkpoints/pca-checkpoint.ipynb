# %% [markdown]
# '''
# We have three variables of interest-- timecourse, KLRGhi vs. KLRGlo,
# and Foxo1 KO vs. WT. Which generates the most variation in the
# dataset?
#
# Use PCA to evaluate the axes of variation.
# '''

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
sns.set_context('poster')

# %%
filename = '../data/rpkm.txt'
data = pd.io.parsers.read_csv(filename, 
                                    sep='\t', 
                                    header=0)
# Clean up column names for easier parsing.
new_index = []
for col in data.columns:
    cleaned = col.replace('-KAA-14-10-31 reads','').replace(' FPKM','')
    cleaned = cleaned.replace('CD8TCell-','').replace('RNA-','')
    new_index.append(cleaned)
new_index[0] = 'id'
data.columns = new_index
cols = ['LCMV-0d', 
        'KLRGhi-LCMV-7d', 
        'KLRGlo-LCMV-7d', 
        'KLRGhi-LCMV-12d', 
        'KLRGlo-LCMV-12d', 
        'LCMV-35d-rep2', 
        'Foxo1-KO-LCMV-0d',
        'Foxo1-KO-KLRGhi-LCMV-7d', 
        'Foxo1-KO-KLRGlo-LCMV-7d', 
        'Foxo1-KO-KLRGhi-LCMV-12d', 
        ]
subdata = data[cols]
subdata.index = data['id']
subdata.head()
# Out:
#               LCMV-0d  KLRGhi-LCMV-7d  KLRGlo-LCMV-7d  KLRGhi-LCMV-12d  \
# id
# NM_001034168    0.000           0.000           0.000            0.000
# NM_001034100    0.000           0.000           0.000            0.000
# NM_146540       0.000           0.000           0.000            0.000
# NM_001242580   25.545          23.975          23.674           22.244
# NM_134184       0.000           0.000           0.000            0.000
#
#               KLRGlo-LCMV-12d  LCMV-35d-rep2  Foxo1-KO-LCMV-0d  \
# id
# NM_001034168            0.048          0.000             0.000
# NM_001034100            0.000          0.000             0.000
# NM_146540               0.000          0.000             0.000
# NM_001242580           28.400         26.337            22.565
# NM_134184               0.000          0.000             0.000
#
#               Foxo1-KO-KLRGhi-LCMV-7d  Foxo1-KO-KLRGlo-LCMV-7d  \
# id
# NM_001034168                     0.00                    0.000
# NM_001034100                     0.00                    0.000
# NM_146540                        0.00                    0.000
# NM_001242580                    21.86                   28.441
# NM_134184                        0.00                    0.000
#
#               Foxo1-KO-KLRGhi-LCMV-12d
# id
# NM_001034168                     0.000
# NM_001034100                     0.000
# NM_146540                        0.000
# NM_001242580                    29.766
# NM_134184                        0.000

# %%
# Filter out genes that aren't changing.
def check_changing(row):
    if row.max() - row.min() < row.min():
        return False
    if row.max() < 10:
        return False
    return True
filtered = subdata[subdata.apply(check_changing, axis=1)]
filtered.head()
# Out:
#               LCMV-0d  KLRGhi-LCMV-7d  KLRGlo-LCMV-7d  KLRGhi-LCMV-12d  \
# id
# NM_026114      13.707          19.021          19.918            8.194
# NM_176902      12.826          17.915          23.533           22.245
# NM_001033352   19.230          10.291          12.660           17.422
# NM_001290716   12.741          29.234          17.760            8.626
# NM_001025432   31.093          21.132          18.841           24.709
#
#               KLRGlo-LCMV-12d  LCMV-35d-rep2  Foxo1-KO-LCMV-0d  \
# id
# NM_026114              10.618         12.860            13.030
# NM_176902              13.480         16.425            10.670
# NM_001033352           19.157         19.987            15.427
# NM_001290716            8.964          9.678            13.254
# NM_001025432           25.643         28.392            45.626
#
#               Foxo1-KO-KLRGhi-LCMV-7d  Foxo1-KO-KLRGlo-LCMV-7d  \
# id
# NM_026114                      19.475                   21.580
# NM_176902                      18.810                   17.584
# NM_001033352                    9.269                    8.689
# NM_001290716                   22.736                   20.088
# NM_001025432                   15.616                   15.841
#
#               Foxo1-KO-KLRGhi-LCMV-12d
# id
# NM_026114                        9.882
# NM_176902                       14.751
# NM_001033352                    13.737
# NM_001290716                     9.601
# NM_001025432                    25.169

# %%
transpose = filtered.transpose()
pca = PCA(n_components=3)
X_r = pca.fit(transpose).transform(transpose)
print('Explained variance ratio (first three components): '
      + str(pca.explained_variance_ratio_))
X_r
# Out:
# Explained variance ratio (first three components): [ 0.89570276  0.08436833  0.00929165]
# array([[-13228.04295225,   4353.61605282,    251.32749594],
#        [ -3740.15853376,  -3502.77700385,    575.46173231],
#        [ -5532.1250465 ,  -2743.11459986,  -1289.80342212],
#        [ 22066.06296505,   1103.4565214 ,    287.649343  ],
#        [  7212.70287253,   2229.87885696,  -1138.50994278],
#        [  3899.89006412,   2540.23936016,  -1426.11058273],
#        [-12926.94765655,   4105.84785447,    998.41355353],
#        [ -2637.00499204,  -4316.01231067,   1073.54621765],
#        [ -5247.0384539 ,  -3828.48449961,   -958.15678661],
#        [ 10132.66173331,     57.3497682 ,   1626.1823918 ]])

# %%
plt.figure()
plt.scatter(X_r[:, 0].tolist(), X_r[:, 1].tolist(), s=100)
plt.title('PCA: RNA-Seq by Condition')
plt.xlabel('PC1 (90% of variance)')
plt.ylabel('PC2 (8% of variance)')

margin = 200
for i, txt in enumerate(transpose.index):
    if i % 2: dir = -1
    plt.annotate(txt, (X_r[i,0] + margin,X_r[i,1] + margin),
                 size=13)

plt.savefig('figures/PCA_RNA-Seq_by_Condition.png',
            bbox_inches='tight')
