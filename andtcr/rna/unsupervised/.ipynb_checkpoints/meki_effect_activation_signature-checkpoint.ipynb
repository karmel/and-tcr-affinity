# %%
'''
Does MEK inhibition preferentially affect activation signature genes?
'''
# Out:
# '\nDoes MEK inhibition preferentially affect activation signature genes?\n'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
sns.set_context('poster')

# %%
# First, get PC1
filename = 'output/clusters/pca_genes_rna_and.txt'
pca = pd.io.parsers.read_csv(filename, 
                             sep='\t', 
                             header=0, index_col=0)
pca.head()
# Out:
#              chr     start       end strand  Length  Copies  \
# id.1
# NR_030484   chr5  98475556  98475664      -     108       1
# NM_138659  chr11  75486777  75509447      +    7437       1
# NM_023733   chr5   8966048   8997146      -    2783       1
# NM_010824  chr11  87793784  87804412      +    2530       1
# NM_172938  chr10  42860512  42960782      +    4734       1
#
#                                        Annotation/Divergence  0-1uM-PCC-24h-1  \
# id.1
# NR_030484             Mir703|Mirn703|mmu-mir-703|-|5|5|ncRNA          132.708
# NM_138659  Prpf8|AU019467|D11Bwg0410e|DBF3/PRP8|Prp8|Sfpr...          118.612
# NM_023733         Crot|1200003H03Rik|-|5 A1|5|protein-coding            5.466
# NM_010824  Mpo|mKIAA4033|RP23-449P23.5|11 C|11 52.22 cM|p...            5.052
# NM_172938  Scml4|9330161D17|mFLJ00197|-|10 B2|10|protein-...            3.143
#
#            100uM-K99A-24h-1  10uM-K99A-24h-1    ...     10uM-K99A-24h-std  \
# id.1                                            ...
# NR_030484           191.024          118.911    ...             47.726879
# NM_138659           105.737           93.584    ...             23.027639
# NM_023733             6.038            9.744    ...              1.788980
# NM_010824            21.501           35.468    ...              3.340372
# NM_172938             1.742            8.579    ...              4.323251
#
#            100uM-K99A-24h  100uM-K99A-24h-std  0-1uM-PCC-24h  \
# id.1
# NR_030484        127.3840           90.000551       101.4030
# NM_138659        106.1970            0.650538       112.5910
# NM_023733          6.4600            0.596798         6.5515
# NM_010824         16.1620            7.550486         7.8325
# NM_172938          2.7515            1.427649         3.6125
#
#            0-1uM-PCC-24h-std  10uM-PCC-24h  10uM-PCC-24h-std  gene_name  \
# id.1
# NR_030484          44.271956      117.8310          1.788980     Mir703
# NM_138659           8.514980      116.6430          3.425225      Prpf8
# NM_023733           1.535129        5.6485          0.567807       Crot
# NM_010824           3.932221        2.1120          0.890955        Mpo
# NM_172938           0.663973        1.1045          0.644174      Scml4
#
#                 pc1       pc2
# id.1
# NR_030484  0.003371 -0.011014
# NM_138659  0.003521 -0.000754
# NM_023733 -0.000422 -0.000247
# NM_010824 -0.002896 -0.002192
# NM_172938 -0.001107  0.002289
#
# [5 rows x 35 columns]

# %%
pca = pca.sort('pc1')

ten_pct = len(pca)/10
top = pca[int(round(9*ten_pct)):]
bottom = pca[:int(ten_pct)]
len(top)
# Out:
# 328

# %%
filename = '../data/mean/rpkm.txt'
data = pd.io.parsers.read_csv(filename, 
                                    sep='\t', 
                                    header=0, index_col=0)

print(data.shape)
cols = ['No-Peptide-24h',
        '10uM-K99A-24h', 
        '100uM-K99A-24h', 
        '0-1uM-PCC-24h', 
        '10uM-PCC-24h', 
        ]
meki_cols = [s + '-MEKi' for s in cols]
labels = ['No Peptide', '10uM K99A', '100uM K99A', '0.1uM PCC', '10uM PCC']
subdata = data[cols + meki_cols]
subdata.head()
# Out:
# (24063, 33)
#            No-Peptide-24h  10uM-K99A-24h  100uM-K99A-24h  0-1uM-PCC-24h  \
# id
# NM_013478          0.0000         0.0000          0.0000         0.0000
# NM_172784          0.3145         0.8530          1.3405         1.0895
# NM_007732          0.0415         0.0040          0.0095         0.0090
# NM_016772         42.7335        36.6585         29.7200        25.7330
# NR_077063          0.0100         0.0470          0.0000         0.0000
#
#            10uM-PCC-24h  No-Peptide-24h-MEKi  10uM-K99A-24h-MEKi  \
# id
# NM_013478        0.0000                0.000               0.000
# NM_172784        0.9210                0.166               0.288
# NM_007732        0.0105                0.093               0.000
# NM_016772       28.8205               33.258              26.258
# NR_077063        0.0000                0.000               0.000
#
#            100uM-K99A-24h-MEKi  0-1uM-PCC-24h-MEKi  10uM-PCC-24h-MEKi
# id
# NM_013478                0.000               0.000              0.000
# NM_172784                0.769               1.096              1.029
# NM_007732                0.000               0.000              0.000
# NM_016772               31.125              24.883             22.904
# NR_077063                0.000               0.000              0.000

# %%
all_cols = zip(cols, meki_cols)
all_cols = [item for sublist in all_cols for item in sublist]

# %%
# Set up colors
colorset = sns.color_palette("husl", 5)[::-1]

# Get sets of six
color_groups = zip(colorset, colorset)

# Flatten
color_groups = [item for sublist in color_groups for item in sublist]

# %%
# Box plots of conditions
top_rpkm = subdata.loc[top.index]
bp = plt.boxplot([top_rpkm[c] for c in all_cols], patch_artist=True)

# Colors.
for i in range(0, len(all_cols)):
    outline_col = '#666666'
    plt.setp(bp['boxes'][i], edgecolor=outline_col)
    plt.setp(bp['boxes'][i], linewidth=3)
    plt.setp(bp['boxes'][i], facecolor=color_groups[i])
    plt.setp(bp['boxes'][i], hatch=(i%2 and '//' or None))
    plt.setp(bp['medians'][i], color=outline_col)
    plt.setp(bp['whiskers'][i*2], color=outline_col)
    plt.setp(bp['whiskers'][i*2+1], color=outline_col)
    plt.setp(bp['caps'][i*2], color=outline_col)
    plt.setp(bp['caps'][i*2+1], color=outline_col)

    
# Custom legend
notx_patch = plt.Rectangle((0, 0), 1, 1, fc="white")
meki_patch = plt.Rectangle((0, 0), 1, 1, fc="white", hatch ='//')

plt.legend([notx_patch, meki_patch], ['Notx', '0.5uM MEKi'], loc='upper left')

plt.ylim([0,400])

plt.ylabel('RPKM')
plt.xticks([x + 1.5 for x in range(len(all_cols)) if x%2], ['']*len(labels))
for i, label in enumerate(labels):
    plt.text(i*2 + 1.5, -10, label,
                ha='center', va='top', fontsize=14)


title = 'MEKi effect on top 10% of PC1'
plt.title(title)

plt.savefig('figures/{}.png'.format(title.replace(' ','_')),
            bbox_inches='tight')

# %%
# Box plots of conditions
bottom_rpkm = subdata.loc[bottom.index]
bp = plt.boxplot([bottom_rpkm[c] for c in all_cols], patch_artist=True)

# Colors.
for i in range(0, len(all_cols)):
    outline_col = '#666666'
    plt.setp(bp['boxes'][i], edgecolor=outline_col)
    plt.setp(bp['boxes'][i], linewidth=3)
    plt.setp(bp['boxes'][i], facecolor=color_groups[i])
    plt.setp(bp['boxes'][i], hatch=(i%2 and '//' or None))
    plt.setp(bp['medians'][i], color=outline_col)
    plt.setp(bp['whiskers'][i*2], color=outline_col)
    plt.setp(bp['whiskers'][i*2+1], color=outline_col)
    plt.setp(bp['caps'][i*2], color=outline_col)
    plt.setp(bp['caps'][i*2+1], color=outline_col)

    
# Custom legend
notx_patch = plt.Rectangle((0, 0), 1, 1, fc="white")
meki_patch = plt.Rectangle((0, 0), 1, 1, fc="white", hatch ='//')

plt.legend([notx_patch, meki_patch], ['Notx', '0.5uM MEKi'], loc='upper right')

plt.ylim([0,400])

plt.ylabel('RPKM')
plt.xticks([x + 1.5 for x in range(len(all_cols)) if x%2], ['']*len(labels))
for i, label in enumerate(labels):
    plt.text(i*2 + 1.5, -10, label,
                ha='center', va='top', fontsize=14)


title = 'MEKi effect on bottom 10% of PC1'
plt.title(title)

plt.savefig('figures/{}.png'.format(title.replace(' ','_')),
            bbox_inches='tight')

# %%
for j, segment in enumerate([bottom_rpkm, top_rpkm]):
    label = 'bottom'
    if j%2: label = 'top'
    normed = segment[cols].divide(segment.max(axis=1), axis=0)
    fig = plt.figure()
    ax = fig.add_subplot(1,1,1)
    
    blues = sns.color_palette('Blues')
    normed.T.plot(legend=False, linewidth=.5, 
                  ax=ax, color=blues)

    greens = sns.color_palette('Greens')
    normed_meki = segment[meki_cols].divide(segment.max(axis=1), axis=0)
    normed_meki.T.plot(legend=False, linewidth=.5, 
                       ax=ax, color=greens)
    normed_meki.mean()
    plt.xticks(range(0, len(labels)), labels)
    ax.set_ylabel('Normalized RPKM')
    title = 'Gene expression in the {} 10% of PC1 with MEKi'.format(label, i+1)
    ax.set_title(title)
    plt.savefig('figures/' + title.replace(' ', '_') + '.png',
        bbox_inches='tight')

# %%
normed_meki.mean()
# Out:
# No-Peptide-24h-MEKi    0.182729
# 10uM-K99A-24h-MEKi     0.248185
# 100uM-K99A-24h-MEKi    0.529648
# 0-1uM-PCC-24h-MEKi     0.717535
# 10uM-PCC-24h-MEKi      0.761728
# dtype: float64
