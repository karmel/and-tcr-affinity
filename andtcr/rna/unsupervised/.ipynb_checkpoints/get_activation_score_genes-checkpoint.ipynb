# %%
'''
We want the intersection of all three activation score gene sets--
replicate 1, replicate 2, and the mean.
'''
# Out:
# '\nWe want the intersection of all three activation score gene sets--\nreplicate 1, replicate 2, and the mean.\n'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# First, get PC1
filename = 'output/clusters/pca_genes_rna_and_rep1.txt'
pca1 = pd.io.parsers.read_csv(filename, 
                             sep='\t', 
                             header=0, index_col=0)
filename = 'output/clusters/pca_genes_rna_and_rep2.txt'
pca2 = pd.io.parsers.read_csv(filename, 
                             sep='\t', 
                             header=0, index_col=0)

filename = 'output/clusters/pca_genes_rna_and.txt'
pca_both = pd.io.parsers.read_csv(filename, 
                             sep='\t', 
                             header=0, index_col=0)
pca_both.head()
# Out:
#              chr     start       end strand  Length  Copies  \
# id
# NM_138659  chr11  75486777  75509447      +    7437       1
# NM_023733   chr5   8966048   8997146      -    2783       1
# NM_010824  chr11  87793784  87804412      +    2530       1
# NM_172938  chr10  42860512  42960782      +    4734       1
# NM_026389  chr11  78512296  78522736      +    1938       1
#
#                                        Annotation/Divergence  0-1uM-PCC-24h-1  \
# id
# NM_138659  Prpf8|AU019467|D11Bwg0410e|DBF3/PRP8|Prp8|Sfpr...          118.612
# NM_023733         Crot|1200003H03Rik|-|5 A1|5|protein-coding            5.466
# NM_010824  Mpo|mKIAA4033|RP23-449P23.5|11 C|11 52.22 cM|p...            5.052
# NM_172938  Scml4|9330161D17|mFLJ00197|-|10 B2|10|protein-...            3.143
# NM_026389  Poldip2|1300003F06Rik|Pdip38|RP23-399H5.6|11 B...           34.750
#
#            100uM-K99A-24h-1  10uM-K99A-24h-1    ...     10uM-K99A-24h-std  \
# id                                              ...
# NM_138659           105.737           93.584    ...             23.027639
# NM_023733             6.038            9.744    ...              1.788980
# NM_010824            21.501           35.468    ...              3.340372
# NM_172938             1.742            8.579    ...              4.323251
# NM_026389            29.188           20.998    ...              7.793024
#
#            100uM-K99A-24h  100uM-K99A-24h-std  0-1uM-PCC-24h  \
# id
# NM_138659        106.1970            0.650538       112.5910
# NM_023733          6.4600            0.596798         6.5515
# NM_010824         16.1620            7.550486         7.8325
# NM_172938          2.7515            1.427649         3.6125
# NM_026389         24.8235            6.172335        27.4805
#
#            0-1uM-PCC-24h-std  10uM-PCC-24h  10uM-PCC-24h-std  gene_name  \
# id
# NM_138659           8.514980      116.6430          3.425225      Prpf8
# NM_023733           1.535129        5.6485          0.567807       Crot
# NM_010824           3.932221        2.1120          0.890955        Mpo
# NM_172938           0.663973        1.1045          0.644174      Scml4
# NM_026389          10.280625       30.8115          4.174051    Poldip2
#
#                 pc1       pc2
# id
# NM_138659  0.003523 -0.000783
# NM_023733 -0.000422 -0.000263
# NM_010824 -0.002897 -0.002263
# NM_172938 -0.001108  0.002380
# NM_026389  0.001002  0.003041
#
# [5 rows x 35 columns]

# %%
# Sort.
pca1 = pca1.sort('pc1')

fraction = 10
ten_pct = len(pca1)/fraction
top1 = pca1[int(round((fraction-1)*ten_pct)):]
bottom1 = pca1[:int(ten_pct)]
print(len(top1))

pca2 = pca2.sort('pc1')

ten_pct = len(pca2)/fraction
top2 = pca2[int(round((fraction-1)*ten_pct)):]
bottom2 = pca2[:int(ten_pct)]
print(len(top2))

pca_both = pca_both.sort('pc1')
ten_pct = len(pca_both)/fraction
top_both = pca_both[int(round((fraction-1)*ten_pct)):]
bottom_both = pca_both[:int(ten_pct)]
print(len(top_both))
# Out:
# 319
# 336
# 305

# %%
# Throw out genes where no-pep standard deviation is too high
cutoff = .2
min_exp = 100
top_both = top_both[(top_both['No-Peptide-24h'] <= min_exp) |
    (top_both['No-Peptide-24h']*cutoff > top_both['No-Peptide-24h-std'])]
bottom_both = bottom_both[(bottom_both['No-Peptide-24h'] <= min_exp) |
    (bottom_both['No-Peptide-24h']*cutoff > bottom_both['No-Peptide-24h-std'])]
print(len(top_both))
print(len(bottom_both))
# Out:
# 264
# 218

# %%
# Get intersection of all three sets.
intersect_top = set(top1.index.tolist()) &\
            set(top2.index.tolist()) &\
            set(top_both.index.tolist())
print(len(intersect_top))
# Out:
# 215

# %%
# Get intersection of all three sets.
intersect_bottom = set(bottom1.index.tolist()) &\
            set(bottom2.index.tolist()) &\
            set(bottom_both.index.tolist())
print(len(intersect_bottom))
# Out:
# 137

# %%
pca_intersect = pca_both.loc[list(intersect_top) + list(intersect_bottom)]
pca_intersect = pca_intersect.sort('pc1')
act_signature = pca_intersect[['gene_name', 'pc1']]
act_signature['Refseq'] = act_signature.index
act_signature.columns = ['gene symbol', 'pc1', 'refseq']
act_signature = act_signature[['refseq', 'gene symbol', 'pc1']]
act_signature.head()
# Out:
# -c:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                     refseq gene symbol       pc1
# id
# NM_017372        NM_017372        Lyz2 -0.141019
# NM_008694        NM_008694         Ngp -0.124549
# NM_008491        NM_008491        Lcn2 -0.073408
# NM_001146124  NM_001146124        Psap -0.034952
# NM_008522        NM_008522         Ltf -0.029025

# %%
act_signature.to_csv('../activationscore/activation_score_genes.txt',
                     header=True, index=False, sep='\t')
