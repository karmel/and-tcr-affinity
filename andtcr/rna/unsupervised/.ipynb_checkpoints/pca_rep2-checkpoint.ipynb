# %% [markdown]
# '''
# Use PCA to evaluate the axes of variation.
# '''

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
sns.set_context('poster')

# %%
filename = '../data/reps1-2/rpkm.txt'
data = pd.io.parsers.read_csv(filename, 
                                    sep='\t', 
                                    header=0)
# Clean up column names for easier parsing.
new_index = []
for col in data.columns:
    cleaned = col.replace('-KAA-15-02-17 reads','').replace(' FPKM','')
    cleaned = cleaned.replace('AND-CD4TCell-RNA-','').replace('../../rep2/tag-dirs/','')
    new_index.append(cleaned)
new_index[0] = 'id'
data.columns = new_index
data.index = data['id']
print(data.shape)
print(data.columns)
cols = ['No-Peptide-24h',
        '10uM-K99A-24h', 
        '100uM-K99A-24h', 
        '0-1uM-PCC-24h', 
        '10uM-PCC-24h', 
        ]
subdata = data[cols]
subdata.head()
# Out:
# (24063, 23)
# Index(['id', 'chr', 'start', 'end', 'strand', 'Length', 'Copies', 'Annotation/Divergence', '../../rep1/tag-dirs/0-1uM-PCC-24h-KAA-15-01-22 reads', '../../rep1/tag-dirs/100uM-K99A-24h-KAA-15-01-22 reads', '../../rep1/tag-dirs/10uM-K99A-24h-KAA-15-01-22 reads', '../../rep1/tag-dirs/10uM-PCC-24h-KAA-15-01-22 reads', '../../rep1/tag-dirs/No-Peptide-24h-KAA-15-01-22 reads', '0-1uM-PCC-24h-0-5uM-MEKi', '0-1uM-PCC-24h', '100uM-K99A-24h-0-5uM-MEKi', '100uM-K99A-24h', '10uM-K99A-24h-0-5uM-MEKi', '10uM-K99A-24h', '10uM-PCC-24h-0-5uM-MEKi', '10uM-PCC-24h', 'No-Peptide-24h-0-5uM-MEKi', 'No-Peptide-24h'], dtype='object')
#            No-Peptide-24h  10uM-K99A-24h  100uM-K99A-24h  0-1uM-PCC-24h  \
# id
# NM_013478           0.000          0.000           0.000          0.000
# NM_172784           0.263          0.644           0.993          1.152
# NM_007732           0.083          0.000           0.019          0.018
# NM_016772          37.441         33.507          24.548         27.646
# NR_077063           0.000          0.078           0.000          0.000
#
#            10uM-PCC-24h
# id
# NM_013478         0.000
# NM_172784         0.925
# NM_007732         0.021
# NM_016772        27.479
# NR_077063         0.000

# %%
# Remove NR_ genes
subdata = subdata[data['id'].str[:3] != 'NR_']

# Filter out genes that aren't changing.
def check_changing(row):
    if row.max() - row.min() < row.min():
        return False
    if row.max() < 10:
        return False
    return True
filtered = subdata[subdata.apply(check_changing, axis=1)]
print(filtered.shape)
filtered.head()
# Out:
# (3607, 5)
#            No-Peptide-24h  10uM-K99A-24h  100uM-K99A-24h  0-1uM-PCC-24h  \
# id
# NR_030484          41.644         51.415          63.744         70.098
# NM_138659          44.732         61.018         106.657        106.570
# NM_023733          11.863         12.274           6.882          7.637
# NM_010824          31.920         40.192          10.823         10.613
# NM_172938          16.078         14.693           3.761          4.082
#
#            10uM-PCC-24h
# id
# NR_030484       116.566
# NM_138659       119.065
# NM_023733         5.247
# NM_010824         1.482
# NM_172938         1.560

# %%
n = 5
transpose = filtered.transpose()
pca = PCA(n_components=n)
X_r = pca.fit(transpose).transform(transpose)
print('Explained variance ratio (first {} components): '.format(n)
      + str(pca.explained_variance_ratio_))
X_r
# Out:
# Explained variance ratio (first 5 components): [  9.96455913e-01   2.45515338e-03   1.04198145e-03   4.69522375e-05
#    4.57855566e-31]
# /Applications/anaconda/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# array([[ -1.40499558e+04,   5.90488608e+02,  -1.22129249e+02,
#          -1.29189352e+00,   5.09894349e-11],
#        [ -8.16120995e+03,  -6.98346008e+02,   3.04334479e+02,
#           2.20554737e+00,   2.06528128e-11],
#        [  6.00999789e+03,  -1.48744943e+02,  -2.96267370e+02,
#           1.02776545e+02,  -6.31805719e-12],
#        [  5.84738048e+03,  -1.85101157e+02,  -3.03438682e+02,
#          -1.01133420e+02,  -1.76263448e-11],
#        [  1.03537874e+04,   4.41703501e+02,   4.17500821e+02,
#          -2.55677871e+00,  -4.77271556e-11]])

# %%
plt.figure()
plt.scatter(X_r[:, 0].tolist(), X_r[:, 1].tolist(), s=100)
plt.title('PCA: RNA-Seq by Condition')
plt.xlabel('PC1 (99% of variance)')
plt.ylabel('PC2 (0.02% of variance)')

margin = 50
for i, txt in enumerate(transpose.index):
    if i % 2: dir = -1
    plt.annotate(txt, (X_r[i,0] + margin,X_r[i,1] + margin),
                 size=13)

plt.savefig('figures/PCA_RNA-Seq_by_Condition_rep2.png',
            bbox_inches='tight')

# %%
# We want to get the top and bottom features that make up each component.
out_data = data[:]
out_data['gene_name'] = [s.split('|')[0] for s in data['Annotation/Divergence']]

components = pd.DataFrame(pca.components_)
pcs = []

for x in range(0,2):
    pc = components.loc[x]
    pc.sort()
    num_elem = len(pc)
    bottom = pc.index[:num_elem//10]
    top = pc.index[9*num_elem//10:]
    
    bottom_ids = filtered.index[bottom]
    top_ids = filtered.index[top]
    out_data.loc[bottom_ids].to_csv('output/clusters/pca_pc{}_bottom_rna_and_rep2.txt'.format(x + 1), 
                        sep='\t', header=True, index=True)
    out_data.loc[top_ids].to_csv('output/clusters/pca_pc{}_top_rna_and_rep2.txt'.format(x + 1), 
                        sep='\t', header=True, index=True)
    pcs.append([filtered.loc[bottom_ids], filtered.loc[top_ids]])
# Out:
# -c:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Output all, sorted, with the PC index.
pc_data = out_data.loc[filtered.index]
pc_data['pc1'] = components.loc[0].tolist()
pc_data['pc2'] = components.loc[1].tolist()
pc_data.to_csv('output/clusters/pca_genes_rna_and_rep2.txt', 
                        sep='\t', header=True, index=True)

# %%
for i, pc in enumerate(pcs):
    for j, segment in enumerate(pc):
        label = 'bottom'
        if j%2: label = 'top'
        normed = segment.divide(segment.max(axis=1), axis=0)
        plt.figure()
        sns.set_palette('Blues')
        normed.T.plot(legend=False, linewidth=.5)
        plt.ylabel('Normalized RPKM')
        title = 'Gene expression in the {} 10% of PC{}'.format(label, i+1)
        plt.title(title)
        plt.savefig('figures/' + title.replace(' ', '_') + '_rep2.png',
            bbox_inches='tight')

# %%
# Plot percent variance explained by the first four PCs
num = 4
span = range(0,num)
ratios = pca.explained_variance_ratio_[:num]*100
plt.figure()
plt.bar([x + .2 for x in span], ratios)
plt.xlim([0, num + .2])
plt.ylabel('Percent of variance explained')
plt.xticks([x + .6 for x in span], ['PC{}'.format(x + 1) for x in span])
title = 'RNA-seq Variance Percentages by Principal Component'
plt.title(title)
plt.savefig('figures/{}_rep2.png'.format(title.replace(' ', '_')), bbox_inches='tight')
