# %% [markdown]
# '''
# Use PCA to evaluate the axes of variation.
# '''

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
sns.set_context('poster')

# %%
filename = '../data/rep1/rpkm.txt'
data = pd.io.parsers.read_csv(filename, 
                                    sep='\t', 
                                    header=0)
# Clean up column names for easier parsing.
new_index = []
for col in data.columns:
    cleaned = col.replace('-KAA-15-01-22 reads','').replace(' FPKM','')
    cleaned = cleaned.replace('AND-CD4TCell-RNA-','').replace('../tag-dirs/','')
    new_index.append(cleaned)
new_index[0] = 'id'
data.columns = new_index
data.index = data['id']
print(data.shape)
cols = ['No-Peptide-24h',
        '10uM-K99A-24h', 
        '100uM-K99A-24h', 
        '0-1uM-PCC-24h', 
        '10uM-PCC-24h', 
        ]
subdata = data[cols]
subdata.head()
# Out:
# (24063, 13)
#               No-Peptide-24h  10uM-K99A-24h  100uM-K99A-24h  0-1uM-PCC-24h  \
# id
# NM_011280              0.000          0.018           0.000          0.000
# NM_022986              0.877          1.582           1.254          2.132
# NM_028370              8.082          5.042           3.242          3.480
# NM_001011865           0.000          0.000           0.000          0.000
# NR_029818              0.000          0.000           0.000          0.000
#
#               10uM-PCC-24h
# id
# NM_011280            0.000
# NM_022986            2.891
# NM_028370            3.333
# NM_001011865         0.000
# NR_029818            0.000

# %%
# Filter out genes that aren't changing.
def check_changing(row):
    if row.max() - row.min() < row.min():
        return False
    if row.max() < 10:
        return False
    return True
filtered = subdata[subdata.apply(check_changing, axis=1)]
print(filtered.shape)
filtered.head()
# Out:
# (3455, 5)
#            No-Peptide-24h  10uM-K99A-24h  100uM-K99A-24h  0-1uM-PCC-24h  \
# id
# NM_015779          80.409         32.074          15.165          3.718
# NM_025359          48.460        146.362         153.193         64.645
# NM_177603          27.698         12.399           8.387          9.572
# NM_027238           7.475         10.709          12.156         15.858
# NR_105986          19.767          1.804           7.541          9.244
#
#            10uM-PCC-24h
# id
# NM_015779         1.068
# NM_025359        63.563
# NM_177603         7.347
# NM_027238        19.425
# NR_105986         7.970

# %%
n = 5
transpose = filtered.transpose()
pca = PCA(n_components=n)
X_r = pca.fit(transpose).transform(transpose)
print('Explained variance ratio (first {} components): '.format(n)
      + str(pca.explained_variance_ratio_))
X_r
# Out:
# Explained variance ratio (first 5 components): [  9.78690825e-01   1.60749579e-02   4.02248189e-03   1.21173485e-03
#    2.48793449e-30]
# /Applications/anaconda/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# array([[ -1.09055916e+04,   4.69120649e+02,  -1.84928116e+01,
#           1.45363211e+01,  -3.00754976e-11],
#        [  8.47295807e+01,  -1.02187545e+03,   5.21714624e+02,
#          -5.86398970e+01,   9.36584144e-12],
#        [  1.43424484e+03,  -7.55409158e+02,  -5.86880086e+02,
#           1.21809173e+02,   3.86357613e-12],
#        [  4.11010591e+03,   5.28528846e+02,  -1.32394973e+02,
#          -3.41910297e+02,   1.31212818e-11],
#        [  5.27651124e+03,   7.79635111e+02,   2.16053246e+02,
#           2.64204700e+02,   4.31854552e-12]])

# %%
plt.figure()
plt.scatter(X_r[:, 0].tolist(), X_r[:, 1].tolist(), s=100)
plt.title('PCA: RNA-Seq by Condition')
plt.xlabel('PC1 (98% of variance)')
plt.ylabel('PC2 (1.5% of variance)')

margin = 50
for i, txt in enumerate(transpose.index):
    if i % 2: dir = -1
    plt.annotate(txt, (X_r[i,0] + margin,X_r[i,1] + margin),
                 size=13)

plt.savefig('figures/PCA_RNA-Seq_by_Condition_rep1.png',
            bbox_inches='tight')

# %%
# We want to get the top and bottom features that make up each component.
out_data = data[:]
out_data['gene_name'] = [s.split('|')[0] for s in data['Annotation/Divergence']]

components = pd.DataFrame(pca.components_)
pcs = []

for x in range(0,2):
    pc = components.loc[x]
    pc.sort()
    num_elem = len(pc)
    bottom = pc.index[:num_elem//10]
    top = pc.index[9*num_elem//10:]
    
    bottom_ids = filtered.index[bottom]
    top_ids = filtered.index[top]
    out_data.loc[bottom_ids].to_csv('output/clusters/pca_pc{}_bottom_rna_and_rep1.txt'.format(x + 1), 
                        sep='\t', header=True, index=True)
    out_data.loc[top_ids].to_csv('output/clusters/pca_pc{}_top_rna_and_rep1.txt'.format(x + 1), 
                        sep='\t', header=True, index=True)
    pcs.append([filtered.loc[bottom_ids], filtered.loc[top_ids]])
# Out:
# -c:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Output all, sorted, with the PC index.
pc_data = out_data.loc[filtered.index]
pc_data['pc1'] = components.loc[0].tolist()
pc_data['pc2'] = components.loc[1].tolist()
pc_data.to_csv('output/clusters/pca_genes_rna_and_rep1.txt', 
                        sep='\t', header=True, index=True)

# %%
for i, pc in enumerate(pcs):
    for j, segment in enumerate(pc):
        label = 'bottom'
        if j%2: label = 'top'
        normed = segment.divide(segment.max(axis=1), axis=0)
        plt.figure()
        sns.set_palette('Blues')
        normed.T.plot(legend=False, linewidth=.5)
        plt.ylabel('Normalized RPKM')
        title = 'Gene expression in the {} 10% of PC{}'.format(label, i+1)
        plt.title(title)
        plt.savefig('figures/' + title.replace(' ', '_') + '_rep1.png',
            bbox_inches='tight')

# %%
# Plot percent variance explained by the first four PCs
num = 4
span = range(0,num)
ratios = pca.explained_variance_ratio_[:num]*100
plt.figure()
plt.bar([x + .2 for x in span], ratios)
plt.xlim([0, num + .2])
plt.ylabel('Percent of variance explained')
plt.xticks([x + .6 for x in span], ['PC{}'.format(x + 1) for x in span])
title = 'RNA-seq Variance Percentages by Principal Component'
plt.title(title)
plt.savefig('figures/{}_rep1.png'.format(title.replace(' ', '_')), bbox_inches='tight')
