# %% [markdown]
# '''
# What sorts of gene clusters fall out of the data?
#
# Lots of different subsets of columns to try.
# Let's start with KMeans.
# '''

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import scale

# %%
# Set up some rules.
max_fdr = 0.01
min_logfc = 2
min_logcpm = 2

# %%
filename = '../data/reps1-2/diffExp.output.txt'
data = pd.io.parsers.read_csv(filename, 
                                    sep='\t', 
                                    header=0)
data.index = data[data.columns[0]].tolist()

# Filter out snoRNA, etc.
data = data[[s.startswith('NM_') for s in data.index]]


# Clean up column names for easier parsing.
cols = ['10uM_K99A', 
        '100uM_K99A', 
        '0_1uM_PCC', 
        '10uM_PCC', 
        ]
# Get three data points for each prefix, then flatten
all_cols = [(pre + ' vs. No_Peptide logFC', 
             pre + ' vs. No_Peptide logCPM', 
             pre + ' vs. No_Peptide FDR') 
            for pre in cols]
all_cols = [item for sublist in all_cols for item in sublist]
subdata = data[all_cols]
subdata.describe()
# Out:
#        10uM_K99A vs. No_Peptide logFC  10uM_K99A vs. No_Peptide logCPM  \
# count                    20433.000000                     20433.000000
# mean                        -0.010625                         1.841015
# std                          1.378734                         4.026040
# min                         -8.245235                        -2.951877
# 25%                         -0.335787                        -2.785543
# 50%                          0.000000                         2.218952
# 75%                          0.324034                         5.505680
# max                          7.149718                        12.983481
#
#        10uM_K99A vs. No_Peptide FDR  100uM_K99A vs. No_Peptide logFC  \
# count                  20433.000000                     20433.000000
# mean                       0.995456                         0.095055
# std                        0.053455                         1.576471
# min                        0.000000                       -10.378510
# 25%                        1.000000                        -0.491615
# 50%                        1.000000                         0.000000
# 75%                        1.000000                         0.597269
# max                        1.000000                         8.281890
#
#        100uM_K99A vs. No_Peptide logCPM  100uM_K99A vs. No_Peptide FDR  \
# count                      20433.000000                   2.043300e+04
# mean                           1.835188                   6.908890e-01
# std                            4.061630                   3.868268e-01
# min                           -2.985960                   6.992677e-19
# 25%                           -2.819961                   3.204005e-01
# 50%                            2.222483                   1.000000e+00
# 75%                            5.567229                   1.000000e+00
# max                           12.628748                   1.000000e+00
#
#        0_1uM_PCC vs. No_Peptide logFC  0_1uM_PCC vs. No_Peptide logCPM  \
# count                    20433.000000                     20433.000000
# mean                         0.095526                         1.847143
# std                          1.648892                         4.061364
# min                        -11.435829                        -2.986916
# 25%                         -0.524206                        -2.819860
# 50%                          0.000000                         2.249291
# 75%                          0.633074                         5.586252
# max                          8.693572                        12.565411
#
#        0_1uM_PCC vs. No_Peptide FDR  10uM_PCC vs. No_Peptide logFC  \
# count                  2.043300e+04                   20433.000000
# mean                   6.915589e-01                       0.145418
# std                    3.848925e-01                       1.783081
# min                    1.638653e-23                     -12.363026
# 25%                    3.265370e-01                      -0.610276
# 50%                    1.000000e+00                       0.000000
# 75%                    1.000000e+00                       0.714313
# max                    1.000000e+00                       9.848374
#
#        10uM_PCC vs. No_Peptide logCPM  10uM_PCC vs. No_Peptide FDR
# count                    20433.000000                 2.043300e+04
# mean                         1.836076                 5.967827e-01
# std                          4.072891                 4.251154e-01
# min                         -3.005949                 2.043059e-54
# 25%                         -2.841167                 9.277591e-02
# 50%                          2.231370                 7.839731e-01
# 75%                          5.591063                 1.000000e+00
# max                         12.405404                 1.000000e+00

# %%
# Filter out genes that aren't changing.
mask_fdr = subdata.filter(like='FDR').min(axis=1) <= max_fdr
mask_cpm = subdata.filter(like='logCPM').max(axis=1) >= min_logcpm
mask_fc = subdata.filter(like='logFC').max(axis=1).abs() >= min_logfc
filtered = subdata[mask_fdr & mask_cpm & mask_fc]

filtered.describe()
# Out:
#        10uM_K99A vs. No_Peptide logFC  10uM_K99A vs. No_Peptide logCPM  \
# count                     1068.000000                      1068.000000
# mean                         0.768117                         5.413757
# std                          0.843991                         2.069791
# min                         -5.740371                        -2.785543
# 25%                          0.572948                         3.793058
# 50%                          0.791651                         5.332672
# 75%                          1.068318                         6.853882
# max                          2.912628                        12.983481
#
#        10uM_K99A vs. No_Peptide FDR  100uM_K99A vs. No_Peptide logFC  \
# count                   1068.000000                      1068.000000
# mean                       0.965971                         1.896499
# std                        0.149083                         1.293948
# min                        0.000090                        -9.740325
# 25%                        1.000000                         1.657764
# 50%                        1.000000                         1.986774
# 75%                        1.000000                         2.400051
# max                        1.000000                         6.387978
#
#        100uM_K99A vs. No_Peptide logCPM  100uM_K99A vs. No_Peptide FDR  \
# count                       1068.000000                   1.068000e+03
# mean                           5.145472                   2.949850e-02
# std                            2.009672                   9.542023e-02
# min                            1.174323                   6.992677e-19
# 25%                            3.588038                   7.216772e-05
# 50%                            5.055420                   1.645785e-03
# 75%                            6.563433                   1.422006e-02
# max                           12.628748                   1.000000e+00
#
#        0_1uM_PCC vs. No_Peptide logFC  0_1uM_PCC vs. No_Peptide logCPM  \
# count                     1068.000000                      1068.000000
# mean                         2.158688                         5.102770
# std                          1.377573                         2.006395
# min                        -11.435829                         0.770971
# 25%                          1.844233                         3.535290
# 50%                          2.197171                         5.023089
# 75%                          2.677047                         6.487380
# max                          5.923480                        12.565411
#
#        0_1uM_PCC vs. No_Peptide FDR  10uM_PCC vs. No_Peptide logFC  \
# count                  1.068000e+03                    1068.000000
# mean                   2.657772e-02                       2.984246
# std                    6.830878e-02                       1.776026
# min                    1.638653e-23                     -12.363026
# 25%                    2.259583e-04                       2.352408
# 50%                    2.745751e-03                       2.897727
# 75%                    1.890764e-02                       3.693453
# max                    9.417389e-01                       9.848374
#
#        10uM_PCC vs. No_Peptide logCPM  10uM_PCC vs. No_Peptide FDR
# count                     1068.000000                 1.068000e+03
# mean                         5.003985                 4.908953e-04
# std                          1.992286                 4.006835e-03
# min                          1.219011                 2.043059e-54
# 25%                          3.435183                 1.464109e-11
# 50%                          4.927576                 6.475145e-08
# 75%                          6.399564                 2.045771e-05
# max                         12.405404                 1.236720e-01

# %%
# Isolate logFC values
logfc = filtered.filter(like='logFC')
logfc.head()
# Out:
#               10uM_K99A vs. No_Peptide logFC  100uM_K99A vs. No_Peptide logFC  \
# NM_001033343                        1.038356                         1.371592
# NM_008039                           0.472504                         1.438680
# NM_001195031                        0.435930                         1.792936
# NM_007801                           1.239587                         1.981918
# NM_031393                           0.737076                         1.438270
#
#               0_1uM_PCC vs. No_Peptide logFC  10uM_PCC vs. No_Peptide logFC
# NM_001033343                        1.717078                       2.098808
# NM_008039                           1.523744                       2.697624
# NM_001195031                        1.871832                       2.634898
# NM_007801                           2.336852                       2.654450
# NM_031393                           1.937487                       2.353337

# %%
scaled = scale(logfc)

# %%
k = 4
model = KMeans(n_clusters=k)
model.fit(scaled)
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=4, n_init=10,
#     n_jobs=1, precompute_distances=True, random_state=None, tol=0.0001,
#     verbose=0)

# %%
# Make dataframe with our scaled data.
labels = model.labels_
scaled_df = pd.DataFrame(scaled, index=logfc.index, columns=logfc.columns)
scaled_df.head()
# Out:
#               10uM_K99A vs. No_Peptide logFC  100uM_K99A vs. No_Peptide logFC  \
# NM_001033343                        0.320341                        -0.405853
# NM_008039                          -0.350421                        -0.353981
# NM_001195031                       -0.393776                        -0.080074
# NM_007801                           0.558881                         0.066045
# NM_031393                          -0.036797                        -0.354299
#
#               0_1uM_PCC vs. No_Peptide logFC  10uM_PCC vs. No_Peptide logFC
# NM_001033343                       -0.320721                      -0.498783
# NM_008039                          -0.461131                      -0.161459
# NM_001195031                       -0.208331                      -0.196794
# NM_007801                           0.129393                      -0.185780
# NM_031393                          -0.160648                      -0.355403

# %%
# Add in gene names and labels for easier viewing
descriptions = data[mask_fdr & mask_cpm & mask_fc]['Annotation/Divergence']
gene_names = [s.split('|')[0] for s in descriptions]
logfc['gene_name'] = gene_names
logfc['label'] = labels
logfc.head()
# Out:
#               10uM_K99A vs. No_Peptide logFC  100uM_K99A vs. No_Peptide logFC  \
# NM_001033343                        1.038356                         1.371592
# NM_008039                           0.472504                         1.438680
# NM_001195031                        0.435930                         1.792936
# NM_007801                           1.239587                         1.981918
# NM_031393                           0.737076                         1.438270
#
#               0_1uM_PCC vs. No_Peptide logFC  10uM_PCC vs. No_Peptide logFC  \
# NM_001033343                        1.717078                       2.098808
# NM_008039                           1.523744                       2.697624
# NM_001195031                        1.871832                       2.634898
# NM_007801                           2.336852                       2.654450
# NM_031393                           1.937487                       2.353337
#
#              gene_name  label
# NM_001033343    Sec31b      2
# NM_008039         Fpr2      2
# NM_001195031      Pag1      2
# NM_007801         Ctsh      2
# NM_031393        Sytl1      2

# %%
# Output sorted by cluster.
clustered = logfc.sort(columns=['label', '10uM_K99A vs. No_Peptide logFC'])
clustered.head()
# Out:
#               10uM_K99A vs. No_Peptide logFC  100uM_K99A vs. No_Peptide logFC  \
# NM_001081445                        0.024427                         2.036341
# NM_009027                           0.215102                         2.523184
# NM_198028                           0.224669                         2.624345
# NM_009769                           0.252321                         2.119895
# NM_001033431                        0.254698                         2.214653
#
#               0_1uM_PCC vs. No_Peptide logFC  10uM_PCC vs. No_Peptide logFC  \
# NM_001081445                        2.798170                       4.859806
# NM_009027                           3.228807                       2.785113
# NM_198028                           2.373293                       4.977439
# NM_009769                           2.647664                       4.227012
# NM_001033431                        2.390881                       4.862661
#
#               gene_name  label
# NM_001081445      Ncam1      0
# NM_009027       Rasgrf2      0
# NM_198028     Serpinb10      0
# NM_009769          Klf5      0
# NM_001033431     Nlrp12      0

# %%
clustered.to_csv('output/clusters/kmeans_clusters_{}.txt'.format(k), sep='\t',
                 header=True, index=True,
                 columns=['gene_name', 'label'] + list(clustered.columns[:-2]))

# %%
clustered.describe()
# Out:
#        10uM_K99A vs. No_Peptide logFC  100uM_K99A vs. No_Peptide logFC  \
# count                     1068.000000                      1068.000000
# mean                         0.768117                         1.896499
# std                          0.843991                         1.293948
# min                         -5.740371                        -9.740325
# 25%                          0.572948                         1.657764
# 50%                          0.791651                         1.986774
# 75%                          1.068318                         2.400051
# max                          2.912628                         6.387978
#
#        0_1uM_PCC vs. No_Peptide logFC  10uM_PCC vs. No_Peptide logFC  \
# count                     1068.000000                    1068.000000
# mean                         2.158688                       2.984246
# std                          1.377573                       1.776026
# min                        -11.435829                     -12.363026
# 25%                          1.844233                       2.352408
# 50%                          2.197171                       2.897727
# 75%                          2.677047                       3.693453
# max                          5.923480                       9.848374
#
#              label
# count  1068.000000
# mean      1.330524
# std       1.066805
# min       0.000000
# 25%       0.000000
# 50%       2.000000
# 75%       2.000000
# max       3.000000

# %%
plt.figure(figsize=(15, 60))
vals_only = clustered.drop(['gene_name', 'label'], axis=1)
plt.pcolor(vals_only, cmap='coolwarm')
plt.ylim([0,len(clustered)])
xcol_names = vals_only.columns
xcol_loc = [x + .5 for x in range(0, len(xcol_names))]
plt.xticks(xcol_loc, xcol_names, rotation=90)
ycol_loc = [x + .5 for x in range(0, len(vals_only))]
plt.yticks(ycol_loc, clustered['gene_name'], size=10)
plt.colorbar()
plt.savefig('figures/kmeans_clusters_{}.png'.format(k))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-ff429d1da417> in <module>()
#       9 plt.yticks(ycol_loc, clustered['gene_name'], size=10)
#      10 plt.colorbar()
# ---> 11 plt.savefig('figures/kmeans_clusters_{}.png'.format(k))
#
# /Applications/anaconda/lib/python3.4/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     575 def savefig(*args, **kwargs):
#     576     fig = gcf()
# --> 577     res = fig.savefig(*args, **kwargs)
#     578     draw()   # need this if 'transparent=True' to reset colors
#     579     return res
#
# /Applications/anaconda/lib/python3.4/site-packages/matplotlib/figure.py in savefig(self, *args, **kwargs)
#    1474             self.set_frameon(frameon)
#    1475
# -> 1476         self.canvas.print_figure(*args, **kwargs)
#    1477
#    1478         if frameon:
#
# /Applications/anaconda/lib/python3.4/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2209                 orientation=orientation,
#    2210                 bbox_inches_restore=_bbox_inches_restore,
# -> 2211                 **kwargs)
#    2212         finally:
#    2213             if bbox_inches and restore_bbox:
#
# /Applications/anaconda/lib/python3.4/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     519
#     520     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 521         FigureCanvasAgg.draw(self)
#     522         renderer = self.get_renderer()
#     523         original_dpi = renderer.dpi
#
# /Applications/anaconda/lib/python3.4/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     462         if __debug__: verbose.report('FigureCanvasAgg.draw', 'debug-annoying')
#     463
# --> 464         self.renderer = self.get_renderer(cleared=True)
#     465         # acquire a lock on the shared font cache
#     466         RendererAgg.lock.acquire()
#
# /Applications/anaconda/lib/python3.4/site-packages/matplotlib/backends/backend_agg.py in get_renderer(self, cleared)
#     479
#     480         if need_new_renderer:
# --> 481             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     482             self._lastKey = key
#     483         elif cleared:
#
# /Applications/anaconda/lib/python3.4/site-packages/matplotlib/backends/backend_agg.py in __init__(self, width, height, dpi)
#      92         self.height = height
#      93         if __debug__: verbose.report('RendererAgg.__init__ width=%s, height=%s'%(width, height), 'debug-annoying')
# ---> 94         self._renderer = _RendererAgg(int(width), int(height), dpi, debug=False)
#      95         self._filter_renderers = []
#      96
#
# ValueError: width and height must each be below 32768
# /Applications/anaconda/lib/python3.4/site-packages/IPython/core/formatters.py:239: FormatterWarning: Exception in image/png formatter: width and height must each be below 32768
#   FormatterWarning,

# %%
pd.merge(clustered[clustered['label'] == 0], filtered)
# Out:
#      10uM_K99A vs. No_Peptide logFC  100uM_K99A vs. No_Peptide logFC  \
# 0                          0.024427                         2.036341
# 1                          0.215102                         2.523184
# 2                          0.224669                         2.624345
# 3                          0.252321                         2.119895
# 4                          0.254698                         2.214653
# 5                          0.284097                         1.950801
# 6                          0.309962                         2.503515
# 7                          0.333142                         2.762490
# 8                          0.342820                         2.283019
# 9                          0.384111                         2.586620
# 10                         0.392326                         2.209124
# 11                         0.394114                         2.050975
# 12                         0.399833                         2.841786
# 13                         0.401720                         1.947921
# 14                         0.401946                         2.288454
# 15                         0.417009                         2.138785
# 16                         0.423575                         1.834978
# 17                         0.432676                         2.248673
# 18                         0.436946                         2.459058
# 19                         0.439122                         2.545039
# 20                         0.440135                         2.046270
# 21                         0.450648                         2.575373
# 22                         0.454500                         2.235484
# 23                         0.461939                         2.537522
# 24                         0.462074                         2.291371
# 25                         0.463177                         2.582418
# 26                         0.467000                         1.904652
# 27                         0.469715                         2.077271
# 28                         0.475809                         2.388206
# 29                         0.483059                         2.247578
# ..                              ...                              ...
# 359                        1.682594                         2.174117
# 360                        1.685922                         2.395573
# 361                        1.686898                         3.116210
# 362                        1.693071                         1.995738
# 363                        1.708910                         2.588620
# 364                        1.710283                         2.160306
# 365                        1.727048                         2.770038
# 366                        1.742586                         2.137723
# 367                        1.743212                         2.276330
# 368                        1.746209                         2.973076
# 369                        1.747186                         2.984349
# 370                        1.755191                         2.399999
# 371                        1.760331                         1.684528
# 372                        1.790696                         3.470919
# 373                        1.823485                         2.625401
# 374                        1.825734                         1.953200
# 375                        1.833376                         2.449144
# 376                        1.847270                         1.871465
# 377                        1.860604                         2.170471
# 378                        1.878808                         2.771949
# 379                        1.925021                         2.494836
# 380                        1.934866                         2.323724
# 381                        1.959409                         2.454375
# 382                        1.968791                         2.140686
# 383                        2.072305                         2.506988
# 384                        2.214832                         3.051492
# 385                        2.246605                         3.021011
# 386                        2.305582                         3.327799
# 387                        2.537137                         2.348406
# 388                        2.709831                         3.075521
#
#      0_1uM_PCC vs. No_Peptide logFC  10uM_PCC vs. No_Peptide logFC  \
# 0                          2.798170                       4.859806
# 1                          3.228807                       2.785113
# 2                          2.373293                       4.977439
# 3                          2.647664                       4.227012
# 4                          2.390881                       4.862661
# 5                          2.200633                       4.265504
# 6                          2.885942                       5.395980
# 7                          2.421014                       3.512398
# 8                          2.499662                       4.598083
# 9                          2.753717                       4.328800
# 10                         2.313060                       3.383118
# 11                         2.765246                       3.428808
# 12                         3.524764                       4.286529
# 13                         2.330623                       4.033490
