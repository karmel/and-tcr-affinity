# %%
'''
Use RefSeq genes to get AP-1 counts (public Th17 data) per gene.
'''
# Out:
# '\nUse RefSeq genes to get AP-1 counts (public Th17 data) per gene.\n'

# %%
import pandas as pd

# %%
from pandas.io.sql import read_sql_query
from sqlalchemy import create_engine


def get_engine(uri, password, username='vespucci_user', dbname='vespucci'):
    '''
    dialect+driver://username:password@host:port/database
    '''
    return create_engine('postgresql://{}:{}@{}:5432/{}'.format(
        username, password, uri, dbname))


def dataframe_from_query(query, engine):
    '''
    Given the database connection and query, return a Pandas dataframe
    with the requested data.
    '''
    return read_sql_query(query, engine)

# %%
engine = get_engine(
    uri='ec2-54-237-70-249.compute-1.amazonaws.com',
    password='vespucci 2015')

# %%
sql = '''
SELECT
seq.sequence_identifier,
chrom."name" as chr_name,
reg.transcription_start,
reg.transcription_end,
reg.strand,
peak.tag_count as {peak}_tag_count

FROM genome_reference_mm10.sequence_identifier seq
JOIN genome_reference_mm10.sequence_transcription_region reg
ON seq.id = reg.sequence_identifier_id
JOIN genome_reference_mm10.chromosome chrom
ON reg.chromosome_id = chrom.id
LEFT OUTER JOIN chipseq.peak_cd4tcell_th17_{peak} peak
ON reg.chromosome_id = peak.chromosome_id
AND reg.start_site_1000 && peak.start_end

'''

# %%
datasets = []
peaks = ['batf', 'cjun', 'irf4', 'junb', 'jund']
for peak in peaks:
    data = dataframe_from_query(sql.format(peak=peak), engine)
    datasets.append(data)

# %%
all_data = pd.concat(datasets, join='outer', axis=0, ignore_index=True)
all_data = all_data.fillna(0)
all_data.head()
# Out:
#    batf_tag_count chr_name  cjun_tag_count  irf4_tag_count  junb_tag_count  \
# 0            0.00     chr7               0               0               0
# 1            0.00     chrX               0               0               0
# 2            0.00     chrX               0               0               0
# 3            7.66     chr8               0               0               0
# 4            0.00     chr9               0               0               0
#
#    jund_tag_count sequence_identifier  strand  transcription_end  \
# 0               0        NM_001166843       0           23578099
# 1               0        NM_001242950       0           11318642
# 2               0        NM_001242950       0           11315475
# 3               0           NM_173015       0          113645192
# 4               0           NM_027895       0           57596233
#
#    transcription_start
# 0             23577184
# 1             11318324
# 2             11315157
# 3            113635798
# 4             57589451

# %%
# The query will return one row for each overlapping peak
# Collapse into one row per refseq id
grouped = all_data.groupby(['sequence_identifier',
                 'chr_name',
                 'transcription_start',
                 'transcription_end',
                 'strand']).sum()
grouped.head()
# Out:
#                                                                            batf_tag_count  \
# sequence_identifier chr_name transcription_start transcription_end strand
# NM_001001130        chr13    67747799            67755134          1                15.30
# NM_001001144        chr9     110333355           110384949         0                26.84
# NM_001001152        chr13    67254917            67269068          1                27.50
# NM_001001160        chr6     85469575            85502994          1                 0.00
# NM_001001176        chrX     106206873           106219842         1                 0.00
#
#                                                                            cjun_tag_count  \
# sequence_identifier chr_name transcription_start transcription_end strand
# NM_001001130        chr13    67747799            67755134          1                 8.87
# NM_001001144        chr9     110333355           110384949         0                14.30
# NM_001001152        chr13    67254917            67269068          1                 0.00
# NM_001001160        chr6     85469575            85502994          1                 0.00
# NM_001001176        chrX     106206873           106219842         1                20.50
#
#                                                                            irf4_tag_count  \
# sequence_identifier chr_name transcription_start transcription_end strand
# NM_001001130        chr13    67747799            67755134          1                33.60
# NM_001001144        chr9     110333355           110384949         0                24.40
# NM_001001152        chr13    67254917            67269068          1                 6.69
# NM_001001160        chr6     85469575            85502994          1                 0.00
# NM_001001176        chrX     106206873           106219842         1                10.40
#
#                                                                            junb_tag_count  \
# sequence_identifier chr_name transcription_start transcription_end strand
# NM_001001130        chr13    67747799            67755134          1                  0.0
# NM_001001144        chr9     110333355           110384949         0                 27.6
# NM_001001152        chr13    67254917            67269068          1                  0.0
# NM_001001160        chr6     85469575            85502994          1                  0.0
# NM_001001176        chrX     106206873           106219842         1                  0.0
#
#                                                                            jund_tag_count
# sequence_identifier chr_name transcription_start transcription_end strand
# NM_001001130        chr13    67747799            67755134          1                 16.1
# NM_001001144        chr9     110333355           110384949         0                 63.5
# NM_001001152        chr13    67254917            67269068          1                 40.6
# NM_001001160        chr6     85469575            85502994          1                  0.0
# NM_001001176        chrX     106206873           106219842         1                 29.1

# %%
grouped.to_csv('../data/ap1_per_gene.txt', 
            sep='\t', header=True, index=True)
