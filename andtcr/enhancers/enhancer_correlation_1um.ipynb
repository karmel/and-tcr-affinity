# %%
'''
How do no-pep enhancers compare with the other two conditions?
'''
# Out:
# '\nHow do no-pep enhancers compare with the other two conditions?\n'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# %%
sns.set_context('poster')

# %%
ab = 'h3k4me2'
data = pd.io.parsers.read_csv('data/union_peaks_1um_{}.txt'.format(ab),
                sep='\t', header=0)
data = data.fillna(0)

# Rename our columns of interest
labels = ['No Peptide', '1uM K99A', '1uM PCC']
last_columns = [labels[1], labels[2], labels[0]]

data.columns = data.columns[:-len(last_columns)].tolist() + last_columns

data.head()
# Out:
#   PeakID (cmd=annotatePeaks.pl /data/mm10/CD4/ChIP/H3K4me2/AND-CD4TCell-H3K4me2-1uM-24h-MNase-All-Conditions/regions.txt mm10 -size given -d AND-CD4TCell-H3K4me2-1uM-K99A-24h-MNase-Combined AND-CD4TCell-H3K4me2-1uM-PCC-24h-MNase-Combined AND-CD4TCell-H3K4me2-No-Peptide-24h-MNase-Combined)  \
# 0                                        chr14-11544
# 1                                         chr1-34166
# 2                                         chr9-25034
# 3                                        chr11-41593
# 4                                        chr11-24338
#
#      Chr      Start        End Strand  Peak Score  Focus Ratio/Region Size  \
# 0  chr14   54144288   54237562      +      5601.3                   56.107
# 1   chr1  138125840  138177010      +      1798.7                   41.383
# 2   chr9   32691735   32727783      +      1658.3                   39.297
# 3  chr11  118218472  118250314      +      1390.0                   33.920
# 4  chr11  117316900  117343238      +      1300.8                   24.780
#
#                               Annotation  \
# 0                             Intergenic
# 1     intron (NM_011210, intron 2 of 29)
# 2   intron (NM_001038642, intron 1 of 6)
# 3  intron (NM_001112699, intron 1 of 12)
# 4  intron (NM_001113487, intron 2 of 10)
#
#                      Detailed Annotation  Distance to TSS     ...      \
# 0                             Intergenic            63004     ...
# 1     intron (NM_011210, intron 2 of 29)            23701     ...
# 2   intron (NM_001038642, intron 1 of 6)            13717     ...
# 3                         B2_Mm2|SINE|B2            14199     ...
# 4  intron (NM_001113487, intron 2 of 10)            -1646     ...
#
#   Nearest Unigene  Nearest Refseq     Nearest Ensembl Gene Name  \
# 0       Mm.319038       NM_010015  ENSMUSG00000022174      Dad1
# 1       Mm.391573       NM_011210  ENSMUSG00000026395     Ptprc
# 2       Mm.292415       NM_011808  ENSMUSG00000032035      Ets1
# 3        Mm.86413       NM_011180  ENSMUSG00000017132     Cyth1
# 4        Mm.38450       NM_017380  ENSMUSG00000059248     Sept9
#
#                                  Gene Alias  \
# 0                                  AI323713
# 1  B220|CD45R|Cd45|L-CA|Ly-5|Lyt-4|T200|loc
# 2   AI196000|AI448617|D230050P06|Ets-1|Tpl1
# 3          CLM1|CTH-1|CYTIP|Pscd1|mKIAA4240
# 4                     MSF1|Msf|PNUTL4|Sint1
#
#                                  Gene Description       Gene Type 1uM K99A  \
# 0                   defender against cell death 1  protein-coding  5380.54
# 1  protein tyrosine phosphatase, receptor type, C  protein-coding  1756.95
# 2        E26 avian leukemia oncogene 1, 5' domain  protein-coding  1550.04
# 3                                     cytohesin 1  protein-coding  1387.53
# 4                                        septin 9  protein-coding  1299.38
#
#    1uM PCC  No Peptide
# 0  5623.98     5848.92
# 1  1778.78     1891.22
# 2  1652.13     1719.38
# 3  1331.70     1432.65
# 4  1285.21     1314.73
#
# [5 rows x 22 columns]

# %%
limit = 2000

# %%
r = pearsonr(data[labels[0]], data[labels[1]])

sns.regplot(labels[0],labels[1], data,
            label='Linear fit (r={:.2f})'.format(r[0]))
plt.xlim([0,limit])
plt.ylim([0,limit])

plt.legend()

plt.xlabel('No Peptide Enhancer Tag Count')
plt.ylabel('1uM K99A Enhancer Tag Count')

title = 'No Peptide versus 1uM K99A enhancer correlation'
plt.title(title)

plt.savefig('figures/{}.png'.format(title.replace(' ','_')), 
            bbox_inches='tight')

# %%
r = pearsonr(data[labels[0]], data[labels[2]])

sns.regplot(labels[0],labels[2], data,
            label='Linear fit (r={:.2f})'.format(r[0]))
plt.xlim([0,limit])
plt.ylim([0,limit])

plt.legend()

plt.xlabel('No Peptide Enhancer Tag Count')
plt.ylabel('1uM PCC Enhancer Tag Count')

title = 'No Peptide versus 1uM PCC enhancer correlation'
plt.title(title)

plt.savefig('figures/{}.png'.format(title.replace(' ','_')), 
            bbox_inches='tight')

# %%
r = pearsonr(data[labels[1]], data[labels[2]])

sns.regplot(labels[1],labels[2], data,
            label='Linear fit (r={:.2f})'.format(r[0]))
plt.xlim([0,limit])
plt.ylim([0,limit])

plt.legend()

plt.xlabel('1uM K99A Enhancer Tag Count')
plt.ylabel('1uM PCC Enhancer Tag Count')

title = '1uM K99A versus 1uM PCC enhancer correlation'
plt.title(title)

plt.savefig('figures/{}.png'.format(title.replace(' ','_')), 
            bbox_inches='tight')
