# %%
'''
How do no-pep enhancers compare with the other two conditions?
'''
# Out:
# '\nHow do no-pep enhancers compare with the other two conditions?\n'

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# %%
ab = 'h3k27ac'
data = pd.io.parsers.read_csv('data/union_peaks_1um_{}.txt'.format(ab), 
                sep='\t', header=0)
data = data.fillna(0)

# Rename our columns of interest
labels = ['No Peptide', '1uM K99A', '1uM PCC']
last_columns = [labels[1], labels[2], labels[0]]

data.columns = data.columns[:-len(last_columns)].tolist() + last_columns

data.head()
# Out:
#   PeakID (cmd=annotatePeaks.pl /data/mm10/CD4/ChIP/H3K27Ac/AND-CD4TCell-H3K27Ac-1uM-24h-MNase-All-Conditions/regions.txt mm10 -size given -d AND-CD4TCell-H3K27Ac-1uM-K99A-24h-MNase-Combined AND-CD4TCell-H3K27Ac-1uM-PCC-24h-MNase-Combined AND-CD4TCell-H3K27Ac-No-Peptide-24h-MNase-Combined)  \
# 0                                        chr14-15663
# 1                                        chr14-18437
# 2                                         chr6-17052
# 3                                         chr9-56390
# 4                                         chr9-18001
#
#      Chr     Start       End Strand  Peak Score  Focus Ratio/Region Size  \
# 0  chr14  54188639  54237983      +      4693.6                   36.003
# 1  chr14  54143129  54187413      +      1923.1                   67.050
# 2   chr6  41530297  41560047      +      1908.1                  127.227
# 3   chr9  32694702  32734546      +      1655.3                   30.703
# ...

# %%
limit = 2000

# %%
r = pearsonr(data[labels[0]], data[labels[1]])

plt.plot(data[labels[0]],data[labels[1]], '.',
            label='r={:.2f}'.format(r[0]))

plt.xlim([0,limit])
plt.ylim([0,limit])

plt.legend()

plt.xlabel('No Peptide Enhancer Tag Count')
plt.ylabel('1uM K99A Enhancer Tag Count')

title = 'No Peptide versus 1uM K99A H3K27Ac correlation'
plt.title(title, y=1.01)

plt.savefig('figures/{}'.format(title.replace(' ','_')), 
            bbox_inches='tight')

# %%
r = pearsonr(data[labels[0]], data[labels[2]])

plt.plot(data[labels[0]],data[labels[2]], '.',
            label='r={:.2f}'.format(r[0]))

plt.xlim([0,limit])
plt.ylim([0,limit])

plt.legend()

plt.xlabel('No Peptide Enhancer Tag Count')
plt.ylabel('1uM PCC Enhancer Tag Count')

title = 'No Peptide versus 1uM PCC H3K27Ac correlation'
plt.title(title, y=1.01)

plt.savefig('figures/{}'.format(title.replace(' ','_')), 
            bbox_inches='tight')

# %%
r = pearsonr(data[labels[1]], data[labels[2]])

plt.plot(data[labels[1]],data[labels[2]], '.',
            label='r={:.2f}'.format(r[0]))

plt.xlim([0,limit])
plt.ylim([0,limit])

plt.legend()

plt.xlabel('1uM K99A Enhancer Tag Count')
plt.ylabel('1uM PCC Enhancer Tag Count')

title = '1uM K99A versus 1uM PCC H3K27Ac correlation'
plt.title(title, y=1.01)

plt.savefig('figures/{}'.format(title.replace(' ','_')), 
            bbox_inches='tight')
